# %%
import argparse
import math
import os
import sys
import time

import numpy as np
from loguru import logger
from collections import defaultdict


import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import DataLoader
from tqdm.auto import tqdm

from transformers import AutoModelForSequenceClassification
from transformers import TFAutoModelForSequenceClassification
from transformers import AutoTokenizer, AutoModel

from dataset.dataset_dbpedia import DBpedia
from dataset.load_data import SentDataLoader, RecDataLoader

# %%
import easydict


args = easydict.EasyDict({
    'seed': 42,
    'output_dir': 'save',
    'output_dataset_dir': 'data/redial/',
    'debug': False,
    'dataset': 'data/redial/',
    'kg_dataset': 'data/dbpedia/',
    
    'context_max_length': 256,
    'entity_max_length': 50,
    'num_workers': 0,
    'senti_tokenizer': 'roberta-base',
    'text_tokenizer': 'roberta-base',
    'text_encoder': 'roberta-base',
    'num_bases': 8,
    
    'num_epochs': 30, #10,
    'batch_size': 64, #64, #256,
    'entity_hidden_size': 128,  
    
    'gradient_accumulation_steps': 1,
    'learning_rate': 1e-3,
    'weight_decay': 0.01,
    'max_grad_norm': None,
    'num_warmup_steps': None,
    'device': 'cuda:1' if torch.cuda.is_available() else 'cpu',
})

print(args.device)

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
print(">>>>>>>>>>> CUDA available :", torch.cuda.is_available())
# Out:
# cuda:1
# >>>>>>>>>>> CUDA available : True

# %%
from transformers import pipeline
 
sentiment_model = pipeline(model="federicopascual/finetuning-sentiment-model-3000-samples")
sentiment_model(["I love this move", "This movie sucks!"])

# %%
# from evaluate_rec import RecEvaluator
# from model_gpt2 import PromptGPT2forCRS
# from config import gpt2_special_tokens_dict, prompt_special_tokens_dict
# from model_prompt import KGPrompt

###############################################################################
## Environment Setting
###############################################################################

def set_seed(seed):
    """
        Setting random seeds
    """
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    np.random.seed(seed)
    
set_seed(args.seed)

# ###############################################################################
# ## Load Data & KG
# ###############################################################################

kg = DBpedia(dataset=args.dataset).get_entity_kg_info()


task='sentiment'
MODEL = f"cardiffnlp/twitter-roberta-base-{task}"

sent_model = AutoModelForSequenceClassification.from_pretrained(MODEL)
sent_model = sent_model.to(args.device)

# Load the tokenizer
senti_tokenizer = AutoTokenizer.from_pretrained(MODEL)

sent_train_dataloader, sent_val_dataloader, sent_test_dataloader = SentDataLoader(args, senti_tokenizer)
#train_dataloader, val_dataloader, test_dataloader = RecDataLoader(args, senti_tokenizer, pad_entity_id=kg['pad_entity_id'])

# pad_entity_id = kg['pad_entity_id']
# train_dataset = CRSRecDataset(
#             dpath=args.dataset, split='train', 
#             tokenizer=senti_tokenizer, context_max_length=args.context_max_length,
#         )

# valid_dataset = CRSRecDataset(
#         dpath=args.dataset, split='valid', 
#         tokenizer=senti_tokenizer, context_max_length=args.context_max_length,
#     )

# test_dataset = CRSRecDataset(
#         dpath=args.dataset, split='test', 
#         tokenizer=senti_tokenizer, context_max_length=args.context_max_length,
#     )

# data_collator = CRSRecDataCollator(
#         tokenizer=senti_tokenizer, context_max_length=args.context_max_length,
#         pad_entity_id=pad_entity_id, device=args.device
#     )

# train_dataloader = DataLoader(
#         train_dataset,
#         batch_size=args.batch_size,
#         collate_fn=data_collator,
#         shuffle=True
#     )
# val_dataloader = DataLoader(
#         valid_dataset,
#         batch_size=args.batch_size,
#         collate_fn=data_collator,
#     )
# test_dataloader = DataLoader(
#         test_dataset,
#         batch_size=args.batch_size,
#         collate_fn=data_collator,
#     )
# Out:
# >>>>>>>>>>> CUDA available : True
# 2023-12-12 13:53:12.170 | DEBUG    | dataset.dataset_dbpedia:_process_entity_kg:40 - #edge: 186339, #relation: 25, #entity: 30890, #item: 6281
#   0%|          | 0/110206 [00:00<?, ?it/s]
#   0%|          | 0/12284 [00:00<?, ?it/s]
#   0%|          | 0/15452 [00:00<?, ?it/s]
#   0%|          | 0/101514 [00:00<?, ?it/s]
#   0%|          | 0/11294 [00:00<?, ?it/s]
#   0%|          | 0/14174 [00:00<?, ?it/s]

# %%
for sent_batch in sent_train_dataloader:
    print("!")
    break
# Out:
# You're using a RobertaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# !
# /home/hyuns6100/anaconda3/envs/env3/lib/python3.8/site-packages/transformers/tokenization_utils_base.py:2372: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   warnings.warn(

# %%
for batch in train_dataloader:
    print("!")
    break
# Out:
# !
# /home/hyuns6100/anaconda3/envs/env3/lib/python3.8/site-packages/transformers/tokenization_utils_base.py:2372: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   warnings.warn(

# %%
train_ent_sent['17839']
# Out:
# {19174: tensor(0.9979, device='cuda:1'),
#  21083: tensor(0.9976, device='cuda:1'),
#  19018: tensor(0.9987, device='cuda:1'),
#  12533: tensor(0.9987, device='cuda:1')}

# %%
batch['conv_id'][2], batch['entity'][2]
# Out:
# ('17839',
#  tensor([19018,  1771, 12533, 30889, 30889, 30889, 30889, 30889, 30889, 30889,
#          30889, 30889, 30889, 30889, 30889, 30889, 30889], device='cuda:1'))

# %%
entity_lists = batch['entity']

user_repr_list = []

for i, entity_list in enumerate(entity_lists):
    if i == 2:
        # pad_entity_id를 제외한 실제 entity ID만 필터링
        filtered_entity_list = [entity for entity in entity_list if entity != kg['pad_entity_id']]

        if not filtered_entity_list:
            # 실제 엔티티가 없는 경우
            user_repr_list.append(torch.zeros(128))#args.kg_emb_dim))
            continue

        filtered_entity_tensor = torch.tensor(filtered_entity_list, dtype=torch.long, )#device=self.device)
        user_repr = kg_embedding[filtered_entity_tensor] # (n_e, dim)

# %%
train_ent_sent['17839']
# Out:
# {19174: tensor(0.9979, device='cuda:1'),
#  21083: tensor(0.9976, device='cuda:1'),
#  19018: tensor(0.9987, device='cuda:1'),
#  12533: tensor(0.9987, device='cuda:1')}

# %%
batch['conv_id'][2], batch['entity'][2], filtered_entity_tensor
# Out:
# ('17839',
#  tensor([19018,  1771, 12533, 30889, 30889, 30889, 30889, 30889, 30889, 30889,
#          30889, 30889, 30889, 30889, 30889, 30889, 30889], device='cuda:1'),
#  tensor([19018,  1771, 12533]))

# %%
ent_sent_dict
# Out:
# {19174: tensor(0.9979, device='cuda:1'),
#  21083: tensor(0.9976, device='cuda:1'),
#  19018: tensor(0.9987, device='cuda:1'),
#  12533: tensor(0.9987, device='cuda:1')}

# %%
ent_sent_dict = self.ent_sent[conv_id]
for i, entity_id in enumerate(entity_list):
    if entity_id in ent_sent_dict:
        sentiment_score = ent_sent_dict[entity_id]

# %%
conv_id = "17839"
ent_sent_dict = train_ent_sent[conv_id]
for i, entity_id in enumerate(filtered_entity_tensor.tolist()):
    if entity_id in ent_sent_dict:
        sentiment_score = ent_sent_dict[entity_id]
        print(entity_id, sentiment_score)
# Out:
# 19018 tensor(0.9987, device='cuda:1')
# 12533 tensor(0.9987, device='cuda:1')

# %%
class SelfAttentionBatch(nn.Module):
    def __init__(self, dim, da, alpha=0.2, dropout=0.5):
        super(SelfAttentionBatch, self).__init__()
        self.dim = dim
        self.da = da
        self.alpha = alpha
        self.dropout = dropout
        self.a = nn.Parameter(torch.zeros(size=(self.dim, self.da)), requires_grad=True)
        self.b = nn.Parameter(torch.zeros(size=(self.da, 1)), requires_grad=True)
        nn.init.xavier_uniform_(self.a.data, gain=1.414)
        nn.init.xavier_uniform_(self.b.data, gain=1.414)

    def forward(self, h, entity_list, train_ent_sent):
        # h: (N, dim) => user가 상호작용한 item/entity 개수만큼의 행렬
        
        e = torch.matmul(torch.tanh(torch.matmul(h, self.a)), self.b).squeeze(dim=1)  # (N)
        print(e.shape, e)
        
        attention = F.softmax(e, dim=0)  # (N)
        print(attention.shape, attention)
        
        conv_id = "17839"
        ent_sent_dict = train_ent_sent[conv_id]
        for i, entity_id in enumerate(entity_list.tolist()):
            if entity_id in ent_sent_dict:
                sent_score = ent_sent_dict[entity_id]
                attention[i] *= sent_score.detach().cpu()
            
        print(attention.shape, attention)
        
        # 조정된 attention 가중치를 정규화
        norm_attention = attention / attention.sum()
        print(norm_attention.shape, norm_attention)
        
        return torch.matmul(norm_attention, h)  # (dim)

# %%
# # train_ent_sent["17839"]

# from copy import deepcopy

# copy_train_ent_sent = deepcopy(train_ent_sent)

# %%
# copy_train_ent_sent["17839"][12533] = torch.tensor(0.2312, device=args.device)
copy_train_ent_sent["17839"]
# Out:
# {19174: tensor(0.9979, device='cuda:1'),
#  21083: tensor(0.9976, device='cuda:1'),
#  19018: tensor(0.9987, device='cuda:1'),
#  12533: tensor(0.2312, device='cuda:1')}

# %%
copy_train_ent_sent
# Out:
# defaultdict(dict,
#             {'14536': {17897: tensor(0.9613, device='cuda:1'),
#               26306: tensor(0.9987, device='cuda:1'),
#               27698: tensor(0.9987, device='cuda:1')},
#              '1516': {18488: tensor(0.9987, device='cuda:1'),
#               28626: tensor(0.9988, device='cuda:1'),
#               26306: tensor(0.9988, device='cuda:1'),
#               25107: tensor(0.9988, device='cuda:1'),
#               28695: tensor(0.9980, device='cuda:1')},
#              '5458': {12533: tensor(0.9982, device='cuda:1'),
#               2115: tensor(0.9980, device='cuda:1'),
#               7102: tensor(0.9968, device='cuda:1')},
#              '5219': {20183: tensor(0.9967, device='cuda:1'),
#               16507: tensor(0.9965, device='cuda:1'),
#               25417: tensor(0.9974, device='cuda:1'),
#               26306: tensor(0.9861, device='cuda:1'),
#               8565: tensor(0.9966, device='cuda:1')},
#              '8126': {26306: tensor(0.9991, device='cuda:1'),
#               9090: tensor(0.9985, device='cuda:1'),
#               21325: tensor(0.9985, device='cuda:1'),
#               22254: tensor(0.9985, device='cuda:1'),
#               16223: tensor(0.9985, device='cuda:1'),
#               10454: tensor(0.9985, device='cuda:1')},
#              '14028': {15264: tensor(0.9893, device='cuda:1'),
#               16223: tensor(0.8867, device='cuda:1'),
#               12570: tensor(0.9862, device='cuda:1'),
#               19454: tensor(0.9862, device='cuda:1')},
#              '13378': {28626: tensor(0.9979, device='cuda:1')},
#              '15824': {26306: tensor(0.9987, device='cuda:1'),
#               12533: tensor(0.9921, device='cuda:1'),
#               19174: tensor(0.9982, device='cuda:1')},
#              '12179': {19018: tensor(0.9979, device='cuda:1'),
#               25155: tensor(0.9971, device='cuda:1'),
#               19174: tensor(0.9938, device='cuda:1'),
#               26306: tensor(0.9956, device='cuda:1'),
#               7579: tensor(0.9956, device='cuda:1')},
#              '11878': {28149: tensor(0.9930, device='cuda:1'),
#               19174: tensor(0.9501, device='cuda:1')},
#              '15478': {3828: tensor(0.9970, device='cuda:1')},
#              '19166': {20028: tensor(0.9987, device='cuda:1'),
#               1615: tensor(0.9987, device='cuda:1'),
#               12533: tensor(0.9985, device='cuda:1'),
#               16384: tensor(0.9967, device='cuda:1')},
#              '11940': {12533: tensor(0.9987, device='cuda:1'),
#               19174: tensor(0.9988, device='cuda:1')},
#              '17611': {25417: tensor(0.9948, device='cuda:1'),
#               12205: tensor(0.9689, device='cuda:1'),
#               19174: tensor(0.9814, device='cuda:1')},
#              '1507': {26338: tensor(0.9987, device='cuda:1'),
#               15812: tensor(0.9987, device='cuda:1'),
#               26306: tensor(0.9988, device='cuda:1'),
#               30546: tensor(0.9955, device='cuda:1'),
#               8828: tensor(0.9955, device='cuda:1')},
#              '10961': {17897: tensor(0.9939, device='cuda:1'),
#               13991: tensor(0.9941, device='cuda:1'),
#               29288: tensor(0.9948, device='cuda:1'),
#               15070: tensor(0.9963, device='cuda:1')},
#              '1159': {17782: tensor(0.9953, device='cuda:1'),
#               24790: tensor(0.9987, device='cuda:1'),
#               26306: tensor(0.9986, device='cuda:1'),
#               2115: tensor(0.9986, device='cuda:1'),
#               16223: tensor(0.9873, device='cuda:1')},
#              '16105': {2115: tensor(0.8876, device='cuda:1'),
#               18874: tensor(0.8526, device='cuda:1'),
#               3682: tensor(0.8526, device='cuda:1'),
#               8828: tensor(0.8526, device='cuda:1')},
#              '7078': {20028: tensor(0.9927, device='cuda:1'),
#               19174: tensor(0.9927, device='cuda:1'),
#               25107: tensor(0.9921, device='cuda:1'),
#               3812: tensor(0.9944, device='cuda:1'),
#               26306: tensor(0.9955, device='cuda:1'),
#               21083: tensor(0.9921, device='cuda:1'),
#               7805: tensor(0.9928, device='cuda:1'),
#               25158: tensor(0.9928, device='cuda:1')},
#              '18824': {12533: tensor(0.9955, device='cuda:1')},
#              '19023': {21083: tensor(0.9958, device='cuda:1'),
#               16223: tensor(0.9958, device='cuda:1'),
#               6138: tensor(0.9987, device='cuda:1'),
#               26306: tensor(0.9983, device='cuda:1')},
#              '15263': {19415: tensor(0.9978, device='cuda:1'),
#               27841: tensor(0.9974, device='cuda:1')},
#              '7617': {15867: tensor(0.9959, device='cuda:1'),
#               16223: tensor(0.9977, device='cuda:1'),
#               13835: tensor(0.9982, device='cuda:1')},
#              '16626': {15083: tensor(0.9973, device='cuda:1'),
#               19174: tensor(0.9970, device='cuda:1'),
#               12533: tensor(0.9976, device='cuda:1'),
#               2115: tensor(0.9989, device='cuda:1'),
#               23446: tensor(0.9970, device='cuda:1'),
#               16223: tensor(0.9970, device='cuda:1')},
#              '1061': {19018: tensor(0.9906, device='cuda:1'),
#               25107: tensor(0.9906, device='cuda:1'),
#               16223: tensor(0.9969, device='cuda:1')},
#              '6583': {9158: tensor(0.9978, device='cuda:1'),
#               3369: tensor(0.9959, device='cuda:1'),
#               10856: tensor(0.9988, device='cuda:1')},
#              '11277': {24528: tensor(0.9986, device='cuda:1'),
#               12533: tensor(0.9986, device='cuda:1'),
#               16223: tensor(0.9986, device='cuda:1'),
#               3724: tensor(0.9970, device='cuda:1'),
#               26306: tensor(0.9973, device='cuda:1'),
#               5080: tensor(0.9932, device='cuda:1'),
#               15474: tensor(0.9932, device='cuda:1')},
#              '2672': {19174: tensor(0.9956, device='cuda:1'),
#               26306: tensor(0.9919, device='cuda:1'),
#               15084: tensor(0.9944, device='cuda:1'),
#               3682: tensor(0.9978, device='cuda:1'),
#               12533: tensor(0.9978, device='cuda:1')},
#              '18693': {25731: tensor(0.9960, device='cuda:1'),
#               16223: tensor(0.9960, device='cuda:1'),
#               19174: tensor(0.9976, device='cuda:1'),
#               6099: tensor(0.9972, device='cuda:1')},
#              '17873': {25858: tensor(0.6267, device='cuda:1'),
#               28621: tensor(0.9972, device='cuda:1'),
#               16223: tensor(0.9972, device='cuda:1'),
#               19724: tensor(0.9394, device='cuda:1'),
#               3067: tensor(0.9394, device='cuda:1'),
#               26660: tensor(0.9394, device='cuda:1'),
#               15812: tensor(0.9394, device='cuda:1')},
#              '1870': {13719: tensor(0.7711, device='cuda:1'),
#               21083: tensor(0.9980, device='cuda:1'),
#               1439: tensor(0.7711, device='cuda:1'),
#               3812: tensor(0.9890, device='cuda:1'),
#               16620: tensor(0.9890, device='cuda:1')},
#              '17731': {19174: tensor(0.9939, device='cuda:1'),
#               2558: tensor(0.9919, device='cuda:1'),
#               16223: tensor(0.9958, device='cuda:1')},
#              '13823': {12533: tensor(0.9970, device='cuda:1'),
#               19174: tensor(0.9925, device='cuda:1')},
#              '18371': {16506: tensor(0.9937, device='cuda:1'),
#               8589: tensor(0.9961, device='cuda:1'),
#               20183: tensor(0.9969, device='cuda:1')},
#              '16347': {19018: tensor(0.9954, device='cuda:1'),
#               27619: tensor(0.9969, device='cuda:1'),
#               24180: tensor(0.9969, device='cuda:1'),
#               16223: tensor(0.9967, device='cuda:1')},
#              '7786': {21849: tensor(0.9960, device='cuda:1'),
#               17897: tensor(0.9925, device='cuda:1'),
#               12533: tensor(0.9947, device='cuda:1')},
#              '5851': {16223: tensor(0.9987, device='cuda:1'),
#               26306: tensor(0.9987, device='cuda:1')},
#              '19555': {5332: tensor(0.9958, device='cuda:1'),
#               8870: tensor(0.9958, device='cuda:1'),
#               1615: tensor(0.9958, device='cuda:1'),
#               11235: tensor(0.9965, device='cuda:1'),
#               3682: tensor(0.9958, device='cuda:1'),
#               19174: tensor(0.9963, device='cuda:1')},
#              '17869': {26306: tensor(0.5114, device='cuda:1'),
#               25107: tensor(0.5114, device='cuda:1'),
#               19174: tensor(0.5114, device='cuda:1'),
#               12205: tensor(0.7865, device='cuda:1')},
#              '8618': {26306: tensor(0.9946, device='cuda:1'),
#               8828: tensor(0.9941, device='cuda:1'),
#               12533: tensor(0.9917, device='cuda:1'),
#               7822: tensor(0.9917, device='cuda:1'),
#               3682: tensor(0.9941, device='cuda:1')},
#              '15664': {2115: tensor(0.9753, device='cuda:1'),
#               28551: tensor(0.8497, device='cuda:1'),
#               3682: tensor(0.9617, device='cuda:1'),
#               18874: tensor(0.9845, device='cuda:1'),
#               21083: tensor(0.9434, device='cuda:1'),
#               16223: tensor(0.9434, device='cuda:1'),
#               21301: tensor(0.9136, device='cuda:1'),
#               3724: tensor(0.9136, device='cuda:1'),
#               1925: tensor(0.9136, device='cuda:1')},
#              '6204': {12533: tensor(0.9942, device='cuda:1'),
#               19174: tensor(0.9971, device='cuda:1'),
#               13085: tensor(0.9820, device='cuda:1')},
#              '8438': {12533: tensor(0.9984, device='cuda:1'),
#               20009: tensor(0.9984, device='cuda:1'),
#               19174: tensor(0.9983, device='cuda:1'),
#               21325: tensor(0.9983, device='cuda:1'),
#               21435: tensor(0.9985, device='cuda:1')},
#              '4783': {26306: tensor(0.9986, device='cuda:1'),
#               25858: tensor(0.9986, device='cuda:1'),
#               16223: tensor(0.9812, device='cuda:1'),
#               4939: tensor(0.9979, device='cuda:1')},
#              '2889': {20183: tensor(0.9987, device='cuda:1'),
#               16044: tensor(0.9988, device='cuda:1'),
#               5251: tensor(0.9985, device='cuda:1'),
#               26306: tensor(0.9987, device='cuda:1'),
#               19174: tensor(0.9986, device='cuda:1')},
#              '12183': {7579: tensor(0.9980, device='cuda:1'),
#               5332: tensor(0.9980, device='cuda:1'),
#               26306: tensor(0.9983, device='cuda:1'),
#               12533: tensor(0.9988, device='cuda:1'),
#               1685: tensor(0.9988, device='cuda:1'),
#               16223: tensor(0.9988, device='cuda:1')},
#              '3801': {8828: tensor(0.9973, device='cuda:1'),
#               16223: tensor(0.9922, device='cuda:1'),
#               3682: tensor(0.9922, device='cuda:1')},
#              '5520': {25107: tensor(0.9979, device='cuda:1'),
#               26306: tensor(0.9991, device='cuda:1'),
#               17897: tensor(0.9988, device='cuda:1'),
#               2115: tensor(0.9988, device='cuda:1'),
#               16223: tensor(0.9988, device='cuda:1')},
#              '7435': {12533: tensor(0.9890, device='cuda:1'),
#               18770: tensor(0.9186, device='cuda:1'),
#               21325: tensor(0.9186, device='cuda:1'),
#               25858: tensor(0.9933, device='cuda:1')},
#              '8811': {8828: tensor(0.9979, device='cuda:1'),
#               20183: tensor(0.9974, device='cuda:1')},
#              '17106': {2115: tensor(0.9980, device='cuda:1'),
#               26306: tensor(0.9988, device='cuda:1'),
#               16223: tensor(0.9988, device='cuda:1'),
#               17579: tensor(0.9976, device='cuda:1')},
#              '19382': {19174: tensor(0.9940, device='cuda:1'),
#               15264: tensor(0.9915, device='cuda:1')},
#              '7990': {2535: tensor(0.9974, device='cuda:1'),
#               21083: tensor(0.9976, device='cuda:1'),
#               16223: tensor(0.9976, device='cuda:1')},
#              '8978': {16223: tensor(0.9958, device='cuda:1'),
#               2460: tensor(0.9963, device='cuda:1'),
#               29966: tensor(0.9963, device='cuda:1'),
#               29650: tensor(0.9977, device='cuda:1'),
#               7535: tensor(0.9977, device='cuda:1')},
#              '786': {30823: tensor(0.3859, device='cuda:1'),
#               28626: tensor(0.9922, device='cuda:1'),
#               3682: tensor(0.9922, device='cuda:1'),
#               2558: tensor(0.9922, device='cuda:1'),
#               25417: tensor(0.3540, device='cuda:1'),
#               29544: tensor(0.9736, device='cuda:1'),
#               6869: tensor(0.9736, device='cuda:1')},
#              '9225': {3828: tensor(0.9963, device='cuda:1'),
#               24180: tensor(0.9936, device='cuda:1'),
#               1925: tensor(0.9934, device='cuda:1')},
#              '9386': {20602: tensor(0.9682, device='cuda:1'),
#               3828: tensor(0.8522, device='cuda:1')},
#              '5870': {5251: tensor(0.9931, device='cuda:1'),
#               11195: tensor(0.9931, device='cuda:1')},
#              '5230': {25107: tensor(0.9978, device='cuda:1'),
#               25155: tensor(0.9988, device='cuda:1'),
#               2558: tensor(0.9978, device='cuda:1'),
#               2762: tensor(0.9990, device='cuda:1'),
#               27335: tensor(0.9990, device='cuda:1')},
#              '9278': {28626: tensor(0.9977, device='cuda:1'),
#               26306: tensor(0.9833, device='cuda:1'),
#               8565: tensor(0.9961, device='cuda:1'),
#               19018: tensor(0.9974, device='cuda:1')},
#              '4486': {10856: tensor(0.9986, device='cuda:1'),
#               5332: tensor(0.9982, device='cuda:1'),
#               17782: tensor(0.9982, device='cuda:1'),
#               19174: tensor(0.9985, device='cuda:1'),
#               5251: tensor(0.9982, device='cuda:1'),
#               8828: tensor(0.9987, device='cuda:1')},
#              '14410': {7432: tensor(0.9399, device='cuda:1'),
#               2355: tensor(0.9399, device='cuda:1'),
#               19174: tensor(0.9864, device='cuda:1'),
#               3682: tensor(0.9961, device='cuda:1')},
#              '5510': {26306: tensor(0.9978, device='cuda:1'),
#               16223: tensor(0.9984, device='cuda:1')},
#              '15419': {10856: tensor(0.9788, device='cuda:1'),
#               26306: tensor(0.9766, device='cuda:1'),
#               5251: tensor(0.9979, device='cuda:1'),
#               12533: tensor(0.9979, device='cuda:1'),
#               14135: tensor(0.9766, device='cuda:1'),
#               19174: tensor(0.9887, device='cuda:1'),
#               16223: tensor(0.9982, device='cuda:1')},
#              '11205': {19018: tensor(0.9922, device='cuda:1'),
#               5251: tensor(0.9787, device='cuda:1'),
#               26306: tensor(0.9787, device='cuda:1'),
#               20602: tensor(0.9934, device='cuda:1'),
#               22572: tensor(0.9934, device='cuda:1'),
#               15474: tensor(0.9934, device='cuda:1'),
#               21890: tensor(0.9747, device='cuda:1'),
#               7875: tensor(0.9747, device='cuda:1'),
#               11406: tensor(0.9747, device='cuda:1')},
#              '8812': {3828: tensor(0.9955, device='cuda:1'),
#               7491: tensor(0.9954, device='cuda:1'),
#               19174: tensor(0.9954, device='cuda:1'),
#               25417: tensor(0.9919, device='cuda:1')},
#              '13734': {19174: tensor(0.9915, device='cuda:1'),
#               20183: tensor(0.9915, device='cuda:1'),
#               16223: tensor(0.9915, device='cuda:1'),
#               19018: tensor(0.9228, device='cuda:1')},
#              '8766': {3828: tensor(0.9975, device='cuda:1'),
#               24180: tensor(0.9974, device='cuda:1')},
#              '10611': {557: tensor(0.9234, device='cuda:1'),
#               15264: tensor(0.9929, device='cuda:1'),
#               20625: tensor(0.9929, device='cuda:1'),
#               6869: tensor(0.9929, device='cuda:1'),
#               27321: tensor(0.9929, device='cuda:1'),
#               27708: tensor(0.9929, device='cuda:1'),
#               21448: tensor(0.9920, device='cuda:1'),
#               14510: tensor(0.9960, device='cuda:1')},
#              '13792': {8828: tensor(0.6476, device='cuda:1'),
#               26306: tensor(0.9840, device='cuda:1'),
#               7432: tensor(0.9783, device='cuda:1'),
#               24528: tensor(0.9878, device='cuda:1'),
#               29358: tensor(0.9878, device='cuda:1')},
#              '4267': {19174: tensor(0.9940, device='cuda:1'),
#               25107: tensor(0.9980, device='cuda:1')},
#              '12727': {19174: tensor(0.8518, device='cuda:1'),
#               28149: tensor(0.8146, device='cuda:1'),
#               16223: tensor(0.9592, device='cuda:1')},
#              '518': {19018: tensor(0.9984, device='cuda:1'),
#               25107: tensor(0.9984, device='cuda:1'),
#               1925: tensor(0.9827, device='cuda:1'),
#               16223: tensor(0.9829, device='cuda:1')},
#              '9704': {18874: tensor(0.9984, device='cuda:1'),
#               20028: tensor(0.9984, device='cuda:1'),
#               20602: tensor(0.9971, device='cuda:1'),
#               3682: tensor(0.9986, device='cuda:1'),
#               12533: tensor(0.9986, device='cuda:1')},
#              '13322': {26306: tensor(0.8360, device='cuda:1'),
#               8126: tensor(0.8360, device='cuda:1'),
#               19174: tensor(0.8360, device='cuda:1'),
#               16223: tensor(0.9474, device='cuda:1'),
#               10856: tensor(0.9865, device='cuda:1'),
#               25858: tensor(0.9161, device='cuda:1'),
#               14705: tensor(0.8971, device='cuda:1')},
#              '7876': {16223: tensor(0.9596, device='cuda:1')},
#              '11048': {12533: tensor(0.9470, device='cuda:1'),
#               25417: tensor(0.7789, device='cuda:1'),
#               20602: tensor(0.9831, device='cuda:1'),
#               22497: tensor(0.9799, device='cuda:1'),
#               3724: tensor(0.6313, device='cuda:1'),
#               1925: tensor(0.9932, device='cuda:1'),
#               17144: tensor(0.0307, device='cuda:1'),
#               7822: tensor(0.9541, device='cuda:1'),
#               109: tensor(0.1152, device='cuda:1'),
#               15264: tensor(0.6313, device='cuda:1'),
#               21030: tensor(0.6313, device='cuda:1'),
#               17018: tensor(0.8432, device='cuda:1'),
#               28551: tensor(0.8432, device='cuda:1'),
#               21301: tensor(0.9929, device='cuda:1'),
#               15070: tensor(0.7076, device='cuda:1'),
#               19174: tensor(0.7789, device='cuda:1'),
#               25107: tensor(0.8771, device='cuda:1'),
#               20108: tensor(0.9967, device='cuda:1'),
#               26306: tensor(0.5068, device='cuda:1'),
#               29244: tensor(0.9799, device='cuda:1'),
#               8076: tensor(0.9799, device='cuda:1'),
#               21083: tensor(0.4661, device='cuda:1'),
#               23597: tensor(0.4661, device='cuda:1')},
#              '8594': {3828: tensor(0.9291, device='cuda:1'),
#               1925: tensor(0.9759, device='cuda:1'),
#               24180: tensor(0.9748, device='cuda:1')},
#              '7525': {17340: tensor(0.9903, device='cuda:1'),
#               607: tensor(0.9903, device='cuda:1'),
#               12533: tensor(0.9931, device='cuda:1'),
#               19174: tensor(0.9918, device='cuda:1'),
#               25417: tensor(0.9926, device='cuda:1'),
#               1925: tensor(0.9926, device='cuda:1')},
#              '14446': {26306: tensor(0.9985, device='cuda:1'),
#               19174: tensor(0.9985, device='cuda:1'),
#               29787: tensor(0.9985, device='cuda:1')},
#              '17098': {2115: tensor(0.9982, device='cuda:1'),
#               20028: tensor(0.9880, device='cuda:1')},
#              '17862': {10856: tensor(0.9944, device='cuda:1'),
#               25417: tensor(0.9944, device='cuda:1'),
#               2558: tensor(0.9915, device='cuda:1'),
#               21083: tensor(0.9938, device='cuda:1'),
#               22992: tensor(0.9840, device='cuda:1'),
#               12533: tensor(0.9840, device='cuda:1'),
#               26306: tensor(0.9915, device='cuda:1'),
#               29407: tensor(0.9915, device='cuda:1')},
#              '15147': {26306: tensor(0.9972, device='cuda:1'),
#               25417: tensor(0.9891, device='cuda:1')},
#              '674': {26306: tensor(0.9651, device='cuda:1'),
#               1925: tensor(0.8667, device='cuda:1')},
#              '18043': {13088: tensor(0.9979, device='cuda:1'),
#               15905: tensor(0.9981, device='cuda:1'),
#               28058: tensor(0.9983, device='cuda:1'),
#               30546: tensor(0.9974, device='cuda:1')},
#              '10079': {26306: tensor(0.9085, device='cuda:1'),
#               17830: tensor(0.9085, device='cuda:1'),
#               30024: tensor(0.8222, device='cuda:1'),
#               19354: tensor(0.8222, device='cuda:1')},
#              '12451': {684: tensor(0.9655, device='cuda:1')},
#              '12313': {11406: tensor(0.9981, device='cuda:1'),
#               16021: tensor(0.9911, device='cuda:1'),
#               10856: tensor(0.9888, device='cuda:1')},
#              '7878': {19174: tensor(0.9983, device='cuda:1'),
#               10856: tensor(0.9804, device='cuda:1'),
#               26306: tensor(0.9980, device='cuda:1')},
#              '14869': {26306: tensor(0.9979, device='cuda:1'),
#               19174: tensor(0.9983, device='cuda:1'),
#               16223: tensor(0.9983, device='cuda:1'),
#               15070: tensor(0.9984, device='cuda:1')},
#              '7430': {3682: tensor(0.9399, device='cuda:1'),
#               8828: tensor(0.9399, device='cuda:1'),
#               21083: tensor(0.9974, device='cuda:1')},
#              '12221': {5332: tensor(0.9979, device='cuda:1'),
#               16223: tensor(0.9979, device='cuda:1'),
#               3682: tensor(0.9981, device='cuda:1')},
#              '19255': {26306: tensor(0.9990, device='cuda:1'),
#               17579: tensor(0.9990, device='cuda:1'),
#               17897: tensor(0.9988, device='cuda:1'),
#               12631: tensor(0.9966, device='cuda:1'),
#               28359: tensor(0.9966, device='cuda:1')},
#              '3972': {21435: tensor(0.9981, device='cuda:1'),
#               15812: tensor(0.9981, device='cuda:1'),
#               8589: tensor(0.9981, device='cuda:1'),
#               3682: tensor(0.9713, device='cuda:1')},
#              '10927': {10856: tensor(0.9838, device='cuda:1'),
#               19174: tensor(0.9725, device='cuda:1')},
#              '2434': {16223: tensor(0.9990, device='cuda:1'),
#               17579: tensor(0.9626, device='cuda:1')},
#              '15439': {26306: tensor(0.9952, device='cuda:1')},
#              '18141': {20183: tensor(0.2853, device='cuda:1'),
#               8828: tensor(0.9472, device='cuda:1'),
#               15070: tensor(0.9472, device='cuda:1'),
#               24528: tensor(0.8487, device='cuda:1'),
#               25107: tensor(0.8487, device='cuda:1'),
#               19174: tensor(0.8487, device='cuda:1')},
#              '2032': {17897: tensor(0.9925, device='cuda:1'),
#               16507: tensor(0.9982, device='cuda:1')},
#              '9711': {29787: tensor(0.9660, device='cuda:1'),
#               16223: tensor(0.9660, device='cuda:1'),
#               15694: tensor(0.9430, device='cuda:1'),
#               14190: tensor(0.9430, device='cuda:1')},
#              '484': {15171: tensor(0.9961, device='cuda:1'),
#               12533: tensor(0.9972, device='cuda:1'),
#               16223: tensor(0.9733, device='cuda:1'),
#               26306: tensor(0.9974, device='cuda:1')},
#              '13482': {12626: tensor(0.9837, device='cuda:1'),
#               25731: tensor(0.9837, device='cuda:1'),
#               20848: tensor(0.9936, device='cuda:1'),
#               1925: tensor(0.9941, device='cuda:1')},
#              '16797': {26306: tensor(0.9550, device='cuda:1'),
#               12533: tensor(0.9946, device='cuda:1'),
#               19174: tensor(0.9375, device='cuda:1'),
#               20183: tensor(0.9188, device='cuda:1'),
#               7432: tensor(0.9975, device='cuda:1'),
#               8589: tensor(0.9975, device='cuda:1'),
#               29407: tensor(0.8914, device='cuda:1')},
#              '15924': {12533: tensor(0.9919, device='cuda:1'),
#               19174: tensor(0.9986, device='cuda:1'),
#               2653: tensor(0.9981, device='cuda:1')},
#              '11607': {8589: tensor(0.9979, device='cuda:1')},
#              '14899': {19174: tensor(0.9780, device='cuda:1'),
#               25107: tensor(0.9951, device='cuda:1')},
#              '12491': {25417: tensor(0.9897, device='cuda:1'),
#               26306: tensor(0.9933, device='cuda:1'),
#               21700: tensor(0.9933, device='cuda:1'),
#               12533: tensor(0.9933, device='cuda:1'),
#               9555: tensor(0.9932, device='cuda:1'),
#               2558: tensor(0.9932, device='cuda:1'),
#               3828: tensor(0.9961, device='cuda:1'),
#               7580: tensor(0.9973, device='cuda:1')},
#              '1015': {25417: tensor(0.9859, device='cuda:1'),
#               19174: tensor(0.8734, device='cuda:1'),
#               20902: tensor(0.8734, device='cuda:1'),
#               12733: tensor(0.8070, device='cuda:1'),
#               2558: tensor(0.9759, device='cuda:1')},
#              '9810': {16223: tensor(0.9390, device='cuda:1'),
#               17897: tensor(0.9972, device='cuda:1')},
#              '6375': {25417: tensor(0.6418, device='cuda:1'),
#               20028: tensor(0.9864, device='cuda:1')},
#              '10695': {19869: tensor(0.0372, device='cuda:1'),
#               10055: tensor(0.0372, device='cuda:1'),
#               4120: tensor(0.0669, device='cuda:1'),
#               27267: tensor(0.6303, device='cuda:1'),
#               23533: tensor(0.6303, device='cuda:1'),
#               15070: tensor(0.6303, device='cuda:1'),
#               8426: tensor(0.0326, device='cuda:1'),
#               19174: tensor(0.2532, device='cuda:1')},
#              '9668': {27619: tensor(0.9971, device='cuda:1'),
#               1925: tensor(0.9899, device='cuda:1'),
#               22998: tensor(0.9899, device='cuda:1'),
#               16223: tensor(0.9961, device='cuda:1')},
#              '5091': {10856: tensor(0.9948, device='cuda:1'),
#               8828: tensor(0.9948, device='cuda:1'),
#               16223: tensor(0.9938, device='cuda:1')},
#              '19365': {28308: tensor(0.9951, device='cuda:1'),
#               25858: tensor(0.9887, device='cuda:1'),
#               8828: tensor(0.9887, device='cuda:1'),
#               16223: tensor(0.9953, device='cuda:1')},
#              '2805': {8828: tensor(0.9938, device='cuda:1'),
#               5396: tensor(0.9971, device='cuda:1'),
#               26306: tensor(0.9876, device='cuda:1'),
#               5251: tensor(0.9876, device='cuda:1'),
#               27335: tensor(0.9964, device='cuda:1'),
#               29787: tensor(0.9876, device='cuda:1')},
#              '18282': {8828: tensor(0.9986, device='cuda:1'),
#               25300: tensor(0.9987, device='cuda:1'),
#               16223: tensor(0.9986, device='cuda:1'),
#               10856: tensor(0.9986, device='cuda:1')},
#              '12469': {18320: tensor(0.9655, device='cuda:1')},
#              '4745': {25992: tensor(0.9880, device='cuda:1'),
#               5505: tensor(0.9852, device='cuda:1'),
#               5332: tensor(0.9880, device='cuda:1'),
#               16223: tensor(0.9543, device='cuda:1')},
#              '7356': {21083: tensor(0.7106, device='cuda:1'),
#               5894: tensor(0.9277, device='cuda:1'),
#               3828: tensor(0.8462, device='cuda:1')},
#              '12837': {8828: tensor(0.9963, device='cuda:1'),
#               26306: tensor(0.9962, device='cuda:1'),
#               15171: tensor(0.9962, device='cuda:1'),
#               18917: tensor(0.9980, device='cuda:1'),
#               13157: tensor(0.9980, device='cuda:1'),
#               19174: tensor(0.9980, device='cuda:1')},
#              '16252': {2115: tensor(0.9975, device='cuda:1'),
#               19174: tensor(0.9960, device='cuda:1'),
#               18874: tensor(0.9884, device='cuda:1'),
#               28551: tensor(0.9884, device='cuda:1')},
#              '3827': {24794: tensor(0.9982, device='cuda:1'),
#               28621: tensor(0.9977, device='cuda:1'),
#               22998: tensor(0.9977, device='cuda:1')},
#              '12857': {19174: tensor(0.9975, device='cuda:1'),
#               25417: tensor(0.9977, device='cuda:1')},
#              '1357': {19018: tensor(0.9978, device='cuda:1'),
#               12533: tensor(0.9978, device='cuda:1'),
#               25858: tensor(0.9691, device='cuda:1'),
#               21238: tensor(0.9929, device='cuda:1'),
#               16223: tensor(0.9929, device='cuda:1')},
#              '12015': {26306: tensor(0.9974, device='cuda:1'),
#               1925: tensor(0.9980, device='cuda:1'),
#               16223: tensor(0.9860, device='cuda:1'),
#               19174: tensor(0.9980, device='cuda:1'),
#               29787: tensor(0.9974, device='cuda:1')},
#              '6048': {30546: tensor(0.9960, device='cuda:1'),
#               5251: tensor(0.9870, device='cuda:1'),
#               19018: tensor(0.9960, device='cuda:1'),
#               26306: tensor(0.9658, device='cuda:1'),
#               10856: tensor(0.9870, device='cuda:1')},
#              '18408': {16223: tensor(0.9979, device='cuda:1')},
#              '18451': {16223: tensor(0.9985, device='cuda:1'),
#               25107: tensor(0.9950, device='cuda:1'),
#               937: tensor(0.9962, device='cuda:1'),
#               24924: tensor(0.9962, device='cuda:1'),
#               19174: tensor(0.9974, device='cuda:1')},
#              '19309': {29688: tensor(0.9924, device='cuda:1'),
#               20183: tensor(0.9950, device='cuda:1')},
#              '10091': {3369: tensor(0.9716, device='cuda:1'),
#               20009: tensor(0.9920, device='cuda:1'),
#               22579: tensor(0.9920, device='cuda:1'),
#               5315: tensor(0.9920, device='cuda:1'),
#               8295: tensor(0.3738, device='cuda:1'),
#               19174: tensor(0.8717, device='cuda:1'),
#               7822: tensor(0.9023, device='cuda:1')},
#              '8943': {19174: tensor(0.9945, device='cuda:1'),
#               25417: tensor(0.9930, device='cuda:1'),
#               7862: tensor(0.9810, device='cuda:1'),
#               3828: tensor(0.9930, device='cuda:1')},
#              '16241': {26306: tensor(0.9950, device='cuda:1'),
#               16223: tensor(0.9960, device='cuda:1'),
#               3682: tensor(0.9960, device='cuda:1'),
#               2115: tensor(0.9960, device='cuda:1')},
#              '18806': {19174: tensor(0.9824, device='cuda:1')},
#              '13523': {29787: tensor(0.9825, device='cuda:1'),
#               5251: tensor(0.9825, device='cuda:1'),
#               17897: tensor(0.9927, device='cuda:1'),
#               8828: tensor(0.9967, device='cuda:1')},
#              '18122': {27619: tensor(0.9789, device='cuda:1'),
#               6837: tensor(0.9917, device='cuda:1'),
#               15324: tensor(0.9967, device='cuda:1'),
#               16223: tensor(0.9868, device='cuda:1')},
#              '8917': {10856: tensor(0.9698, device='cuda:1'),
#               24180: tensor(0.9895, device='cuda:1'),
#               21700: tensor(0.9906, device='cuda:1'),
#               3828: tensor(0.9906, device='cuda:1')},
#              '633': {12533: tensor(0.9945, device='cuda:1'),
#               1925: tensor(0.9945, device='cuda:1'),
#               30546: tensor(0.9425, device='cuda:1'),
#               19018: tensor(0.9425, device='cuda:1'),
#               28089: tensor(0.9902, device='cuda:1'),
#               16223: tensor(0.9902, device='cuda:1')},
#              '17028': {7491: tensor(0.9984, device='cuda:1'),
#               5894: tensor(0.9986, device='cuda:1'),
#               383: tensor(0.9986, device='cuda:1'),
#               8589: tensor(0.9984, device='cuda:1'),
#               3828: tensor(0.9987, device='cuda:1')},
#              '17614': {12533: tensor(0.9930, device='cuda:1'),
#               20183: tensor(0.9945, device='cuda:1'),
#               19174: tensor(0.9941, device='cuda:1'),
#               25155: tensor(0.9945, device='cuda:1')},
#              '9451': {3828: tensor(0.9963, device='cuda:1'),
#               11866: tensor(0.9970, device='cuda:1'),
#               15839: tensor(0.9970, device='cuda:1')},
#              '3186': {17897: tensor(0.9967, device='cuda:1'),
#               26244: tensor(0.9967, device='cuda:1'),
#               16223: tensor(0.9980, device='cuda:1')},
#              '8777': {24180: tensor(0.9532, device='cuda:1'),
#               19174: tensor(0.9759, device='cuda:1'),
#               1865: tensor(0.9966, device='cuda:1'),
#               3828: tensor(0.3620, device='cuda:1'),
#               25895: tensor(0.9532, device='cuda:1')},
#              '14562': {16223: tensor(0.9982, device='cuda:1'),
#               24790: tensor(0.9979, device='cuda:1'),
#               13835: tensor(0.9979, device='cuda:1'),
#               24924: tensor(0.9979, device='cuda:1')},
#              '10546': {19174: tensor(0.9970, device='cuda:1'),
#               26306: tensor(0.9977, device='cuda:1'),
#               11611: tensor(0.9977, device='cuda:1'),
#               15091: tensor(0.9977, device='cuda:1'),
#               3369: tensor(0.9970, device='cuda:1'),
#               16730: tensor(0.9970, device='cuda:1'),
#               16223: tensor(0.9983, device='cuda:1')},
#              '3891': {29787: tensor(0.9865, device='cuda:1'),
#               26306: tensor(0.9954, device='cuda:1'),
#               19174: tensor(0.9974, device='cuda:1'),
#               21301: tensor(0.9908, device='cuda:1'),
#               21238: tensor(0.9908, device='cuda:1'),
#               2115: tensor(0.9981, device='cuda:1'),
#               10712: tensor(0.9981, device='cuda:1'),
#               3682: tensor(0.9865, device='cuda:1'),
#               12533: tensor(0.8981, device='cuda:1'),
#               2558: tensor(0.8981, device='cuda:1')},
#              '1014': {14782: tensor(0.9938, device='cuda:1'),
#               24088: tensor(0.9910, device='cuda:1'),
#               10792: tensor(0.9910, device='cuda:1'),
#               3453: tensor(0.9910, device='cuda:1'),
#               3682: tensor(0.9910, device='cuda:1'),
#               30546: tensor(0.9897, device='cuda:1'),
#               23903: tensor(0.9897, device='cuda:1'),
#               27852: tensor(0.9953, device='cuda:1')},
#              '19671': {16223: tensor(0.9952, device='cuda:1')},
#              '17058': {16785: tensor(0.4317, device='cuda:1'),
#               25417: tensor(0.7832, device='cuda:1')},
#              '10508': {16223: tensor(0.9868, device='cuda:1'),
#               19174: tensor(0.9975, device='cuda:1')},
#              '10110': {14359: tensor(0.9971, device='cuda:1'),
#               23020: tensor(0.9975, device='cuda:1'),
#               11406: tensor(0.9979, device='cuda:1')},
#              '14626': {2115: tensor(0.9989, device='cuda:1'),
#               13617: tensor(0.9977, device='cuda:1'),
#               26306: tensor(0.9980, device='cuda:1'),
#               5251: tensor(0.9980, device='cuda:1'),
#               3828: tensor(0.9980, device='cuda:1')},
#              '583': {7952: tensor(0.9817, device='cuda:1'),
#               27820: tensor(0.9934, device='cuda:1'),
#               16632: tensor(0.9752, device='cuda:1'),
#               17897: tensor(0.9900, device='cuda:1'),
#               21700: tensor(0.9752, device='cuda:1'),
#               1925: tensor(0.9752, device='cuda:1')},
#              '14489': {8828: tensor(0.9952, device='cuda:1'),
#               12533: tensor(0.9905, device='cuda:1')},
#              '5810': {27698: tensor(0.9978, device='cuda:1')},
#              '1979': {3682: tensor(0.9988, device='cuda:1'),
#               16785: tensor(0.9973, device='cuda:1'),
#               26306: tensor(0.9970, device='cuda:1'),
#               3369: tensor(0.9970, device='cuda:1'),
#               4880: tensor(0.9969, device='cuda:1')},
#              '8279': {248: tensor(0.9888, device='cuda:1'),
#               3682: tensor(0.9968, device='cuda:1'),
#               27651: tensor(0.9975, device='cuda:1')},
#              '6176': {12533: tensor(0.9097, device='cuda:1'),
#               26306: tensor(0.9983, device='cuda:1')},
#              '7720': {18112: tensor(0.9575, device='cuda:1'),
#               20183: tensor(0.9979, device='cuda:1'),
#               17857: tensor(0.9415, device='cuda:1')},
#              '9990': {24528: tensor(0.9926, device='cuda:1'),
#               3369: tensor(0.9758, device='cuda:1'),
#               1925: tensor(0.4597, device='cuda:1'),
#               20183: tensor(0.9809, device='cuda:1')},
#              '16013': {9124: tensor(0.9979, device='cuda:1'),
#               1865: tensor(0.9982, device='cuda:1'),
#               3682: tensor(0.9982, device='cuda:1'),
#               26306: tensor(0.9985, device='cuda:1'),
#               5251: tensor(0.9978, device='cuda:1')},
#              '17795': {5244: tensor(0.9441, device='cuda:1'),
#               9258: tensor(0.9872, device='cuda:1'),
#               3369: tensor(0.9356, device='cuda:1'),
#               16223: tensor(0.9827, device='cuda:1')},
#              '2892': {16223: tensor(0.9945, device='cuda:1'),
#               19174: tensor(0.9922, device='cuda:1'),
#               20183: tensor(0.9922, device='cuda:1')},
#              '11415': {19174: tensor(0.9981, device='cuda:1'),
#               20496: tensor(0.9944, device='cuda:1'),
#               21617: tensor(0.9918, device='cuda:1'),
#               5332: tensor(0.9916, device='cuda:1'),
#               12795: tensor(0.9916, device='cuda:1'),
#               2358: tensor(0.9916, device='cuda:1'),
#               2537: tensor(0.9981, device='cuda:1'),
#               3369: tensor(0.9984, device='cuda:1')},
#              '14541': {16785: tensor(0.6925, device='cuda:1'),
#               1865: tensor(0.5763, device='cuda:1'),
#               25417: tensor(0.9325, device='cuda:1'),
#               26306: tensor(0.1032, device='cuda:1')},
#              '6163': {16223: tensor(0.9684, device='cuda:1')},
#              '11265': {26306: tensor(0.9982, device='cuda:1'),
#               5549: tensor(0.9986, device='cuda:1')},
#              '5780': {26306: tensor(0.9985, device='cuda:1'),
#               24924: tensor(0.9905, device='cuda:1')},
#              '14020': {7952: tensor(0.6991, device='cuda:1'),
#               19174: tensor(0.6991, device='cuda:1'),
#               21083: tensor(0.9145, device='cuda:1'),
#               5332: tensor(0.9145, device='cuda:1'),
#               27213: tensor(0.9145, device='cuda:1')},
#              '7711': {25417: tensor(0.9985, device='cuda:1'),
#               26306: tensor(0.9728, device='cuda:1')},
#              '5023': {16223: tensor(0.7006, device='cuda:1'),
#               25858: tensor(0.9868, device='cuda:1'),
#               19018: tensor(0.9868, device='cuda:1')},
#              '15108': {8828: tensor(0.9726, device='cuda:1')},
#              '18694': {10856: tensor(0.9986, device='cuda:1'),
#               12533: tensor(0.9925, device='cuda:1'),
#               19174: tensor(0.9954, device='cuda:1')},
#              '10716': {3067: tensor(0.9971, device='cuda:1'),
#               3570: tensor(0.9976, device='cuda:1'),
#               12533: tensor(0.9976, device='cuda:1')},
#              '18366': {20183: tensor(0.9910, device='cuda:1'),
#               25417: tensor(0.9862, device='cuda:1'),
#               29425: tensor(0.9951, device='cuda:1')},
#              '10514': {15264: tensor(0.6616, device='cuda:1'),
#               19174: tensor(0.9929, device='cuda:1')},
#              '13469': {12533: tensor(0.9929, device='cuda:1'),
#               26306: tensor(0.9876, device='cuda:1'),
#               265: tensor(0.9024, device='cuda:1')},
#              '19122': {17800: tensor(0.9870, device='cuda:1'),
#               3438: tensor(0.9870, device='cuda:1'),
#               27698: tensor(0.9975, device='cuda:1'),
#               12205: tensor(0.9296, device='cuda:1'),
#               26306: tensor(0.9807, device='cuda:1'),
#               21083: tensor(0.9766, device='cuda:1'),
#               20028: tensor(0.9766, device='cuda:1')},
#              '411': {26306: tensor(0.9735, device='cuda:1'),
#               12533: tensor(0.9822, device='cuda:1')},
#              '2381': {21083: tensor(0.9980, device='cuda:1'),
#               29425: tensor(0.9986, device='cuda:1'),
#               9083: tensor(0.9986, device='cuda:1')},
#              '18626': {20028: tensor(0.9985, device='cuda:1'),
#               12533: tensor(0.9977, device='cuda:1'),
#               19174: tensor(0.9978, device='cuda:1'),
#               1925: tensor(0.9848, device='cuda:1'),
#               12205: tensor(0.9951, device='cuda:1')},
#              '16099': {8828: tensor(0.9895, device='cuda:1'),
#               3682: tensor(0.9970, device='cuda:1'),
#               18874: tensor(0.9950, device='cuda:1'),
#               2115: tensor(0.9950, device='cuda:1')},
#              '2269': {5505: tensor(0.9918, device='cuda:1'),
#               16223: tensor(0.9926, device='cuda:1'),
#               18874: tensor(0.6989, device='cuda:1'),
#               21150: tensor(0.6989, device='cuda:1')},
#              '19444': {17897: tensor(0.9631, device='cuda:1'),
#               26306: tensor(0.9558, device='cuda:1'),
#               20028: tensor(0.9631, device='cuda:1')},
#              '2652': {11240: tensor(0.9947, device='cuda:1'),
#               16620: tensor(0.9953, device='cuda:1'),
#               4265: tensor(0.8282, device='cuda:1')},
#              '9886': {20496: tensor(0.9949, device='cuda:1'),
#               26306: tensor(0.9951, device='cuda:1'),
#               25417: tensor(0.9958, device='cuda:1'),
#               20183: tensor(0.9958, device='cuda:1')},
#              '8071': {25417: tensor(0.9982, device='cuda:1'),
#               7822: tensor(0.9975, device='cuda:1'),
#               24151: tensor(0.9975, device='cuda:1')},
#              '4787': {27619: tensor(0.9931, device='cuda:1'),
#               3682: tensor(0.9951, device='cuda:1'),
#               2460: tensor(0.9955, device='cuda:1'),
#               5332: tensor(0.9895, device='cuda:1'),
#               19205: tensor(0.9932, device='cuda:1'),
#               21142: tensor(0.9895, device='cuda:1'),
#               15264: tensor(0.9932, device='cuda:1'),
#               29407: tensor(0.9932, device='cuda:1'),
#               29703: tensor(0.9932, device='cuda:1')},
#              '3638': {3682: tensor(0.9933, device='cuda:1'),
#               16223: tensor(0.9933, device='cuda:1'),
#               29310: tensor(0.9930, device='cuda:1')},
#              '12384': {8396: tensor(0.9899, device='cuda:1'),
#               18093: tensor(0.9899, device='cuda:1'),
#               27032: tensor(0.9921, device='cuda:1'),
#               13586: tensor(0.9921, device='cuda:1'),
#               26306: tensor(0.9912, device='cuda:1')},
#              '11250': {15264: tensor(0.9894, device='cuda:1'),
#               26306: tensor(0.9244, device='cuda:1'),
#               3724: tensor(0.9894, device='cuda:1'),
#               8050: tensor(0.9894, device='cuda:1'),
#               29407: tensor(0.9894, device='cuda:1'),
#               14135: tensor(0.9870, device='cuda:1'),
#               12290: tensor(0.9854, device='cuda:1')},
#              '14758': {26306: tensor(0.9983, device='cuda:1')},
#              '7943': {14081: tensor(0.9873, device='cuda:1'),
#               26306: tensor(0.9929, device='cuda:1')},
#              '19201': {20066: tensor(0.9967, device='cuda:1'),
#               16223: tensor(0.9967, device='cuda:1'),
#               25417: tensor(0.5204, device='cuda:1'),
#               6902: tensor(0.9967, device='cuda:1')},
#              '18130': {12533: tensor(0.9988, device='cuda:1'),
#               28149: tensor(0.9945, device='cuda:1')},
#              '12805': {7491: tensor(0.9986, device='cuda:1'),
#               2115: tensor(0.9297, device='cuda:1')},
#              '14835': {7952: tensor(0.9213, device='cuda:1'),
#               17897: tensor(0.6361, device='cuda:1'),
#               22254: tensor(0.5229, device='cuda:1'),
#               25417: tensor(0.6361, device='cuda:1')},
#              '11372': {24924: tensor(0.9794, device='cuda:1'),
#               12533: tensor(0.9959, device='cuda:1'),
#               21083: tensor(0.9840, device='cuda:1'),
#               16223: tensor(0.9605, device='cuda:1'),
#               19174: tensor(0.9883, device='cuda:1'),
#               14214: tensor(0.9913, device='cuda:1')},
#              '1636': {16223: tensor(0.9980, device='cuda:1'),
#               11864: tensor(0.9983, device='cuda:1')},
#              '7189': {16223: tensor(0.9952, device='cuda:1'),
#               3496: tensor(0.9928, device='cuda:1'),
#               5332: tensor(0.9928, device='cuda:1')},
#              '10571': {2558: tensor(0.9664, device='cuda:1'),
#               25417: tensor(0.9979, device='cuda:1'),
#               26306: tensor(0.9967, device='cuda:1')},
#              '8416': {25417: tensor(0.7175, device='cuda:1'),
#               25107: tensor(0.9838, device='cuda:1'),
#               28551: tensor(0.9838, device='cuda:1')},
#              '5146': {26306: tensor(0.9979, device='cuda:1'),
#               3682: tensor(0.9964, device='cuda:1'),
#               25858: tensor(0.9968, device='cuda:1')},
#              '4583': {26306: tensor(0.9583, device='cuda:1'),
#               19174: tensor(0.9982, device='cuda:1')},
#              '2877': {12533: tensor(0.9955, device='cuda:1'),
#               24794: tensor(0.9914, device='cuda:1'),
#               16223: tensor(0.9979, device='cuda:1'),
#               25858: tensor(0.9940, device='cuda:1')},
#              '9011': {17985: tensor(0.9964, device='cuda:1'),
#               20183: tensor(0.9964, device='cuda:1'),
#               3682: tensor(0.9986, device='cuda:1')},
#              '14945': {7822: tensor(0.9957, device='cuda:1'),
#               26306: tensor(0.9962, device='cuda:1'),
#               2355: tensor(0.9596, device='cuda:1'),
#               3682: tensor(0.9702, device='cuda:1'),
#               16223: tensor(0.9702, device='cuda:1'),
#               8509: tensor(0.9877, device='cuda:1')},
#              '10860': {26306: tensor(0.9987, device='cuda:1'),
#               3682: tensor(0.9898, device='cuda:1')},
#              '8135': {12533: tensor(0.9988, device='cuda:1'),
#               19174: tensor(0.9987, device='cuda:1')},
#              '13132': {10856: tensor(0.9950, device='cuda:1'),
#               14659: tensor(0.9970, device='cuda:1'),
#               12710: tensor(0.9973, device='cuda:1'),
#               19018: tensor(0.9973, device='cuda:1'),
#               16223: tensor(0.9971, device='cuda:1')},
#              '16866': {19174: tensor(0.3396, device='cuda:1'),
#               8594: tensor(0.7945, device='cuda:1'),
#               26306: tensor(0.9943, device='cuda:1')},
#              '15075': {26306: tensor(0.9984, device='cuda:1'),
#               2115: tensor(0.9984, device='cuda:1'),
#               13991: tensor(0.9983, device='cuda:1')},
#              '14484': {26893: tensor(0.9934, device='cuda:1'),
#               19174: tensor(0.9959, device='cuda:1'),
#               16223: tensor(0.9959, device='cuda:1'),
#               25417: tensor(0.9985, device='cuda:1')},
#              '14746': {28149: tensor(0.9987, device='cuda:1'),
#               17897: tensor(0.9981, device='cuda:1'),
#               27698: tensor(0.9988, device='cuda:1')},
#              '2226': {26306: tensor(0.9848, device='cuda:1'),
#               25417: tensor(0.9976, device='cuda:1'),
#               25107: tensor(0.9976, device='cuda:1'),
#               2558: tensor(0.9976, device='cuda:1')},
#              '16045': {8386: tensor(0.9967, device='cuda:1'),
#               1925: tensor(0.9967, device='cuda:1'),
#               20066: tensor(0.9981, device='cuda:1')},
#              '14866': {25858: tensor(0.9896, device='cuda:1'),
#               26306: tensor(0.9980, device='cuda:1'),
#               16223: tensor(0.9843, device='cuda:1'),
#               19174: tensor(0.9811, device='cuda:1')},
#              '17577': {19174: tensor(0.9829, device='cuda:1'),
#               15474: tensor(0.9382, device='cuda:1'),
#               16223: tensor(0.9312, device='cuda:1'),
#               10856: tensor(0.9896, device='cuda:1')},
#              '18656': {15264: tensor(0.9934, device='cuda:1'),
#               3682: tensor(0.9983, device='cuda:1'),
#               1925: tensor(0.9947, device='cuda:1')},
#              '6842': {20183: tensor(0.9972, device='cuda:1'),
#               3682: tensor(0.9473, device='cuda:1')},
# ...
#               16223: tensor(0.9982, device='cuda:1'),
#               19174: tensor(0.9982, device='cuda:1')},
#              '18179': {16223: tensor(0.9959, device='cuda:1'),
#               27619: tensor(0.9538, device='cuda:1'),
#               1925: tensor(0.9402, device='cuda:1')},
#              '18281': {16223: tensor(0.9972, device='cuda:1'),
#               20183: tensor(0.9970, device='cuda:1')},
#              '9043': {26306: tensor(0.9897, device='cuda:1'),
#               5251: tensor(0.9897, device='cuda:1'),
#               21083: tensor(0.9983, device='cuda:1'),
#               20028: tensor(0.9955, device='cuda:1')},
#              '12490': {25417: tensor(0.9942, device='cuda:1'),
#               26306: tensor(0.9942, device='cuda:1'),
#               2558: tensor(0.9912, device='cuda:1'),
#               16730: tensor(0.9912, device='cuda:1'),
#               20028: tensor(0.9912, device='cuda:1'),
#               16223: tensor(0.9912, device='cuda:1'),
#               16785: tensor(0.9900, device='cuda:1'),
#               10454: tensor(0.9900, device='cuda:1')},
#              '5899': {26306: tensor(0.9924, device='cuda:1'),
#               12533: tensor(0.9971, device='cuda:1'),
#               19174: tensor(0.9938, device='cuda:1')},
#              '9482': {3067: tensor(0.9977, device='cuda:1'),
#               20183: tensor(0.9975, device='cuda:1')},
#              '3957': {12570: tensor(0.9764, device='cuda:1')},
#              '3990': {23492: tensor(0.9850, device='cuda:1'),
#               3496: tensor(0.8697, device='cuda:1'),
#               25190: tensor(0.9960, device='cuda:1'),
#               12533: tensor(0.9728, device='cuda:1'),
#               25126: tensor(0.6489, device='cuda:1')},
#              '5427': {19174: tensor(0.9985, device='cuda:1'),
#               12533: tensor(0.8174, device='cuda:1'),
#               26306: tensor(0.9986, device='cuda:1'),
#               7822: tensor(0.9986, device='cuda:1'),
#               16506: tensor(0.9976, device='cuda:1')},
#              '18576': {12533: tensor(0.9968, device='cuda:1'),
#               8589: tensor(0.9984, device='cuda:1'),
#               19174: tensor(0.9986, device='cuda:1')},
#              '3220': {3369: tensor(0.9970, device='cuda:1'),
#               16223: tensor(0.9982, device='cuda:1'),
#               11265: tensor(0.9974, device='cuda:1'),
#               11949: tensor(0.9974, device='cuda:1'),
#               19018: tensor(0.9972, device='cuda:1')},
#              '9661': {29425: tensor(0.9631, device='cuda:1'),
#               28058: tensor(0.8015, device='cuda:1'),
#               13332: tensor(0.8015, device='cuda:1'),
#               12533: tensor(0.9978, device='cuda:1'),
#               23802: tensor(0.8996, device='cuda:1'),
#               5894: tensor(0.8996, device='cuda:1'),
#               3994: tensor(0.8996, device='cuda:1')},
#              '4511': {3682: tensor(0.9442, device='cuda:1'),
#               15474: tensor(0.9969, device='cuda:1')},
#              '799': {11240: tensor(0.9987, device='cuda:1'),
#               13819: tensor(0.9987, device='cuda:1'),
#               3606: tensor(0.9987, device='cuda:1'),
#               25417: tensor(0.9962, device='cuda:1'),
#               3812: tensor(0.9962, device='cuda:1'),
#               3369: tensor(0.9962, device='cuda:1')},
#              '16718': {265: tensor(0.9162, device='cuda:1'),
#               3828: tensor(0.9725, device='cuda:1'),
#               12533: tensor(0.3133, device='cuda:1'),
#               16223: tensor(0.3618, device='cuda:1'),
#               28551: tensor(0.4904, device='cuda:1')},
#              '13709': {3682: tensor(0.9928, device='cuda:1'),
#               12533: tensor(0.9547, device='cuda:1')},
#              '3131': {8594: tensor(0.9971, device='cuda:1'),
#               16223: tensor(0.9569, device='cuda:1'),
#               19174: tensor(0.9490, device='cuda:1'),
#               21325: tensor(0.9971, device='cuda:1'),
#               1717: tensor(0.9971, device='cuda:1')},
#              '5589': {1865: tensor(0.9760, device='cuda:1'),
#               25858: tensor(0.9946, device='cuda:1'),
#               3828: tensor(0.2255, device='cuda:1'),
#               13573: tensor(0.9889, device='cuda:1')},
#              '18275': {26306: tensor(0.9975, device='cuda:1')},
#              '6983': {26306: tensor(0.9981, device='cuda:1'),
#               20028: tensor(0.9981, device='cuda:1'),
#               16223: tensor(0.9964, device='cuda:1'),
#               12246: tensor(0.9988, device='cuda:1')},
#              '3595': {4089: tensor(0.9824, device='cuda:1'),
#               3682: tensor(0.9728, device='cuda:1'),
#               26306: tensor(0.9384, device='cuda:1'),
#               3369: tensor(0.8436, device='cuda:1'),
#               28687: tensor(0.8403, device='cuda:1')},
#              '3090': {15413: tensor(0.9973, device='cuda:1'),
#               19018: tensor(0.9975, device='cuda:1'),
#               12533: tensor(0.9975, device='cuda:1')},
#              '5875': {7952: tensor(0.9985, device='cuda:1'),
#               1925: tensor(0.9985, device='cuda:1'),
#               22254: tensor(0.9987, device='cuda:1'),
#               16983: tensor(0.9987, device='cuda:1'),
#               13332: tensor(0.9988, device='cuda:1')},
#              '7798': {21325: tensor(0.7240, device='cuda:1')},
#              '8447': {16223: tensor(0.9984, device='cuda:1')},
#              '6719': {29052: tensor(0.9834, device='cuda:1'),
#               9980: tensor(0.9834, device='cuda:1'),
#               27598: tensor(0.9834, device='cuda:1'),
#               18727: tensor(0.9834, device='cuda:1'),
#               27714: tensor(0.9976, device='cuda:1'),
#               29787: tensor(0.9976, device='cuda:1'),
#               13966: tensor(0.9983, device='cuda:1'),
#               10856: tensor(0.9988, device='cuda:1'),
#               3812: tensor(0.9988, device='cuda:1'),
#               4089: tensor(0.9175, device='cuda:1'),
#               21083: tensor(0.9175, device='cuda:1'),
#               9855: tensor(0.9830, device='cuda:1'),
#               28359: tensor(0.9830, device='cuda:1')},
#              '2322': {16507: tensor(0.9982, device='cuda:1'),
#               19174: tensor(0.9982, device='cuda:1'),
#               2115: tensor(0.9984, device='cuda:1')},
#              '18675': {16223: tensor(0.9986, device='cuda:1'),
#               8828: tensor(0.9986, device='cuda:1'),
#               12533: tensor(0.9986, device='cuda:1')},
#              '13715': {25417: tensor(0.9822, device='cuda:1'),
#               16223: tensor(0.9860, device='cuda:1'),
#               1925: tensor(0.9810, device='cuda:1'),
#               20192: tensor(0.9860, device='cuda:1')},
#              '8062': {28551: tensor(0.6578, device='cuda:1'),
#               19174: tensor(0.8511, device='cuda:1'),
#               16735: tensor(0.8511, device='cuda:1'),
#               16223: tensor(0.8511, device='cuda:1')},
#              '12468': {21122: tensor(0.9730, device='cuda:1'),
#               1925: tensor(0.9730, device='cuda:1'),
#               8828: tensor(0.9744, device='cuda:1'),
#               13835: tensor(0.6197, device='cuda:1')},
#              '9887': {16223: tensor(0.9989, device='cuda:1'),
#               22333: tensor(0.9985, device='cuda:1')},
#              '2234': {16785: tensor(0.9746, device='cuda:1'),
#               5251: tensor(0.9850, device='cuda:1'),
#               25417: tensor(0.9990, device='cuda:1'),
#               19174: tensor(0.9990, device='cuda:1'),
#               16223: tensor(0.9990, device='cuda:1')},
#              '6695': {3828: tensor(0.5634, device='cuda:1'),
#               17897: tensor(0.5634, device='cuda:1'),
#               21083: tensor(0.5634, device='cuda:1'),
#               5251: tensor(0.5634, device='cuda:1')},
#              '17251': {26306: tensor(0.9966, device='cuda:1'),
#               8589: tensor(0.9966, device='cuda:1'),
#               8093: tensor(0.9976, device='cuda:1'),
#               5332: tensor(0.9966, device='cuda:1')},
#              '11916': {3369: tensor(0.9950, device='cuda:1'),
#               23148: tensor(0.9950, device='cuda:1'),
#               8078: tensor(0.9950, device='cuda:1'),
#               1925: tensor(0.9962, device='cuda:1'),
#               25417: tensor(0.9948, device='cuda:1'),
#               19174: tensor(0.9948, device='cuda:1')},
#              '5549': {17897: tensor(0.9988, device='cuda:1'),
#               7952: tensor(0.9905, device='cuda:1')},
#              '18423': {29032: tensor(0.9755, device='cuda:1'),
#               26306: tensor(0.9755, device='cuda:1'),
#               24386: tensor(0.9967, device='cuda:1'),
#               26971: tensor(0.9967, device='cuda:1'),
#               15873: tensor(0.9972, device='cuda:1'),
#               19174: tensor(0.9972, device='cuda:1')},
#              '19584': {1925: tensor(0.9975, device='cuda:1'),
#               26306: tensor(0.9981, device='cuda:1'),
#               14135: tensor(0.9981, device='cuda:1')},
#              '11778': {6048: tensor(0.9870, device='cuda:1'),
#               26306: tensor(0.9870, device='cuda:1'),
#               16620: tensor(0.9029, device='cuda:1'),
#               9083: tensor(0.9824, device='cuda:1'),
#               20183: tensor(0.8578, device='cuda:1')},
#              '15433': {26306: tensor(0.9969, device='cuda:1'),
#               3812: tensor(0.9986, device='cuda:1')},
#              '7205': {20066: tensor(0.9952, device='cuda:1'),
#               19174: tensor(0.9960, device='cuda:1')},
#              '6660': {8589: tensor(0.9751, device='cuda:1'),
#               7952: tensor(0.9910, device='cuda:1'),
#               5234: tensor(0.9848, device='cuda:1')},
#              '10808': {26306: tensor(0.9485, device='cuda:1'),
#               25551: tensor(0.9709, device='cuda:1'),
#               13617: tensor(0.9979, device='cuda:1'),
#               3828: tensor(0.9979, device='cuda:1'),
#               18874: tensor(0.9967, device='cuda:1'),
#               14081: tensor(0.9967, device='cuda:1'),
#               1615: tensor(0.9404, device='cuda:1')},
#              '18367': {12533: tensor(0.9944, device='cuda:1'),
#               16223: tensor(0.9974, device='cuda:1'),
#               29787: tensor(0.9936, device='cuda:1')},
#              '6859': {21083: tensor(0.9779, device='cuda:1'),
#               25417: tensor(0.9144, device='cuda:1'),
#               20183: tensor(0.9144, device='cuda:1')},
#              '9351': {26306: tensor(0.8714, device='cuda:1'),
#               5332: tensor(0.8714, device='cuda:1'),
#               10663: tensor(0.9606, device='cuda:1'),
#               1925: tensor(0.8451, device='cuda:1'),
#               29332: tensor(0.9566, device='cuda:1'),
#               17837: tensor(0.9566, device='cuda:1')},
#              '17203': {25858: tensor(0.0739, device='cuda:1'),
#               14312: tensor(0.3898, device='cuda:1'),
#               1865: tensor(0.3898, device='cuda:1'),
#               21301: tensor(0.3898, device='cuda:1'),
#               19174: tensor(0.3898, device='cuda:1'),
#               15264: tensor(0.0780, device='cuda:1'),
#               20816: tensor(0.0437, device='cuda:1'),
#               5505: tensor(0.0261, device='cuda:1'),
#               20066: tensor(0.0286, device='cuda:1'),
#               2115: tensor(0.4744, device='cuda:1')},
#              '7082': {26306: tensor(0.2220, device='cuda:1'),
#               15083: tensor(0.2220, device='cuda:1'),
#               11834: tensor(0.2220, device='cuda:1'),
#               17579: tensor(0.2238, device='cuda:1')},
#              '1279': {6902: tensor(0.9963, device='cuda:1'),
#               3682: tensor(0.9989, device='cuda:1'),
#               20183: tensor(0.9963, device='cuda:1'),
#               7226: tensor(0.9963, device='cuda:1')},
#              '9566': {16632: tensor(0.9348, device='cuda:1'),
#               24180: tensor(0.9678, device='cuda:1'),
#               19174: tensor(0.9234, device='cuda:1'),
#               4650: tensor(0.9799, device='cuda:1'),
#               20028: tensor(0.9799, device='cuda:1')},
#              '3947': {7952: tensor(0.9984, device='cuda:1'),
#               17897: tensor(0.8282, device='cuda:1')},
#              '18113': {16223: tensor(0.9638, device='cuda:1'),
#               26306: tensor(0.9911, device='cuda:1'),
#               15091: tensor(0.9911, device='cuda:1'),
#               20028: tensor(0.9911, device='cuda:1'),
#               1925: tensor(0.9911, device='cuda:1')},
#              '586': {9561: tensor(0.9970, device='cuda:1'),
#               17579: tensor(0.9970, device='cuda:1'),
#               7217: tensor(0.9970, device='cuda:1'),
#               26306: tensor(0.9814, device='cuda:1'),
#               19174: tensor(0.9957, device='cuda:1'),
#               9388: tensor(0.9718, device='cuda:1'),
#               3369: tensor(0.9180, device='cuda:1')},
#              '6439': {19174: tensor(0.9980, device='cuda:1'),
#               3369: tensor(0.9984, device='cuda:1'),
#               10856: tensor(0.9979, device='cuda:1'),
#               24180: tensor(0.9979, device='cuda:1')},
#              '14355': {26306: tensor(0.9919, device='cuda:1'),
#               10856: tensor(0.9732, device='cuda:1')},
#              '2331': {6138: tensor(0.9968, device='cuda:1'),
#               17340: tensor(0.9968, device='cuda:1'),
#               16223: tensor(0.9987, device='cuda:1'),
#               607: tensor(0.9983, device='cuda:1'),
#               19174: tensor(0.9966, device='cuda:1')},
#              '6425': {29425: tensor(0.9985, device='cuda:1')},
#              '7635': {26306: tensor(0.9986, device='cuda:1'),
#               19174: tensor(0.9983, device='cuda:1'),
#               25107: tensor(0.9981, device='cuda:1'),
#               27708: tensor(0.9986, device='cuda:1')},
#              '11360': {19174: tensor(0.9972, device='cuda:1'),
#               9442: tensor(0.9851, device='cuda:1'),
#               16515: tensor(0.9851, device='cuda:1')},
#              '13957': {12533: tensor(0.9974, device='cuda:1'),
#               19174: tensor(0.9979, device='cuda:1')},
#              '12840': {1865: tensor(0.8605, device='cuda:1'),
#               16223: tensor(0.9911, device='cuda:1')},
#              '15443': {10856: tensor(0.9949, device='cuda:1'),
#               5251: tensor(0.9970, device='cuda:1'),
#               1925: tensor(0.9949, device='cuda:1'),
#               28551: tensor(0.9970, device='cuda:1'),
#               26306: tensor(0.9958, device='cuda:1'),
#               3067: tensor(0.9962, device='cuda:1'),
#               26660: tensor(0.9962, device='cuda:1'),
#               9786: tensor(0.9971, device='cuda:1'),
#               3828: tensor(0.9970, device='cuda:1'),
#               24533: tensor(0.9970, device='cuda:1')},
#              '16910': {19174: tensor(0.9851, device='cuda:1'),
#               2115: tensor(0.7198, device='cuda:1'),
#               7862: tensor(0.9852, device='cuda:1')},
#              '5759': {16223: tensor(0.9640, device='cuda:1'),
#               25417: tensor(0.9968, device='cuda:1'),
#               3828: tensor(0.9905, device='cuda:1'),
#               19174: tensor(0.9786, device='cuda:1'),
#               7491: tensor(0.9968, device='cuda:1')},
#              '5972': {15083: tensor(0.9991, device='cuda:1'),
#               19174: tensor(0.9970, device='cuda:1')},
#              '11567': {25417: tensor(0.9899, device='cuda:1')},
#              '19353': {12533: tensor(0.9709, device='cuda:1'),
#               9090: tensor(0.9709, device='cuda:1')},
#              '567': {26039: tensor(0.9171, device='cuda:1'),
#               16632: tensor(0.8841, device='cuda:1'),
#               3682: tensor(0.3390, device='cuda:1'),
#               25107: tensor(0.3390, device='cuda:1')},
#              '13172': {19174: tensor(0.6600, device='cuda:1'),
#               28149: tensor(0.7126, device='cuda:1'),
#               25417: tensor(0.0647, device='cuda:1')},
#              '14360': {16223: tensor(0.8917, device='cuda:1'),
#               30518: tensor(0.9457, device='cuda:1')},
#              '19155': {15083: tensor(0.9553, device='cuda:1'),
#               26306: tensor(0.9881, device='cuda:1')},
#              '12765': {16223: tensor(0.9960, device='cuda:1'),
#               12533: tensor(0.9960, device='cuda:1')},
#              ...})

# %%
filtered_entity_tensor
# Out:
# tensor([19018,  1771, 12533])

# %%
class ApplySentSelfAttentionBatch(nn.Module):
    def __init__(self, dim, da, alpha=0.2, dropout=0.5): #, ent_sent=None):
        super(ApplySentSelfAttentionBatch, self).__init__()
        self.dim = dim
        self.da = da
        self.alpha = alpha
        self.dropout = dropout
        
        # self.ent_sent = ent_sent
        self.a = nn.Parameter(torch.zeros(size=(self.dim, self.da)), requires_grad=True)
        self.b = nn.Parameter(torch.zeros(size=(self.da, 1)), requires_grad=True)
        nn.init.xavier_uniform_(self.a.data, gain=1.414)
        nn.init.xavier_uniform_(self.b.data, gain=1.414)

    def forward(self, h, entity_list, conv_id, ent_sent):
        # h: (N, dim) => user가 상호작용한 item/entity 개수만큼의 행렬
        e = torch.matmul(torch.tanh(torch.matmul(h, self.a)), self.b).squeeze(dim=1)  # (N)
        attention = F.softmax(e, dim=0)  # (N)
        
        ent_sent_dict = ent_sent[conv_id]
        for i, entity_id in enumerate(entity_list.tolist()):
            if entity_id in ent_sent_dict:
                sent_score = ent_sent_dict[entity_id]
                attention[i] *= sent_score.detach().cpu()
        
        print(attention)
        
        # attention 가중치를 정규화
        norm_attention = attention / attention.sum()
        
        print(norm_attention)
        
        return torch.matmul(norm_attention, h)  # (dim)

# %%
filtered_entity_tensor
# Out:
# tensor([19018,  1771, 12533])

# %%
0.04008 + 0.437960
# Out:
# 0.47804

# %%
0.037360 + 0.441232
# Out:
# 0.478592

# %%
attn = ApplySentSelfAttentionBatch(128, 128)

# (user_repr, user_entity_tensor_list, conv_ids[i], ent_sent)

attn_user_repr = attn(user_repr, filtered_entity_tensor, conv_id="17839", ent_sent=copy_train_ent_sent)
attn_user_repr.shape
# Out:
# tensor([0.2120, 0.6119, 0.0407], grad_fn=<CopySlices>)
# tensor([0.2452, 0.7078, 0.0470], grad_fn=<DivBackward0>)
# torch.Size([128])

# %%
copy_train_ent_sent["17839"]
# Out:
# {19174: tensor(0.9979, device='cuda:1'),
#  21083: tensor(0.9976, device='cuda:1'),
#  19018: tensor(0.9987, device='cuda:1'),
#  12533: tensor(0.2312, device='cuda:1')}

# %%
filtered_entity_tensor
# Out:
# tensor([19018,  1771, 12533])

# %%
class EntitySentModel(nn.Module):
    def __init__(self, model):
        super(EntitySentModel, self).__init__()
        
        self.model = model
        self.ent_sent = defaultdict(dict)

    def forward(self, batch):
        input_ids, attention_mask = batch["context"]['input_ids'], batch["context"]['attention_mask']
        
        outputs = self.model(input_ids=input_ids, attention_mask=attention_mask)
        logits = outputs.logits
            
        logits = logits.detach() ## 추론 시 기울기 흐르는 것 방지 (오류 발생했었음) => 결론적으로 해결 안됐음;;
        
        probabilities = F.softmax(logits, dim=1)
        
        # Extracting probabilities for negative and positive sentiments
        neg, neu, pos = probabilities.unbind(dim=-1)
        sent_score = pos / (pos + neg)
        
        for i, score in enumerate(sent_score):
            if len(batch['entity'][i]) != 0:
                for entity in batch['entity'][i]:
                    #Store the sentiment score in train_ent_sent
                    self.ent_sent[batch['conv_id'][i]][entity] = score

# %%
train_ent_sent_model = EntitySentModel(sent_model).to(args.device)
val_ent_sent_model = EntitySentModel(sent_model).to(args.device)
test_ent_sent_model = EntitySentModel(sent_model).to(args.device)

for batch in tqdm(sent_train_dataloader):
    with torch.no_grad():
        train_ent_sent_model(batch)
    
for batch in tqdm(sent_val_dataloader):
    with torch.no_grad():
        val_ent_sent_model.forward(batch)
    
for batch in tqdm(sent_test_dataloader):
    with torch.no_grad():
        test_ent_sent_model.forward(batch)

train_ent_sent = train_ent_sent_model.ent_sent
val_ent_sent = val_ent_sent_model.ent_sent
test_ent_sent = test_ent_sent_model.ent_sent
# Out:
#   0%|          | 0/1722 [00:00<?, ?it/s]
# /home/hyuns6100/anaconda3/envs/env3/lib/python3.8/site-packages/transformers/tokenization_utils_base.py:2372: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   warnings.warn(
#   0%|          | 0/192 [00:00<?, ?it/s]
#   0%|          | 0/242 [00:00<?, ?it/s]

# %%
list(train_ent_sent.items())
# Out:
# ('14205', {26306: tensor(0.9974, device='cuda:1')})

# %%
len(train_ent_sent), len(val_ent_sent)

list(train_ent_sent.items())[-50], list(val_ent_sent.items())[-50], list(test_ent_sent.items())[-50]
# Out:
# (('14205', {26306: tensor(0.9974, device='cuda:1')}),
#  ('18172',
#   {17897: tensor(0.1186, device='cuda:1'),
#    18093: tensor(0.9979, device='cuda:1'),
#    1925: tensor(0.1186, device='cuda:1'),
#    22254: tensor(0.9990, device='cuda:1')}),
#  ('23109',
#   {30546: tensor(0.9579, device='cuda:1'),
#    12533: tensor(0.6316, device='cuda:1'),
#    27382: tensor(0.5373, device='cuda:1')}))

# %%
train_ent_sent
# Out:
# defaultdict(dict,
#             {'19429': {19174: tensor(0.9959, device='cuda:1')},
#              '8618': {3682: tensor(0.9924, device='cuda:1'),
#               8828: tensor(0.9924, device='cuda:1'),
#               12533: tensor(0.2536, device='cuda:1'),
#               7822: tensor(0.2536, device='cuda:1'),
#               26306: tensor(0.3332, device='cuda:1')},
#              '16534': {13573: tensor(0.6659, device='cuda:1'),
#               6696: tensor(0.9966, device='cuda:1')},
#              '13724': {2115: tensor(0.9983, device='cuda:1'),
#               3812: tensor(0.9939, device='cuda:1'),
#               20028: tensor(0.9983, device='cuda:1'),
#               19174: tensor(0.9983, device='cuda:1'),
#               26306: tensor(0.9979, device='cuda:1'),
#               5251: tensor(0.9979, device='cuda:1'),
#               3828: tensor(0.9979, device='cuda:1'),
#               4028: tensor(0.9979, device='cuda:1')},
#              '17100': {25417: tensor(0.1408, device='cuda:1'),
#               2115: tensor(0.9983, device='cuda:1'),
#               12533: tensor(0.9949, device='cuda:1'),
#               21083: tensor(0.3217, device='cuda:1'),
#               20028: tensor(0.1866, device='cuda:1'),
#               19174: tensor(0.1866, device='cuda:1'),
#               1865: tensor(0.1408, device='cuda:1'),
#               1925: tensor(0.1408, device='cuda:1')},
#              '17813': {15812: tensor(0.9952, device='cuda:1'),
#               19174: tensor(0.1521, device='cuda:1')},
#              '10905': {19174: tensor(0.9705, device='cuda:1')},
#              '8072': {9258: tensor(0.2789, device='cuda:1'),
#               19174: tensor(0.1491, device='cuda:1'),
#               16223: tensor(0.9979, device='cuda:1')},
#              '19603': {5251: tensor(0.9990, device='cuda:1'),
#               24745: tensor(0.9148, device='cuda:1'),
#               30185: tensor(0.9148, device='cuda:1'),
#               25417: tensor(0.8951, device='cuda:1'),
#               28626: tensor(0.9112, device='cuda:1'),
#               3828: tensor(0.0182, device='cuda:1'),
#               1865: tensor(0.9976, device='cuda:1')},
#              '11902': {26306: tensor(0.9981, device='cuda:1')},
#              '2924': {15264: tensor(0.9988, device='cuda:1'),
#               12533: tensor(0.9988, device='cuda:1'),
#               25107: tensor(0.9951, device='cuda:1'),
#               30380: tensor(0.9980, device='cuda:1'),
#               2558: tensor(0.6893, device='cuda:1')},
#              '3734': {10856: tensor(0.8087, device='cuda:1'),
#               14359: tensor(0.9988, device='cuda:1'),
#               9786: tensor(0.9956, device='cuda:1'),
#               8589: tensor(0.9956, device='cuda:1')},
#              '484': {16223: tensor(0.9733, device='cuda:1'),
#               26306: tensor(0.9850, device='cuda:1'),
#               15171: tensor(0.9926, device='cuda:1'),
#               12533: tensor(0.9982, device='cuda:1')},
#              '10975': {16507: tensor(0.9989, device='cuda:1'),
#               7952: tensor(0.9981, device='cuda:1')},
#              '15425': {10856: tensor(0.9989, device='cuda:1')},
#              '10862': {16223: tensor(0.9607, device='cuda:1'),
#               17144: tensor(0.3617, device='cuda:1'),
#               22497: tensor(0.3617, device='cuda:1'),
#               15070: tensor(0.3617, device='cuda:1')},
#              '6128': {26306: tensor(0.9984, device='cuda:1'),
#               25107: tensor(0.9988, device='cuda:1')},
#              '17376': {8589: tensor(0.9529, device='cuda:1'),
#               15264: tensor(0.9954, device='cuda:1'),
#               26306: tensor(0.9529, device='cuda:1')},
#              '11407': {28551: tensor(0.0245, device='cuda:1'),
#               8848: tensor(0.5519, device='cuda:1'),
#               21083: tensor(0.5519, device='cuda:1'),
#               20028: tensor(0.5519, device='cuda:1'),
#               29787: tensor(0.8826, device='cuda:1')},
#              '17780': {11240: tensor(0.9937, device='cuda:1'),
#               19174: tensor(0.1549, device='cuda:1'),
#               20066: tensor(0.1549, device='cuda:1'),
#               2115: tensor(0.9981, device='cuda:1'),
#               20816: tensor(0.9974, device='cuda:1'),
#               18112: tensor(0.9974, device='cuda:1'),
#               17897: tensor(0.1549, device='cuda:1')},
#              '11817': {3682: tensor(0.8862, device='cuda:1'),
#               19174: tensor(0.8862, device='cuda:1'),
#               16223: tensor(0.8862, device='cuda:1')},
#              '15486': {12533: tensor(0.9956, device='cuda:1'),
#               26306: tensor(0.9750, device='cuda:1')},
#              '3634': {8828: tensor(0.9359, device='cuda:1')},
#              '14866': {19174: tensor(0.6995, device='cuda:1'),
#               25858: tensor(0.8538, device='cuda:1'),
#               16223: tensor(0.9848, device='cuda:1'),
#               26306: tensor(0.9812, device='cuda:1')},
#              '12733': {25417: tensor(0.9919, device='cuda:1')},
#              '9106': {16223: tensor(0.9835, device='cuda:1'),
#               3828: tensor(0.0103, device='cuda:1'),
#               19174: tensor(0.9987, device='cuda:1'),
#               22571: tensor(0.9987, device='cuda:1'),
#               27030: tensor(0.9987, device='cuda:1'),
#               21083: tensor(0.9987, device='cuda:1')},
#              '15824': {19174: tensor(0.9964, device='cuda:1'),
#               12533: tensor(0.9986, device='cuda:1'),
#               26306: tensor(0.9986, device='cuda:1')},
#              '10616': {1925: tensor(0.0282, device='cuda:1'),
#               28149: tensor(0.9812, device='cuda:1'),
#               20183: tensor(0.9986, device='cuda:1'),
#               26306: tensor(0.5708, device='cuda:1'),
#               28026: tensor(0.5708, device='cuda:1'),
#               25417: tensor(0.9897, device='cuda:1')},
#              '7963': {26829: tensor(0.9987, device='cuda:1')},
#              '12185': {25417: tensor(0.9954, device='cuda:1'),
#               25107: tensor(0.9954, device='cuda:1'),
#               12533: tensor(0.5428, device='cuda:1')},
#              '15557': {18874: tensor(0.1801, device='cuda:1'),
#               3682: tensor(0.8963, device='cuda:1')},
#              '6052': {7088: tensor(0.9987, device='cuda:1'),
#               21700: tensor(0.9987, device='cuda:1'),
#               3828: tensor(0.9918, device='cuda:1'),
#               26306: tensor(0.5988, device='cuda:1'),
#               21083: tensor(0.9985, device='cuda:1')},
#              '16252': {2115: tensor(0.9989, device='cuda:1'),
#               19174: tensor(0.7262, device='cuda:1'),
#               18874: tensor(0.8353, device='cuda:1'),
#               28551: tensor(0.8353, device='cuda:1')},
#              '12241': {25417: tensor(0.9986, device='cuda:1'),
#               26306: tensor(0.9986, device='cuda:1')},
#              '18659': {25417: tensor(0.9982, device='cuda:1'),
#               12205: tensor(0.9859, device='cuda:1')},
#              '14187': {28687: tensor(0.9701, device='cuda:1'),
#               15264: tensor(0.9970, device='cuda:1')},
#              '7835': {26306: tensor(0.9966, device='cuda:1'),
#               10856: tensor(0.9811, device='cuda:1'),
#               8828: tensor(0.9873, device='cuda:1'),
#               16223: tensor(0.9873, device='cuda:1')},
#              '3364': {5505: tensor(0.9989, device='cuda:1')},
#              '1216': {20066: tensor(0.9653, device='cuda:1'),
#               4650: tensor(0.2357, device='cuda:1')},
#              '2275': {26306: tensor(0.9938, device='cuda:1'),
#               25107: tensor(0.9938, device='cuda:1'),
#               3812: tensor(0.9938, device='cuda:1'),
#               16506: tensor(0.9922, device='cuda:1'),
#               24180: tensor(0.3248, device='cuda:1')},
#              '13838': {5024: tensor(0.9985, device='cuda:1'),
#               17897: tensor(0.9987, device='cuda:1'),
#               3682: tensor(0.9987, device='cuda:1'),
#               11834: tensor(0.9987, device='cuda:1'),
#               21083: tensor(0.9987, device='cuda:1')},
#              '7690': {15084: tensor(0.9833, device='cuda:1'),
#               24790: tensor(0.9833, device='cuda:1'),
#               15889: tensor(0.9956, device='cuda:1'),
#               9677: tensor(0.1452, device='cuda:1'),
#               5505: tensor(0.9985, device='cuda:1'),
#               19018: tensor(0.9985, device='cuda:1'),
#               9118: tensor(0.9985, device='cuda:1'),
#               1865: tensor(0.9243, device='cuda:1')},
#              '13358': {25417: tensor(0.8382, device='cuda:1'),
#               16223: tensor(0.9962, device='cuda:1'),
#               9133: tensor(0.9983, device='cuda:1'),
#               26306: tensor(0.9958, device='cuda:1')},
#              '1103': {15474: tensor(0.6055, device='cuda:1'),
#               16223: tensor(0.9865, device='cuda:1'),
#               8126: tensor(0.0873, device='cuda:1'),
#               22998: tensor(0.6123, device='cuda:1')},
#              '14794': {16223: tensor(0.9967, device='cuda:1'),
#               19174: tensor(0.9991, device='cuda:1')},
#              '12779': {8828: tensor(0.9976, device='cuda:1'),
#               12533: tensor(0.6929, device='cuda:1')},
#              '10447': {27820: tensor(0.4653, device='cuda:1'),
#               21325: tensor(0.9911, device='cuda:1')},
#              '1754': {26306: tensor(0.9281, device='cuda:1'),
#               13756: tensor(0.9980, device='cuda:1'),
#               8589: tensor(0.9980, device='cuda:1'),
#               12710: tensor(0.9980, device='cuda:1'),
#               20183: tensor(0.9980, device='cuda:1'),
#               29425: tensor(0.9928, device='cuda:1'),
#               13573: tensor(0.9928, device='cuda:1')},
#              '18102': {12533: tensor(0.9780, device='cuda:1'),
#               16223: tensor(0.9780, device='cuda:1'),
#               10856: tensor(0.9986, device='cuda:1'),
#               25858: tensor(0.9987, device='cuda:1')},
#              '9368': {3682: tensor(0.9942, device='cuda:1'),
#               20602: tensor(0.9964, device='cuda:1'),
#               7822: tensor(0.9971, device='cuda:1'),
#               8579: tensor(0.9971, device='cuda:1'),
#               29279: tensor(0.9971, device='cuda:1'),
#               26306: tensor(0.3981, device='cuda:1')},
#              '3757': {12533: tensor(0.9981, device='cuda:1'),
#               16506: tensor(0.9859, device='cuda:1')},
#              '9301': {21083: tensor(0.4292, device='cuda:1'),
#               3828: tensor(0.9988, device='cuda:1')},
#              '6252': {27698: tensor(0.8607, device='cuda:1'),
#               11834: tensor(0.7575, device='cuda:1'),
#               26306: tensor(0.9990, device='cuda:1'),
#               1615: tensor(0.9979, device='cuda:1')},
#              '11003': {17897: tensor(0.9970, device='cuda:1'),
#               7952: tensor(0.9976, device='cuda:1')},
#              '674': {1925: tensor(0.3817, device='cuda:1'),
#               26306: tensor(0.3485, device='cuda:1')},
#              '18677': {17897: tensor(0.1360, device='cuda:1'),
#               22254: tensor(0.1360, device='cuda:1'),
#               16730: tensor(0.0448, device='cuda:1'),
#               3828: tensor(0.0448, device='cuda:1'),
#               26402: tensor(0.9720, device='cuda:1'),
#               7822: tensor(0.9720, device='cuda:1'),
#               24790: tensor(0.9720, device='cuda:1')},
#              '10430': {16223: tensor(0.9986, device='cuda:1')},
#              '6701': {22992: tensor(0.0204, device='cuda:1'),
#               15474: tensor(0.0204, device='cuda:1'),
#               5251: tensor(0.0204, device='cuda:1'),
#               19174: tensor(0.8515, device='cuda:1'),
#               21700: tensor(0.9934, device='cuda:1'),
#               6869: tensor(0.9934, device='cuda:1')},
#              '18477': {28149: tensor(0.9987, device='cuda:1'),
#               25417: tensor(0.9797, device='cuda:1'),
#               21083: tensor(0.9797, device='cuda:1'),
#               19174: tensor(0.0027, device='cuda:1'),
#               16785: tensor(0.1660, device='cuda:1'),
#               26306: tensor(0.5120, device='cuda:1'),
#               12497: tensor(0.9985, device='cuda:1')},
#              '1944': {27708: tensor(0.9989, device='cuda:1'),
#               16620: tensor(0.9841, device='cuda:1'),
#               2558: tensor(0.9841, device='cuda:1'),
#               3369: tensor(0.9970, device='cuda:1')},
#              '18654': {12533: tensor(0.8036, device='cuda:1')},
#              '538': {25417: tensor(0.0425, device='cuda:1'),
#               19174: tensor(0.0908, device='cuda:1'),
#               6862: tensor(0.0908, device='cuda:1'),
#               28551: tensor(0.0908, device='cuda:1'),
#               26306: tensor(0.9832, device='cuda:1')},
#              '18591': {3828: tensor(0.7990, device='cuda:1'),
#               12533: tensor(0.8906, device='cuda:1'),
#               7491: tensor(0.8906, device='cuda:1'),
#               15070: tensor(0.8906, device='cuda:1'),
#               980: tensor(0.7442, device='cuda:1'),
#               13332: tensor(0.9946, device='cuda:1')},
#              '6760': {15171: tensor(0.9730, device='cuda:1'),
#               25858: tensor(0.2434, device='cuda:1'),
#               26306: tensor(0.9979, device='cuda:1'),
#               19018: tensor(0.9986, device='cuda:1')},
#              '8990': {25726: tensor(0.9887, device='cuda:1'),
#               13332: tensor(0.8251, device='cuda:1'),
#               29407: tensor(0.8251, device='cuda:1')},
#              '560': {25858: tensor(0.9966, device='cuda:1'),
#               16223: tensor(0.8919, device='cuda:1'),
#               29961: tensor(0.9985, device='cuda:1')},
#              '2340': {2115: tensor(0.9141, device='cuda:1'),
#               16223: tensor(0.9962, device='cuda:1'),
#               21083: tensor(0.9916, device='cuda:1'),
#               7348: tensor(0.9916, device='cuda:1'),
#               6589: tensor(0.9916, device='cuda:1'),
#               19247: tensor(0.8134, device='cuda:1'),
#               6311: tensor(0.5293, device='cuda:1')},
#              '9859': {1925: tensor(0.9700, device='cuda:1'),
#               25257: tensor(0.9892, device='cuda:1'),
#               12533: tensor(0.8092, device='cuda:1')},
#              '14726': {13835: tensor(0.5248, device='cuda:1')},
#              '3950': {26306: tensor(0.9428, device='cuda:1'),
#               30823: tensor(0.0549, device='cuda:1'),
#               2115: tensor(0.9986, device='cuda:1'),
#               5251: tensor(0.9986, device='cuda:1')},
#              '4938': {25858: tensor(0.9975, device='cuda:1'),
#               28621: tensor(0.2384, device='cuda:1'),
#               22998: tensor(0.2384, device='cuda:1'),
#               26306: tensor(0.8406, device='cuda:1'),
#               16223: tensor(0.8406, device='cuda:1')},
#              '14028': {12570: tensor(0.9229, device='cuda:1'),
#               19454: tensor(0.9229, device='cuda:1'),
#               16223: tensor(0.8867, device='cuda:1'),
#               15264: tensor(0.9989, device='cuda:1')},
#              '12134': {16223: tensor(0.9959, device='cuda:1'),
#               23903: tensor(0.9985, device='cuda:1')},
#              '15973': {13332: tensor(0.9985, device='cuda:1'),
#               12533: tensor(0.9951, device='cuda:1'),
#               20028: tensor(0.9951, device='cuda:1'),
#               5894: tensor(0.9951, device='cuda:1'),
#               19174: tensor(0.2622, device='cuda:1')},
#              '927': {25417: tensor(0.9979, device='cuda:1'),
#               12533: tensor(0.5821, device='cuda:1'),
#               19018: tensor(0.9968, device='cuda:1'),
#               25107: tensor(0.5821, device='cuda:1'),
#               25731: tensor(0.5821, device='cuda:1'),
#               16223: tensor(0.9738, device='cuda:1'),
#               23183: tensor(0.9738, device='cuda:1'),
#               20816: tensor(0.9738, device='cuda:1')},
#              '2785': {25417: tensor(0.9924, device='cuda:1'),
#               19174: tensor(0.8467, device='cuda:1')},
#              '14730': {25858: tensor(0.9988, device='cuda:1'),
#               13835: tensor(0.4153, device='cuda:1'),
#               16223: tensor(0.9148, device='cuda:1')},
#              '17896': {20066: tensor(0.9521, device='cuda:1'),
#               22575: tensor(0.9961, device='cuda:1'),
#               27011: tensor(0.9961, device='cuda:1')},
#              '13482': {20848: tensor(0.9947, device='cuda:1'),
#               12626: tensor(0.8107, device='cuda:1'),
#               25731: tensor(0.8107, device='cuda:1'),
#               1925: tensor(0.4498, device='cuda:1')},
#              '12431': {16507: tensor(0.9755, device='cuda:1')},
#              '11505': {21083: tensor(0.3999, device='cuda:1'),
#               3828: tensor(0.9992, device='cuda:1')},
#              '963': {27698: tensor(0.9929, device='cuda:1'),
#               26306: tensor(0.9955, device='cuda:1'),
#               20066: tensor(0.9929, device='cuda:1'),
#               13093: tensor(0.9987, device='cuda:1'),
#               24748: tensor(0.9955, device='cuda:1'),
#               2613: tensor(0.9955, device='cuda:1'),
#               11866: tensor(0.9955, device='cuda:1'),
#               7580: tensor(0.9955, device='cuda:1'),
#               19487: tensor(0.9955, device='cuda:1'),
#               8878: tensor(0.9673, device='cuda:1'),
#               19174: tensor(0.9987, device='cuda:1')},
#              '14635': {29787: tensor(0.9987, device='cuda:1'),
#               20028: tensor(0.9985, device='cuda:1'),
#               25417: tensor(0.5856, device='cuda:1')},
#              '3961': {10856: tensor(0.8343, device='cuda:1'),
#               19174: tensor(0.9990, device='cuda:1')},
#              '7469': {7959: tensor(0.9978, device='cuda:1'),
#               3682: tensor(0.9934, device='cuda:1'),
#               18308: tensor(0.9968, device='cuda:1')},
#              '8137': {6856: tensor(0.9973, device='cuda:1'),
#               25417: tensor(0.9973, device='cuda:1')},
#              '6931': {26306: tensor(0.9900, device='cuda:1'),
#               25107: tensor(0.9881, device='cuda:1'),
#               12205: tensor(0.9961, device='cuda:1')},
#              '7420': {19018: tensor(0.9975, device='cuda:1'),
#               16394: tensor(0.9975, device='cuda:1'),
#               3682: tensor(0.8443, device='cuda:1'),
#               15812: tensor(0.9981, device='cuda:1'),
#               16223: tensor(0.8443, device='cuda:1')},
#              '11873': {2115: tensor(0.9951, device='cuda:1'),
#               21083: tensor(0.9954, device='cuda:1')},
#              '3124': {5251: tensor(0.9987, device='cuda:1'),
#               11229: tensor(0.9228, device='cuda:1'),
#               19174: tensor(0.9228, device='cuda:1'),
#               8828: tensor(0.8674, device='cuda:1'),
#               26306: tensor(0.9330, device='cuda:1'),
#               10276: tensor(0.5125, device='cuda:1')},
#              '16962': {1685: tensor(0.0842, device='cuda:1'),
#               12246: tensor(0.0236, device='cuda:1'),
#               19174: tensor(0.7070, device='cuda:1'),
#               12533: tensor(0.9786, device='cuda:1')},
#              '791': {3682: tensor(0.1517, device='cuda:1'),
#               19174: tensor(0.4613, device='cuda:1'),
#               29101: tensor(0.5253, device='cuda:1'),
#               5251: tensor(0.9865, device='cuda:1'),
#               1925: tensor(0.9865, device='cuda:1')},
#              '16523': {11240: tensor(0.8757, device='cuda:1'),
#               19174: tensor(0.9364, device='cuda:1'),
#               4986: tensor(0.9976, device='cuda:1'),
#               8263: tensor(0.0244, device='cuda:1')},
#              '8702': {26306: tensor(0.9899, device='cuda:1'),
#               3828: tensor(0.9899, device='cuda:1'),
#               24180: tensor(0.9388, device='cuda:1'),
#               12533: tensor(0.9987, device='cuda:1'),
#               28149: tensor(0.9987, device='cuda:1')},
#              '6534': {16223: tensor(0.8011, device='cuda:1')},
#              '6833': {16223: tensor(0.6846, device='cuda:1')},
#              '3737': {29787: tensor(0.9986, device='cuda:1'),
#               20028: tensor(0.9986, device='cuda:1'),
#               9083: tensor(0.3072, device='cuda:1'),
#               24151: tensor(0.9985, device='cuda:1'),
#               25126: tensor(0.9920, device='cuda:1'),
#               19174: tensor(0.9920, device='cuda:1'),
#               25726: tensor(0.9920, device='cuda:1')},
#              '16129': {12533: tensor(0.4170, device='cuda:1'),
#               21083: tensor(0.9990, device='cuda:1')},
#              '18563': {2653: tensor(0.9951, device='cuda:1'),
#               25107: tensor(0.8737, device='cuda:1'),
#               25721: tensor(0.9182, device='cuda:1')},
#              '12337': {12533: tensor(0.9954, device='cuda:1'),
#               27001: tensor(0.9986, device='cuda:1'),
#               24790: tensor(0.9986, device='cuda:1'),
#               16223: tensor(0.9104, device='cuda:1'),
#               21083: tensor(0.9964, device='cuda:1')},
#              '3164': {3812: tensor(0.9972, device='cuda:1'),
#               21083: tensor(0.0082, device='cuda:1'),
#               20183: tensor(0.0082, device='cuda:1'),
#               18488: tensor(0.9972, device='cuda:1'),
#               12533: tensor(0.9972, device='cuda:1')},
#              '12889': {25858: tensor(0.1569, device='cuda:1'),
#               19174: tensor(0.2807, device='cuda:1'),
#               15070: tensor(0.2807, device='cuda:1')},
#              '13315': {15474: tensor(0.9972, device='cuda:1'),
#               25417: tensor(0.1863, device='cuda:1')},
#              '16573': {15171: tensor(0.7910, device='cuda:1'),
#               12533: tensor(0.8925, device='cuda:1')},
#              '3031': {19174: tensor(0.9906, device='cuda:1'),
#               3682: tensor(0.9928, device='cuda:1')},
#              '10259': {25107: tensor(0.9951, device='cuda:1'),
#               25417: tensor(0.0838, device='cuda:1'),
#               3812: tensor(0.0838, device='cuda:1'),
#               28551: tensor(0.0838, device='cuda:1')},
#              '6461': {16223: tensor(0.9985, device='cuda:1'),
#               19174: tensor(0.3557, device='cuda:1')},
#              '9540': {25726: tensor(0.9983, device='cuda:1'),
#               3682: tensor(0.9942, device='cuda:1')},
#              '11011': {21083: tensor(0.5976, device='cuda:1'),
#               16223: tensor(0.9967, device='cuda:1'),
#               27619: tensor(0.9911, device='cuda:1'),
#               19174: tensor(0.9966, device='cuda:1')},
#              '5710': {19174: tensor(0.9902, device='cuda:1'),
#               12533: tensor(0.9968, device='cuda:1')},
#              '16945': {5332: tensor(0.9979, device='cuda:1'),
#               12533: tensor(0.9059, device='cuda:1'),
#               10953: tensor(0.9059, device='cuda:1'),
#               2558: tensor(0.9059, device='cuda:1'),
#               5894: tensor(0.9059, device='cuda:1')},
#              '2820': {20028: tensor(0.9960, device='cuda:1'),
#               26306: tensor(0.9988, device='cuda:1'),
#               5251: tensor(0.9991, device='cuda:1'),
#               19174: tensor(0.9742, device='cuda:1')},
#              '3545': {7952: tensor(0.9986, device='cuda:1'),
#               20066: tensor(0.9989, device='cuda:1')},
#              '4250': {10856: tensor(0.8714, device='cuda:1'),
#               26306: tensor(0.9990, device='cuda:1')},
#              '8250': {26306: tensor(0.9983, device='cuda:1'),
#               12533: tensor(0.9858, device='cuda:1'),
#               16223: tensor(0.9858, device='cuda:1'),
#               21516: tensor(0.5164, device='cuda:1')},
#              '15519': {8509: tensor(0.9980, device='cuda:1'),
#               7822: tensor(0.9980, device='cuda:1'),
#               8828: tensor(0.9947, device='cuda:1'),
#               12533: tensor(0.9947, device='cuda:1')},
#              '14162': {10856: tensor(0.9483, device='cuda:1'),
#               25858: tensor(0.9931, device='cuda:1'),
#               21083: tensor(0.0320, device='cuda:1')},
#              '17686': {19354: tensor(0.4260, device='cuda:1'),
#               21083: tensor(0.4260, device='cuda:1')},
#              '17151': {17897: tensor(0.9975, device='cuda:1'),
#               26306: tensor(0.2553, device='cuda:1'),
#               19018: tensor(0.2553, device='cuda:1'),
#               19174: tensor(0.9963, device='cuda:1'),
#               17579: tensor(0.6943, device='cuda:1'),
#               19724: tensor(0.9964, device='cuda:1')},
#              '12355': {17897: tensor(0.9364, device='cuda:1')},
#              '12727': {28149: tensor(0.9060, device='cuda:1'),
#               16223: tensor(0.0916, device='cuda:1'),
#               19174: tensor(0.5294, device='cuda:1')},
#              '18324': {26306: tensor(0.9972, device='cuda:1'),
#               28026: tensor(0.9972, device='cuda:1'),
#               12205: tensor(0.9801, device='cuda:1')},
#              '16612': {29787: tensor(0.9228, device='cuda:1'),
#               12533: tensor(0.9986, device='cuda:1'),
#               17579: tensor(0.6525, device='cuda:1'),
#               17340: tensor(0.6525, device='cuda:1'),
#               26829: tensor(0.6525, device='cuda:1')},
#              '19826': {18719: tensor(0.9880, device='cuda:1'),
#               1775: tensor(0.9986, device='cuda:1')},
#              '10903': {26306: tensor(0.9987, device='cuda:1'),
#               12533: tensor(0.9977, device='cuda:1')},
#              '16608': {17897: tensor(0.9988, device='cuda:1'),
#               26306: tensor(0.9988, device='cuda:1')},
#              '7419': {16223: tensor(0.9947, device='cuda:1'),
#               15812: tensor(0.9936, device='cuda:1'),
#               3682: tensor(0.9891, device='cuda:1'),
#               12533: tensor(0.9975, device='cuda:1'),
#               1925: tensor(0.9975, device='cuda:1')},
#              '12289': {19336: tensor(0.9984, device='cuda:1'),
#               3633: tensor(0.9984, device='cuda:1'),
#               8386: tensor(0.9747, device='cuda:1'),
#               19174: tensor(0.5496, device='cuda:1'),
#               10856: tensor(0.2936, device='cuda:1'),
#               4105: tensor(0.2936, device='cuda:1'),
#               28339: tensor(0.9983, device='cuda:1'),
#               6249: tensor(0.1429, device='cuda:1')},
#              '12611': {17144: tensor(0.7958, device='cuda:1'),
#               1925: tensor(0.9963, device='cuda:1'),
#               24386: tensor(0.8158, device='cuda:1'),
#               11434: tensor(0.9670, device='cuda:1'),
#               2115: tensor(0.6264, device='cuda:1'),
#               26306: tensor(0.6986, device='cuda:1'),
#               21253: tensor(0.6986, device='cuda:1'),
#               21030: tensor(0.6986, device='cuda:1'),
#               15070: tensor(0.5293, device='cuda:1'),
#               5251: tensor(0.7889, device='cuda:1'),
#               29787: tensor(0.6767, device='cuda:1')},
#              '5821': {7350: tensor(0.9984, device='cuda:1'),
#               21083: tensor(0.9933, device='cuda:1'),
#               17897: tensor(0.9975, device='cuda:1'),
#               16223: tensor(0.9975, device='cuda:1'),
#               22254: tensor(0.9987, device='cuda:1')},
#              '1303': {26306: tensor(0.9969, device='cuda:1'),
#               27714: tensor(0.9969, device='cuda:1'),
#               15083: tensor(0.9969, device='cuda:1'),
#               12533: tensor(0.7626, device='cuda:1'),
#               29407: tensor(0.9498, device='cuda:1')},
#              '9743': {3067: tensor(0.2438, device='cuda:1'),
#               12533: tensor(0.9759, device='cuda:1'),
#               16392: tensor(0.9965, device='cuda:1')},
#              '6062': {19174: tensor(0.3557, device='cuda:1'),
#               17489: tensor(0.3551, device='cuda:1'),
#               12533: tensor(0.8158, device='cuda:1')},
#              '897': {3682: tensor(0.9596, device='cuda:1'),
#               3812: tensor(0.9960, device='cuda:1'),
#               29425: tensor(0.9972, device='cuda:1'),
#               1925: tensor(0.9972, device='cuda:1')},
#              '7205': {20066: tensor(0.9797, device='cuda:1'),
#               19174: tensor(0.5426, device='cuda:1')},
#              '7456': {19174: tensor(0.9984, device='cuda:1'),
#               25417: tensor(0.9976, device='cuda:1')},
#              '18538': {10856: tensor(0.9979, device='cuda:1')},
#              '3639': {25417: tensor(0.9980, device='cuda:1'),
#               25107: tensor(0.9980, device='cuda:1'),
#               1439: tensor(0.9975, device='cuda:1')},
#              '19117': {12533: tensor(0.9973, device='cuda:1')},
#              '2764': {1925: tensor(0.9734, device='cuda:1'),
#               15264: tensor(0.9958, device='cuda:1'),
#               14190: tensor(0.9958, device='cuda:1'),
#               2431: tensor(0.9958, device='cuda:1'),
#               1865: tensor(0.9513, device='cuda:1'),
#               21142: tensor(0.3809, device='cuda:1'),
#               20066: tensor(0.6898, device='cuda:1'),
#               19174: tensor(0.9987, device='cuda:1'),
#               29279: tensor(0.9987, device='cuda:1'),
#               8828: tensor(0.3809, device='cuda:1'),
#               4613: tensor(0.9982, device='cuda:1'),
#               12631: tensor(0.9982, device='cuda:1'),
#               26893: tensor(0.9777, device='cuda:1')},
#              '9318': {19247: tensor(0.5021, device='cuda:1'),
#               16223: tensor(0.9987, device='cuda:1'),
#               6138: tensor(0.9977, device='cuda:1'),
#               3491: tensor(0.9977, device='cuda:1'),
#               17579: tensor(0.9977, device='cuda:1'),
#               26402: tensor(0.5137, device='cuda:1')},
#              '2862': {3682: tensor(0.6567, device='cuda:1'),
#               8828: tensor(0.4222, device='cuda:1'),
#               7432: tensor(0.9977, device='cuda:1')},
#              '11084': {10856: tensor(0.9974, device='cuda:1'),
#               8828: tensor(0.3983, device='cuda:1'),
#               26338: tensor(0.9974, device='cuda:1')},
#              '12476': {26244: tensor(0.9985, device='cuda:1'),
#               1925: tensor(0.9954, device='cuda:1'),
#               17897: tensor(0.7597, device='cuda:1')},
#              '16178': {8828: tensor(0.9986, device='cuda:1'),
#               24528: tensor(0.9975, device='cuda:1')},
#              '19576': {21722: tensor(0.6130, device='cuda:1'),
#               21325: tensor(0.9718, device='cuda:1'),
#               4613: tensor(0.9718, device='cuda:1'),
#               20183: tensor(0.9718, device='cuda:1'),
#               26341: tensor(0.9938, device='cuda:1')},
#              '9200': {9293: tensor(0.9980, device='cuda:1'),
#               19174: tensor(0.9989, device='cuda:1')},
#              '14982': {25858: tensor(0.9926, device='cuda:1'),
#               16507: tensor(0.9926, device='cuda:1'),
#               13088: tensor(0.9936, device='cuda:1'),
#               26306: tensor(0.9936, device='cuda:1'),
#               6099: tensor(0.9955, device='cuda:1'),
#               19174: tensor(0.5293, device='cuda:1'),
#               2115: tensor(0.9978, device='cuda:1'),
#               16223: tensor(0.9857, device='cuda:1')},
#              '11428': {19174: tensor(0.3898, device='cuda:1'),
#               16223: tensor(0.6184, device='cuda:1')},
#              '1472': {25858: tensor(0.9985, device='cuda:1'),
#               16223: tensor(0.0129, device='cuda:1')},
#              '3206': {28026: tensor(0.9973, device='cuda:1'),
#               25417: tensor(0.9987, device='cuda:1')},
#              '4787': {15264: tensor(0.2731, device='cuda:1'),
#               29407: tensor(0.2731, device='cuda:1'),
#               19205: tensor(0.9937, device='cuda:1'),
#               29703: tensor(0.2731, device='cuda:1'),
#               27619: tensor(0.9990, device='cuda:1'),
#               3682: tensor(0.9990, device='cuda:1'),
#               5332: tensor(0.9937, device='cuda:1'),
#               21142: tensor(0.9937, device='cuda:1'),
#               2460: tensor(0.9990, device='cuda:1')},
#              '3926': {25731: tensor(0.9973, device='cuda:1'),
#               25417: tensor(0.9710, device='cuda:1')},
#              '2756': {26306: tensor(0.9146, device='cuda:1'),
#               16223: tensor(0.9783, device='cuda:1'),
#               12533: tensor(0.9971, device='cuda:1'),
#               12631: tensor(0.9971, device='cuda:1')},
#              '4843': {5251: tensor(0.9988, device='cuda:1'),
#               3828: tensor(0.9989, device='cuda:1')},
#              '16072': {8828: tensor(0.0257, device='cuda:1'),
#               3682: tensor(0.0257, device='cuda:1'),
#               3724: tensor(0.5209, device='cuda:1'),
#               3828: tensor(0.5350, device='cuda:1'),
#               2115: tensor(0.9971, device='cuda:1'),
#               21700: tensor(0.0257, device='cuda:1'),
#               1925: tensor(0.9960, device='cuda:1')},
#              '7530': {16223: tensor(0.3963, device='cuda:1'),
#               15264: tensor(0.4417, device='cuda:1'),
#               24790: tensor(0.4417, device='cuda:1')},
#              '6414': {12533: tensor(0.9961, device='cuda:1')},
#              '15787': {1925: tensor(0.9973, device='cuda:1'),
#               16223: tensor(0.9836, device='cuda:1'),
#               3491: tensor(0.9975, device='cuda:1')},
#              '12570': {19174: tensor(0.5458, device='cuda:1'),
#               25417: tensor(0.9860, device='cuda:1'),
#               12533: tensor(0.9459, device='cuda:1')},
#              '6049': {26306: tensor(0.9911, device='cuda:1'),
#               12533: tensor(0.9973, device='cuda:1'),
#               20028: tensor(0.9911, device='cuda:1'),
#               19174: tensor(0.9911, device='cuda:1'),
#               29787: tensor(0.9843, device='cuda:1'),
#               2537: tensor(0.1972, device='cuda:1')},
#              '10968': {16223: tensor(0.9800, device='cuda:1')},
#              '8082': {16223: tensor(0.9982, device='cuda:1'),
#               11864: tensor(0.9864, device='cuda:1')},
#              '9782': {26306: tensor(0.9987, device='cuda:1'),
#               4762: tensor(0.9987, device='cuda:1'),
#               28687: tensor(0.9962, device='cuda:1'),
#               16223: tensor(0.9967, device='cuda:1')},
#              '5219': {8565: tensor(0.9984, device='cuda:1'),
#               26306: tensor(0.9910, device='cuda:1'),
#               25417: tensor(0.9978, device='cuda:1'),
#               20183: tensor(0.9713, device='cuda:1'),
#               16507: tensor(0.9955, device='cuda:1')},
#              '13721': {14081: tensor(0.9921, device='cuda:1'),
#               29787: tensor(0.2070, device='cuda:1'),
#               20028: tensor(0.2070, device='cuda:1'),
#               18874: tensor(0.9984, device='cuda:1'),
#               3682: tensor(0.9984, device='cuda:1')},
#              '7488': {19174: tensor(0.3840, device='cuda:1'),
#               10856: tensor(0.9374, device='cuda:1'),
#               6099: tensor(0.9977, device='cuda:1'),
#               27698: tensor(0.9981, device='cuda:1')},
#              '6784': {16223: tensor(0.9973, device='cuda:1'),
#               27649: tensor(0.9969, device='cuda:1'),
#               21430: tensor(0.9969, device='cuda:1'),
#               10856: tensor(0.3035, device='cuda:1'),
#               25417: tensor(0.8965, device='cuda:1')},
#              '1158': {26306: tensor(0.7383, device='cuda:1'),
#               11864: tensor(0.9986, device='cuda:1'),
#               29425: tensor(0.9986, device='cuda:1'),
#               3682: tensor(0.9986, device='cuda:1'),
#               7875: tensor(0.9986, device='cuda:1'),
#               19430: tensor(0.7383, device='cuda:1')},
#              '16142': {16506: tensor(0.9987, device='cuda:1')},
#              '2910': {12533: tensor(0.7125, device='cuda:1'),
#               3067: tensor(0.9959, device='cuda:1'),
#               19174: tensor(0.9930, device='cuda:1')},
#              '16398': {19174: tensor(0.5684, device='cuda:1'),
#               3682: tensor(0.9887, device='cuda:1')},
#              '15504': {19174: tensor(0.8267, device='cuda:1'),
#               25858: tensor(0.9987, device='cuda:1'),
#               16223: tensor(0.9949, device='cuda:1')},
#              '8911': {10535: tensor(0.9914, device='cuda:1'),
#               3369: tensor(0.1407, device='cuda:1'),
#               13332: tensor(0.5522, device='cuda:1'),
#               25726: tensor(0.5522, device='cuda:1')},
#              '19275': {20183: tensor(0.9944, device='cuda:1'),
#               12533: tensor(0.9985, device='cuda:1'),
#               19174: tensor(0.5473, device='cuda:1'),
#               19018: tensor(0.9985, device='cuda:1'),
#               17192: tensor(0.3014, device='cuda:1'),
#               1034: tensor(0.3014, device='cuda:1')},
#              '4738': {29787: tensor(0.4906, device='cuda:1'),
#               14135: tensor(0.4906, device='cuda:1'),
#               16223: tensor(0.4906, device='cuda:1'),
#               25858: tensor(0.9977, device='cuda:1')},
#              '1791': {15264: tensor(0.9958, device='cuda:1')},
#              '9287': {25417: tensor(0.2782, device='cuda:1'),
#               13617: tensor(0.9977, device='cuda:1'),
#               3682: tensor(0.4051, device='cuda:1'),
#               29425: tensor(0.9977, device='cuda:1'),
#               26306: tensor(0.9977, device='cuda:1')},
#              '16586': {3812: tensor(0.9992, device='cuda:1'),
#               26306: tensor(0.9643, device='cuda:1'),
#               25107: tensor(0.9643, device='cuda:1'),
#               19174: tensor(0.9643, device='cuda:1'),
#               7491: tensor(0.9223, device='cuda:1'),
#               15083: tensor(0.9504, device='cuda:1'),
#               3828: tensor(0.9504, device='cuda:1'),
#               12533: tensor(0.9504, device='cuda:1')},
#              '10552': {26306: tensor(0.9982, device='cuda:1'),
#               12533: tensor(0.9918, device='cuda:1')},
#              '17310': {12533: tensor(0.0279, device='cuda:1'),
#               15264: tensor(0.9964, device='cuda:1'),
#               3682: tensor(0.9682, device='cuda:1')},
#              '14376': {16223: tensor(0.0853, device='cuda:1'),
#               26306: tensor(0.9979, device='cuda:1'),
#               5251: tensor(0.9979, device='cuda:1'),
#               2115: tensor(0.9979, device='cuda:1'),
#               3828: tensor(0.9979, device='cuda:1'),
#               4028: tensor(0.9979, device='cuda:1'),
#               1925: tensor(0.0409, device='cuda:1')},
#              '18196': {5251: tensor(0.9971, device='cuda:1'),
#               4508: tensor(0.9989, device='cuda:1'),
#               3682: tensor(0.9954, device='cuda:1'),
#               12533: tensor(0.9990, device='cuda:1'),
#               8726: tensor(0.0919, device='cuda:1'),
#               19174: tensor(0.1482, device='cuda:1')},
#              '11974': {10196: tensor(0.9902, device='cuda:1'),
#               29336: tensor(0.9989, device='cuda:1'),
#               29787: tensor(0.9989, device='cuda:1'),
#               7952: tensor(0.9977, device='cuda:1'),
#               16223: tensor(0.9977, device='cuda:1'),
#               26059: tensor(0.9356, device='cuda:1'),
#               16507: tensor(0.9988, device='cuda:1')},
#              '10189': {14135: tensor(0.9981, device='cuda:1'),
#               29407: tensor(0.9982, device='cuda:1')},
#              '6778': {5251: tensor(0.9872, device='cuda:1'),
#               26306: tensor(0.9782, device='cuda:1'),
#               17897: tensor(0.9927, device='cuda:1')},
#              '10384': {6138: tensor(0.0626, device='cuda:1'),
#               607: tensor(0.9138, device='cuda:1'),
#               5505: tensor(0.9974, device='cuda:1'),
#               12533: tensor(0.9974, device='cuda:1'),
#               28551: tensor(0.9974, device='cuda:1'),
#               1865: tensor(0.9013, device='cuda:1')},
#              '3949': {3682: tensor(0.6661, device='cuda:1'),
#               16223: tensor(0.6661, device='cuda:1'),
#               26306: tensor(0.3406, device='cuda:1'),
#               19174: tensor(0.9921, device='cuda:1')},
#              '12249': {12533: tensor(0.8045, device='cuda:1')},
#              '11970': {7952: tensor(0.9989, device='cuda:1'),
#               26306: tensor(0.9989, device='cuda:1'),
#               16507: tensor(0.9987, device='cuda:1'),
#               19174: tensor(0.9964, device='cuda:1'),
#               16223: tensor(0.9977, device='cuda:1')},
#              '14370': {2115: tensor(0.9889, device='cuda:1'),
#               12533: tensor(0.0704, device='cuda:1'),
#               25417: tensor(0.9889, device='cuda:1'),
#               21700: tensor(0.9889, device='cuda:1')},
#              '19129': {20066: tensor(0.9976, device='cuda:1'),
#               20816: tensor(0.0462, device='cuda:1'),
#               20183: tensor(0.0462, device='cuda:1'),
#               26244: tensor(0.9976, device='cuda:1'),
#               27698: tensor(0.5963, device='cuda:1'),
#               25417: tensor(0.5167, device='cuda:1'),
#               26306: tensor(0.9881, device='cuda:1')},
#              '18765': {20028: tensor(0.5921, device='cuda:1'),
#               16223: tensor(0.9982, device='cuda:1')},
#              '9439': {26306: tensor(0.9336, device='cuda:1')},
#              '2632': {12533: tensor(0.8008, device='cuda:1'),
#               17296: tensor(0.9972, device='cuda:1')},
#              '2805': {5396: tensor(0.9988, device='cuda:1'),
#               26306: tensor(0.9172, device='cuda:1'),
#               5251: tensor(0.9172, device='cuda:1'),
#               27335: tensor(0.9984, device='cuda:1'),
#               8828: tensor(0.9976, device='cuda:1'),
#               29787: tensor(0.9172, device='cuda:1')},
#              '2716': {3682: tensor(0.3529, device='cuda:1'),
#               12533: tensor(0.7834, device='cuda:1'),
#               19174: tensor(0.7834, device='cuda:1'),
#               18112: tensor(0.8567, device='cuda:1'),
#               28551: tensor(0.8567, device='cuda:1'),
#               24528: tensor(0.8567, device='cuda:1'),
#               3828: tensor(0.8567, device='cuda:1'),
#               2558: tensor(0.8567, device='cuda:1')},
#              '5197': {12533: tensor(0.9945, device='cuda:1'),
#               16223: tensor(0.9973, device='cuda:1')},
#              '6058': {3682: tensor(0.9979, device='cuda:1'),
#               7432: tensor(0.9888, device='cuda:1'),
#               29040: tensor(0.9888, device='cuda:1')},
#              '19628': {29787: tensor(0.0941, device='cuda:1'),
#               21083: tensor(0.0941, device='cuda:1'),
#               20028: tensor(0.0941, device='cuda:1'),
#               15083: tensor(0.9397, device='cuda:1'),
#               3496: tensor(0.9990, device='cuda:1'),
#               19018: tensor(0.9769, device='cuda:1'),
#               12533: tensor(0.9769, device='cuda:1'),
#               19174: tensor(0.9769, device='cuda:1')},
#              '14774': {16223: tensor(0.9977, device='cuda:1')},
#              '15898': {16223: tensor(0.9973, device='cuda:1'),
#               17897: tensor(0.4014, device='cuda:1'),
#               2115: tensor(0.9987, device='cuda:1'),
#               19174: tensor(0.3840, device='cuda:1'),
#               10856: tensor(0.9946, device='cuda:1')},
#              '9827': {12533: tensor(0.9971, device='cuda:1'),
#               21083: tensor(0.6425, device='cuda:1'),
#               17340: tensor(0.6425, device='cuda:1')},
#              '19135': {12533: tensor(0.9620, device='cuda:1'),
#               26306: tensor(0.9981, device='cuda:1'),
#               20028: tensor(0.4499, device='cuda:1'),
#               1925: tensor(0.9781, device='cuda:1')},
#              '15963': {21435: tensor(0.9986, device='cuda:1'),
#               19174: tensor(0.9974, device='cuda:1'),
#               1865: tensor(0.9937, device='cuda:1'),
#               20028: tensor(0.9937, device='cuda:1'),
#               26306: tensor(0.9929, device='cuda:1'),
#               3682: tensor(0.2948, device='cuda:1'),
#               20183: tensor(0.9974, device='cuda:1'),
#               2115: tensor(0.9985, device='cuda:1'),
#               1925: tensor(0.9929, device='cuda:1'),
#               15839: tensor(0.9929, device='cuda:1'),
#               24942: tensor(0.9985, device='cuda:1')},
#              '7525': {19174: tensor(0.4214, device='cuda:1'),
#               25417: tensor(0.2307, device='cuda:1'),
#               1925: tensor(0.2307, device='cuda:1'),
#               17340: tensor(0.9883, device='cuda:1'),
#               607: tensor(0.9883, device='cuda:1'),
#               12533: tensor(0.4214, device='cuda:1')},
#              '16424': {29425: tensor(0.9956, device='cuda:1'),
#               6696: tensor(0.9985, device='cuda:1'),
#               2558: tensor(0.9975, device='cuda:1'),
#               26306: tensor(0.9975, device='cuda:1')},
#              '2828': {16223: tensor(0.9988, device='cuda:1')},
#              '9157': {29407: tensor(0.9278, device='cuda:1'),
#               16506: tensor(0.4594, device='cuda:1')},
#              '11299': {11240: tensor(0.9982, device='cuda:1'),
#               3369: tensor(0.7181, device='cuda:1'),
#               18488: tensor(0.9987, device='cuda:1')},
#              '18552': {16223: tensor(0.9799, device='cuda:1'),
#               19174: tensor(0.9937, device='cuda:1')},
#              '16539': {18320: tensor(0.9107, device='cuda:1'),
#               13573: tensor(0.2167, device='cuda:1'),
#               24151: tensor(0.2167, device='cuda:1'),
#               14662: tensor(0.6357, device='cuda:1'),
#               22353: tensor(0.9974, device='cuda:1'),
#               25319: tensor(0.6382, device='cuda:1')},
#              '5327': {17489: tensor(0.9521, device='cuda:1'),
#               8750: tensor(0.0234, device='cuda:1')},
#              '13821': {2115: tensor(0.9981, device='cuda:1'),
#               3682: tensor(0.6783, device='cuda:1'),
#               5251: tensor(0.6783, device='cuda:1'),
#               19174: tensor(0.6783, device='cuda:1'),
#               17067: tensor(0.6783, device='cuda:1'),
#               15839: tensor(0.6783, device='cuda:1'),
#               21083: tensor(0.9895, device='cuda:1')},
#              '8609': {3828: tensor(0.7500, device='cuda:1'),
#               21083: tensor(0.9981, device='cuda:1')},
#              '8316': {16223: tensor(0.9600, device='cuda:1'),
#               19724: tensor(0.9962, device='cuda:1')},
#              '5570': {3828: tensor(0.1243, device='cuda:1'),
#               26306: tensor(0.9982, device='cuda:1'),
#               3682: tensor(0.9982, device='cuda:1'),
#               16223: tensor(0.9982, device='cuda:1')},
#              '9053': {21083: tensor(0.9798, device='cuda:1'),
#               26306: tensor(0.9991, device='cuda:1')},
#              '16200': {29310: tensor(0.9811, device='cuda:1'),
#               29425: tensor(0.5068, device='cuda:1')},
#              '7395': {1455: tensor(0.7310, device='cuda:1'),
#               15474: tensor(0.8915, device='cuda:1'),
#               19174: tensor(0.8915, device='cuda:1')},
#              '16913': {25858: tensor(0.4316, device='cuda:1'),
#               25726: tensor(0.4329, device='cuda:1'),
#               26306: tensor(0.5573, device='cuda:1'),
#               3682: tensor(0.5573, device='cuda:1'),
#               21435: tensor(0.5573, device='cuda:1')},
#              '9573': {25417: tensor(0.2190, device='cuda:1'),
#               21030: tensor(0.9955, device='cuda:1')},
#              '17140': {1717: tensor(0.9875, device='cuda:1'),
#               12631: tensor(0.9927, device='cuda:1'),
#               30178: tensor(0.9973, device='cuda:1'),
#               16506: tensor(0.6995, device='cuda:1'),
#               26306: tensor(0.8599, device='cuda:1'),
#               29407: tensor(0.8599, device='cuda:1'),
#               12533: tensor(0.9875, device='cuda:1'),
#               25895: tensor(0.8599, device='cuda:1'),
#               25731: tensor(0.9696, device='cuda:1'),
#               23189: tensor(0.9978, device='cuda:1'),
#               20028: tensor(0.7935, device='cuda:1')},
#              '13685': {21083: tensor(0.9082, device='cuda:1'),
#               26306: tensor(0.9779, device='cuda:1'),
#               3491: tensor(0.2258, device='cuda:1'),
#               16223: tensor(0.9681, device='cuda:1'),
#               15264: tensor(0.9681, device='cuda:1'),
#               12570: tensor(0.9681, device='cuda:1')},
#              '11855': {16223: tensor(0.0474, device='cuda:1'),
#               10856: tensor(0.9820, device='cuda:1')},
#              '518': {16223: tensor(0.9137, device='cuda:1'),
#               1925: tensor(0.9985, device='cuda:1'),
#               19018: tensor(0.7897, device='cuda:1'),
#               25107: tensor(0.7897, device='cuda:1')},
#              '18214': {19174: tensor(0.9987, device='cuda:1'),
#               16223: tensor(0.9988, device='cuda:1'),
#               20028: tensor(0.9988, device='cuda:1'),
#               15091: tensor(0.9978, device='cuda:1'),
#               27619: tensor(0.9952, device='cuda:1'),
# ...
#               16506: tensor(0.9815, device='cuda:1'),
#               1925: tensor(0.9815, device='cuda:1')},
#              '12121': {19174: tensor(0.5473, device='cuda:1'),
#               16223: tensor(0.9952, device='cuda:1'),
#               3616: tensor(0.9988, device='cuda:1'),
#               16507: tensor(0.9347, device='cuda:1'),
#               26306: tensor(0.9952, device='cuda:1'),
#               7952: tensor(0.9600, device='cuda:1')},
#              '7863': {19174: tensor(0.2176, device='cuda:1'),
#               26306: tensor(0.0440, device='cuda:1'),
#               26229: tensor(0.7151, device='cuda:1'),
#               21083: tensor(0.0218, device='cuda:1'),
#               15912: tensor(0.9986, device='cuda:1'),
#               3812: tensor(0.1936, device='cuda:1'),
#               25417: tensor(0.9972, device='cuda:1'),
#               19299: tensor(0.0440, device='cuda:1'),
#               7693: tensor(0.5650, device='cuda:1'),
#               28890: tensor(0.0440, device='cuda:1'),
#               20028: tensor(0.0440, device='cuda:1'),
#               1925: tensor(0.5650, device='cuda:1')},
#              '2915': {3067: tensor(0.9984, device='cuda:1'),
#               27335: tensor(0.9984, device='cuda:1'),
#               18344: tensor(0.9850, device='cuda:1'),
#               20028: tensor(0.9977, device='cuda:1'),
#               12533: tensor(0.9151, device='cuda:1')},
#              '15540': {26306: tensor(0.9984, device='cuda:1'),
#               8509: tensor(0.9984, device='cuda:1'),
#               20028: tensor(0.7941, device='cuda:1')},
#              '4867': {25155: tensor(0.6722, device='cuda:1'),
#               11617: tensor(0.0615, device='cuda:1'),
#               16223: tensor(0.0615, device='cuda:1'),
#               24790: tensor(0.6544, device='cuda:1'),
#               26306: tensor(0.9976, device='cuda:1'),
#               19018: tensor(0.9471, device='cuda:1')},
#              '2771': {19174: tensor(0.6845, device='cuda:1'),
#               8828: tensor(0.9649, device='cuda:1')},
#              '17176': {3369: tensor(0.9901, device='cuda:1'),
#               24790: tensor(0.9978, device='cuda:1'),
#               16223: tensor(0.9978, device='cuda:1')},
#              '16818': {20066: tensor(0.9984, device='cuda:1')},
#              '15931': {12533: tensor(0.9857, device='cuda:1'),
#               1439: tensor(0.9986, device='cuda:1')},
#              '19901': {19174: tensor(0.5473, device='cuda:1'),
#               3491: tensor(0.9989, device='cuda:1'),
#               21083: tensor(0.9983, device='cuda:1')},
#              '10179': {2115: tensor(0.9982, device='cuda:1'),
#               12533: tensor(0.9986, device='cuda:1')},
#              '15878': {20183: tensor(0.9858, device='cuda:1'),
#               16223: tensor(0.9723, device='cuda:1'),
#               19174: tensor(0.4373, device='cuda:1')},
#              '9117': {16223: tensor(0.2762, device='cuda:1'),
#               25731: tensor(0.9983, device='cuda:1'),
#               20028: tensor(0.2762, device='cuda:1')},
#              '11804': {12533: tensor(0.9928, device='cuda:1'),
#               3369: tensor(0.2380, device='cuda:1'),
#               29425: tensor(0.9969, device='cuda:1'),
#               6441: tensor(0.9969, device='cuda:1'),
#               20028: tensor(0.9976, device='cuda:1')},
#              '7560': {15264: tensor(0.9935, device='cuda:1'),
#               25858: tensor(0.9935, device='cuda:1'),
#               11012: tensor(0.9935, device='cuda:1'),
#               19174: tensor(0.9935, device='cuda:1'),
#               7433: tensor(0.9935, device='cuda:1'),
#               3342: tensor(0.9935, device='cuda:1'),
#               15259: tensor(0.9935, device='cuda:1'),
#               22900: tensor(0.9767, device='cuda:1')},
#              '4857': {8126: tensor(0.7446, device='cuda:1'),
#               15694: tensor(0.7446, device='cuda:1'),
#               16223: tensor(0.9832, device='cuda:1'),
#               8828: tensor(0.9866, device='cuda:1'),
#               10856: tensor(0.9832, device='cuda:1')},
#              '10029': {19174: tensor(0.9986, device='cuda:1'),
#               16730: tensor(0.7071, device='cuda:1'),
#               17340: tensor(0.7071, device='cuda:1'),
#               16223: tensor(0.8360, device='cuda:1'),
#               21083: tensor(0.0300, device='cuda:1'),
#               12570: tensor(0.9892, device='cuda:1'),
#               19596: tensor(0.9892, device='cuda:1'),
#               10238: tensor(0.9892, device='cuda:1'),
#               25417: tensor(0.7663, device='cuda:1')},
#              '7826': {19174: tensor(0.9924, device='cuda:1'),
#               6642: tensor(0.9985, device='cuda:1'),
#               10055: tensor(0.9976, device='cuda:1')},
#              '7575': {8589: tensor(0.9973, device='cuda:1'),
#               21083: tensor(0.9975, device='cuda:1'),
#               10856: tensor(0.9878, device='cuda:1'),
#               26338: tensor(0.8016, device='cuda:1')},
#              '6019': {10856: tensor(0.6585, device='cuda:1')},
#              '8797': {26306: tensor(0.9981, device='cuda:1'),
#               13966: tensor(0.9981, device='cuda:1'),
#               12533: tensor(0.9624, device='cuda:1'),
#               19174: tensor(0.9943, device='cuda:1')},
#              '1958': {26306: tensor(0.9980, device='cuda:1'),
#               12631: tensor(0.6832, device='cuda:1'),
#               1925: tensor(0.3379, device='cuda:1')},
#              '17106': {26306: tensor(0.9988, device='cuda:1'),
#               16223: tensor(0.9988, device='cuda:1'),
#               2115: tensor(0.1387, device='cuda:1'),
#               17579: tensor(0.5294, device='cuda:1')},
#              '12805': {2115: tensor(0.3203, device='cuda:1'),
#               7491: tensor(0.9983, device='cuda:1')},
#              '10252': {26306: tensor(0.9978, device='cuda:1'),
#               25858: tensor(0.9978, device='cuda:1'),
#               24790: tensor(0.9978, device='cuda:1'),
#               16223: tensor(0.9956, device='cuda:1')},
#              '957': {16223: tensor(0.5488, device='cuda:1'),
#               26306: tensor(0.9980, device='cuda:1'),
#               27001: tensor(0.9990, device='cuda:1'),
#               15264: tensor(0.5488, device='cuda:1'),
#               3881: tensor(0.5488, device='cuda:1'),
#               23209: tensor(0.9976, device='cuda:1'),
#               28621: tensor(0.9976, device='cuda:1')},
#              '6240': {20183: tensor(0.3773, device='cuda:1'),
#               26306: tensor(0.9982, device='cuda:1')},
#              '18315': {19174: tensor(0.0737, device='cuda:1'),
#               980: tensor(0.9979, device='cuda:1'),
#               1925: tensor(0.9979, device='cuda:1'),
#               25417: tensor(0.6408, device='cuda:1'),
#               25107: tensor(0.6408, device='cuda:1'),
#               20028: tensor(0.9919, device='cuda:1')},
#              '1554': {19174: tensor(0.9954, device='cuda:1'),
#               16223: tensor(0.9878, device='cuda:1')},
#              '1895': {3682: tensor(0.9948, device='cuda:1'),
#               8589: tensor(0.9989, device='cuda:1'),
#               8726: tensor(0.9989, device='cuda:1')},
#              '5160': {26306: tensor(0.9974, device='cuda:1'),
#               2115: tensor(0.4537, device='cuda:1'),
#               12631: tensor(0.4537, device='cuda:1')},
#              '9873': {7952: tensor(0.9101, device='cuda:1'),
#               1925: tensor(0.9101, device='cuda:1'),
#               22254: tensor(0.9101, device='cuda:1')},
#              '19536': {25417: tensor(0.3597, device='cuda:1'),
#               20183: tensor(0.9988, device='cuda:1'),
#               16785: tensor(0.9287, device='cuda:1')},
#              '4533': {12246: tensor(0.9988, device='cuda:1'),
#               8828: tensor(0.9084, device='cuda:1'),
#               16223: tensor(0.9084, device='cuda:1'),
#               10856: tensor(0.9964, device='cuda:1')},
#              '18363': {20028: tensor(0.9954, device='cuda:1'),
#               26306: tensor(0.9959, device='cuda:1'),
#               19018: tensor(0.9954, device='cuda:1'),
#               25107: tensor(0.9954, device='cuda:1'),
#               12533: tensor(0.9954, device='cuda:1'),
#               19174: tensor(0.8969, device='cuda:1')},
#              '5229': {19174: tensor(0.9566, device='cuda:1'),
#               5894: tensor(0.9566, device='cuda:1'),
#               24645: tensor(0.9665, device='cuda:1'),
#               12533: tensor(0.9665, device='cuda:1'),
#               1286: tensor(0.9665, device='cuda:1')},
#              '2666': {11866: tensor(0.9940, device='cuda:1'),
#               15839: tensor(0.1312, device='cuda:1')},
#              '11961': {16223: tensor(0.9988, device='cuda:1'),
#               19174: tensor(0.9793, device='cuda:1'),
#               25155: tensor(0.8356, device='cuda:1')},
#              '6195': {12533: tensor(0.9981, device='cuda:1'),
#               29787: tensor(0.9098, device='cuda:1')},
#              '3018': {7432: tensor(0.7510, device='cuda:1'),
#               26306: tensor(0.9951, device='cuda:1'),
#               19174: tensor(0.9951, device='cuda:1')},
#              '736': {21083: tensor(0.9549, device='cuda:1'),
#               3369: tensor(0.7679, device='cuda:1'),
#               26971: tensor(0.9215, device='cuda:1'),
#               16223: tensor(0.9941, device='cuda:1')},
#              '16957': {4665: tensor(0.5884, device='cuda:1'),
#               5024: tensor(0.9983, device='cuda:1'),
#               5332: tensor(0.9983, device='cuda:1'),
#               24924: tensor(0.9012, device='cuda:1'),
#               1772: tensor(0.1226, device='cuda:1'),
#               6539: tensor(0.9976, device='cuda:1'),
#               25054: tensor(0.9976, device='cuda:1')},
#              '5674': {16223: tensor(0.9974, device='cuda:1'),
#               16394: tensor(0.9985, device='cuda:1'),
#               28687: tensor(0.9987, device='cuda:1')},
#              '10369': {3828: tensor(0.9979, device='cuda:1')},
#              '6652': {25417: tensor(0.9949, device='cuda:1'),
#               23189: tensor(0.9981, device='cuda:1'),
#               16223: tensor(0.2310, device='cuda:1')},
#              '16511': {19174: tensor(0.1740, device='cuda:1'),
#               3682: tensor(0.9682, device='cuda:1'),
#               12246: tensor(0.0379, device='cuda:1'),
#               16223: tensor(0.9682, device='cuda:1'),
#               12533: tensor(0.9700, device='cuda:1'),
#               8509: tensor(0.9700, device='cuda:1')},
#              '18143': {11866: tensor(0.1152, device='cuda:1'),
#               26893: tensor(0.9968, device='cuda:1'),
#               16223: tensor(0.6165, device='cuda:1'),
#               26306: tensor(0.9968, device='cuda:1')},
#              '9160': {24472: tensor(0.9977, device='cuda:1'),
#               25858: tensor(0.9977, device='cuda:1'),
#               8828: tensor(0.9902, device='cuda:1')},
#              '15801': {25417: tensor(0.7083, device='cuda:1'),
#               15474: tensor(0.7083, device='cuda:1'),
#               25107: tensor(0.9892, device='cuda:1'),
#               1925: tensor(0.4067, device='cuda:1'),
#               20183: tensor(0.4067, device='cuda:1')},
#              '19439': {8426: tensor(0.9980, device='cuda:1'),
#               26306: tensor(0.9980, device='cuda:1'),
#               21083: tensor(0.9980, device='cuda:1'),
#               13617: tensor(0.9977, device='cuda:1')},
#              '8620': {6192: tensor(0.9953, device='cuda:1'),
#               12570: tensor(0.9823, device='cuda:1'),
#               16223: tensor(0.9906, device='cuda:1'),
#               29612: tensor(0.9906, device='cuda:1')},
#              '10181': {20028: tensor(0.9988, device='cuda:1'),
#               15083: tensor(0.9984, device='cuda:1')},
#              '6812': {12533: tensor(0.6262, device='cuda:1'),
#               26306: tensor(0.9982, device='cuda:1')},
#              '12643': {19174: tensor(0.9975, device='cuda:1'),
#               26306: tensor(0.9956, device='cuda:1'),
#               16223: tensor(0.9956, device='cuda:1')},
#              '19277': {16223: tensor(0.9972, device='cuda:1'),
#               8649: tensor(0.9972, device='cuda:1'),
#               11235: tensor(0.8567, device='cuda:1'),
#               20578: tensor(0.9311, device='cuda:1'),
#               19174: tensor(0.9311, device='cuda:1'),
#               17698: tensor(0.0987, device='cuda:1')},
#              '2431': {12533: tensor(0.9127, device='cuda:1'),
#               16223: tensor(0.8768, device='cuda:1')},
#              '4529': {16223: tensor(0.9920, device='cuda:1'),
#               16507: tensor(0.1811, device='cuda:1'),
#               25858: tensor(0.9979, device='cuda:1'),
#               3491: tensor(0.9981, device='cuda:1')},
#              '10408': {19174: tensor(0.9617, device='cuda:1'),
#               12205: tensor(0.3071, device='cuda:1'),
#               5251: tensor(0.5951, device='cuda:1'),
#               12533: tensor(0.5951, device='cuda:1'),
#               28551: tensor(0.5951, device='cuda:1')},
#              '582': {21700: tensor(0.9954, device='cuda:1'),
#               4215: tensor(0.9954, device='cuda:1'),
#               22353: tensor(0.0162, device='cuda:1'),
#               25858: tensor(0.9984, device='cuda:1'),
#               14190: tensor(0.9984, device='cuda:1')},
#              '16402': {16223: tensor(0.9973, device='cuda:1'),
#               12533: tensor(0.9965, device='cuda:1'),
#               8509: tensor(0.9963, device='cuda:1'),
#               19174: tensor(0.9973, device='cuda:1'),
#               7822: tensor(0.1965, device='cuda:1'),
#               25107: tensor(0.9963, device='cuda:1')},
#              '13972': {12533: tensor(0.8244, device='cuda:1'),
#               2115: tensor(0.9978, device='cuda:1')},
#              '7614': {25417: tensor(0.7086, device='cuda:1'),
#               19174: tensor(0.0893, device='cuda:1')},
#              '9565': {12533: tensor(0.9774, device='cuda:1'),
#               13332: tensor(0.9774, device='cuda:1'),
#               27714: tensor(0.9988, device='cuda:1'),
#               1717: tensor(0.9988, device='cuda:1')},
#              '14224': {13819: tensor(0.5556, device='cuda:1'),
#               7432: tensor(0.8695, device='cuda:1'),
#               29787: tensor(0.9987, device='cuda:1'),
#               21700: tensor(0.9987, device='cuda:1'),
#               26306: tensor(0.9473, device='cuda:1')},
#              '10648': {19174: tensor(0.9953, device='cuda:1'),
#               17985: tensor(0.9988, device='cuda:1'),
#               16482: tensor(0.9988, device='cuda:1'),
#               19238: tensor(0.9988, device='cuda:1'),
#               27335: tensor(0.9988, device='cuda:1'),
#               29192: tensor(0.9988, device='cuda:1'),
#               13991: tensor(0.9988, device='cuda:1'),
#               8073: tensor(0.9988, device='cuda:1'),
#               21862: tensor(0.9988, device='cuda:1'),
#               8076: tensor(0.9988, device='cuda:1'),
#               8396: tensor(0.9988, device='cuda:1'),
#               16620: tensor(0.9988, device='cuda:1'),
#               18608: tensor(0.9988, device='cuda:1'),
#               25107: tensor(0.9988, device='cuda:1'),
#               26740: tensor(0.9988, device='cuda:1'),
#               30423: tensor(0.9988, device='cuda:1'),
#               13496: tensor(0.9988, device='cuda:1'),
#               9497: tensor(0.9988, device='cuda:1'),
#               19018: tensor(0.9496, device='cuda:1'),
#               12533: tensor(0.9981, device='cuda:1')},
#              '10257': {26306: tensor(0.9986, device='cuda:1'),
#               19174: tensor(0.9978, device='cuda:1'),
#               20066: tensor(0.9983, device='cuda:1'),
#               29425: tensor(0.9986, device='cuda:1'),
#               26039: tensor(0.9643, device='cuda:1')},
#              '5233': {16620: tensor(0.9985, device='cuda:1'),
#               3369: tensor(0.4348, device='cuda:1'),
#               25155: tensor(0.0541, device='cuda:1'),
#               18670: tensor(0.9984, device='cuda:1')},
#              '411': {12533: tensor(0.9973, device='cuda:1'),
#               26306: tensor(0.3068, device='cuda:1')},
#              '8207': {16223: tensor(0.6086, device='cuda:1'),
#               27619: tensor(0.9982, device='cuda:1'),
#               19174: tensor(0.9909, device='cuda:1')},
#              ...})

# %%
# Assuming ent_sent is your dictionary
for conv_id, entities in train_ent_sent.items():
    for entity_id, sent_score in entities.items():
        print(f"Conv ID: {conv_id}, Entity ID: {entity_id}, requires_grad: {sent_score.requires_grad}")
        # You can break or continue based on your needs
        break  # This breaks out of the inner loop
    break  # This breaks out of the outer loop
# Out:
# Conv ID: 19429, Entity ID: 19174, requires_grad: False

# %%
train_ent_sent
# Out:
# defaultdict(dict,
#             {'19429': {19174: tensor(0.9981, device='cuda:1')},
#              '8618': {3682: tensor(0.9941, device='cuda:1'),
#               8828: tensor(0.9941, device='cuda:1'),
#               12533: tensor(0.9917, device='cuda:1'),
#               7822: tensor(0.9917, device='cuda:1'),
#               26306: tensor(0.9946, device='cuda:1')},
#              '16534': {13573: tensor(0.8968, device='cuda:1'),
#               6696: tensor(0.9980, device='cuda:1')},
#              '13724': {2115: tensor(0.9981, device='cuda:1'),
#               3812: tensor(0.9968, device='cuda:1'),
#               20028: tensor(0.9981, device='cuda:1'),
#               19174: tensor(0.9981, device='cuda:1'),
#               26306: tensor(0.9979, device='cuda:1'),
#               5251: tensor(0.9979, device='cuda:1'),
#               3828: tensor(0.9979, device='cuda:1'),
#               4028: tensor(0.9979, device='cuda:1')},
#              '17100': {25417: tensor(0.9767, device='cuda:1'),
#               2115: tensor(0.9855, device='cuda:1'),
#               12533: tensor(0.9927, device='cuda:1'),
#               21083: tensor(0.9898, device='cuda:1'),
#               20028: tensor(0.9788, device='cuda:1'),
#               19174: tensor(0.9788, device='cuda:1'),
#               1865: tensor(0.9767, device='cuda:1'),
#               1925: tensor(0.9767, device='cuda:1')},
#              '17813': {15812: tensor(0.9953, device='cuda:1'),
#               19174: tensor(0.9969, device='cuda:1')},
#              '10905': {19174: tensor(0.9930, device='cuda:1')},
#              '8072': {9258: tensor(0.9969, device='cuda:1'),
#               19174: tensor(0.9977, device='cuda:1'),
#               16223: tensor(0.9983, device='cuda:1')},
#              '19603': {5251: tensor(0.9971, device='cuda:1'),
#               24745: tensor(0.9876, device='cuda:1'),
#               30185: tensor(0.9876, device='cuda:1'),
#               25417: tensor(0.9940, device='cuda:1'),
#               28626: tensor(0.9929, device='cuda:1'),
#               3828: tensor(0.9819, device='cuda:1'),
#               1865: tensor(0.9966, device='cuda:1')},
#              '11902': {26306: tensor(0.9989, device='cuda:1')},
#              '2924': {15264: tensor(0.9988, device='cuda:1'),
#               12533: tensor(0.9988, device='cuda:1'),
#               25107: tensor(0.9987, device='cuda:1'),
#               30380: tensor(0.9974, device='cuda:1'),
#               2558: tensor(0.9937, device='cuda:1')},
#              '3734': {10856: tensor(0.9355, device='cuda:1'),
#               14359: tensor(0.9954, device='cuda:1'),
#               9786: tensor(0.9938, device='cuda:1'),
#               8589: tensor(0.9938, device='cuda:1')},
#              '484': {16223: tensor(0.9733, device='cuda:1'),
#               26306: tensor(0.9974, device='cuda:1'),
#               15171: tensor(0.9961, device='cuda:1'),
#               12533: tensor(0.9972, device='cuda:1')},
#              '10975': {16507: tensor(0.9988, device='cuda:1'),
#               7952: tensor(0.9987, device='cuda:1')},
#              '15425': {10856: tensor(0.9962, device='cuda:1')},
#              '10862': {16223: tensor(0.9864, device='cuda:1'),
#               17144: tensor(0.8053, device='cuda:1'),
#               22497: tensor(0.8053, device='cuda:1'),
#               15070: tensor(0.8053, device='cuda:1')},
#              '6128': {26306: tensor(0.9982, device='cuda:1'),
#               25107: tensor(0.9986, device='cuda:1')},
#              '17376': {8589: tensor(0.9964, device='cuda:1'),
#               15264: tensor(0.9980, device='cuda:1'),
#               26306: tensor(0.9964, device='cuda:1')},
#              '11407': {28551: tensor(0.9871, device='cuda:1'),
#               8848: tensor(0.9688, device='cuda:1'),
#               21083: tensor(0.9688, device='cuda:1'),
#               20028: tensor(0.9688, device='cuda:1'),
#               29787: tensor(0.8901, device='cuda:1')},
#              '17780': {11240: tensor(0.9957, device='cuda:1'),
#               19174: tensor(0.9956, device='cuda:1'),
#               20066: tensor(0.9956, device='cuda:1'),
#               2115: tensor(0.9962, device='cuda:1'),
#               20816: tensor(0.9978, device='cuda:1'),
#               18112: tensor(0.9978, device='cuda:1'),
#               17897: tensor(0.9956, device='cuda:1')},
#              '11817': {3682: tensor(0.9690, device='cuda:1'),
#               19174: tensor(0.9690, device='cuda:1'),
#               16223: tensor(0.9690, device='cuda:1')},
#              '15486': {12533: tensor(0.9915, device='cuda:1'),
#               26306: tensor(0.9974, device='cuda:1')},
#              '3634': {8828: tensor(0.9991, device='cuda:1')},
#              '14866': {19174: tensor(0.9811, device='cuda:1'),
#               25858: tensor(0.9896, device='cuda:1'),
#               16223: tensor(0.9843, device='cuda:1'),
#               26306: tensor(0.9980, device='cuda:1')},
#              '12733': {25417: tensor(0.9967, device='cuda:1')},
#              '9106': {16223: tensor(0.9461, device='cuda:1'),
#               3828: tensor(0.8469, device='cuda:1'),
#               19174: tensor(0.9737, device='cuda:1'),
#               22571: tensor(0.9737, device='cuda:1'),
#               27030: tensor(0.9737, device='cuda:1'),
#               21083: tensor(0.9737, device='cuda:1')},
#              '15824': {19174: tensor(0.9982, device='cuda:1'),
#               12533: tensor(0.9987, device='cuda:1'),
#               26306: tensor(0.9987, device='cuda:1')},
#              '10616': {1925: tensor(0.7566, device='cuda:1'),
#               28149: tensor(0.9902, device='cuda:1'),
#               20183: tensor(0.9950, device='cuda:1'),
#               26306: tensor(0.9839, device='cuda:1'),
#               28026: tensor(0.9839, device='cuda:1'),
#               25417: tensor(0.9845, device='cuda:1')},
#              '7963': {26829: tensor(0.9986, device='cuda:1')},
#              '12185': {25417: tensor(0.9986, device='cuda:1'),
#               25107: tensor(0.9986, device='cuda:1'),
#               12533: tensor(0.9977, device='cuda:1')},
#              '15557': {18874: tensor(0.9955, device='cuda:1'),
#               3682: tensor(0.9123, device='cuda:1')},
#              '6052': {7088: tensor(0.9964, device='cuda:1'),
#               21700: tensor(0.9964, device='cuda:1'),
#               3828: tensor(0.9864, device='cuda:1'),
#               26306: tensor(0.9972, device='cuda:1'),
#               21083: tensor(0.9966, device='cuda:1')},
#              '16252': {2115: tensor(0.9975, device='cuda:1'),
#               19174: tensor(0.9960, device='cuda:1'),
#               18874: tensor(0.9884, device='cuda:1'),
#               28551: tensor(0.9884, device='cuda:1')},
#              '12241': {25417: tensor(0.9944, device='cuda:1'),
#               26306: tensor(0.9986, device='cuda:1')},
#              '18659': {25417: tensor(0.9973, device='cuda:1'),
#               12205: tensor(0.9989, device='cuda:1')},
#              '14187': {28687: tensor(0.9669, device='cuda:1'),
#               15264: tensor(0.9990, device='cuda:1')},
#              '7835': {26306: tensor(0.9989, device='cuda:1'),
#               10856: tensor(0.9920, device='cuda:1'),
#               8828: tensor(0.9986, device='cuda:1'),
#               16223: tensor(0.9986, device='cuda:1')},
#              '3364': {5505: tensor(0.9972, device='cuda:1')},
#              '1216': {20066: tensor(0.9951, device='cuda:1'),
#               4650: tensor(0.9956, device='cuda:1')},
#              '2275': {26306: tensor(0.9963, device='cuda:1'),
#               25107: tensor(0.9963, device='cuda:1'),
#               3812: tensor(0.9963, device='cuda:1'),
#               16506: tensor(0.9977, device='cuda:1'),
#               24180: tensor(0.9522, device='cuda:1')},
#              '13838': {5024: tensor(0.9987, device='cuda:1'),
#               17897: tensor(0.9986, device='cuda:1'),
#               3682: tensor(0.9986, device='cuda:1'),
#               11834: tensor(0.9986, device='cuda:1'),
#               21083: tensor(0.9987, device='cuda:1')},
#              '7690': {15084: tensor(0.9962, device='cuda:1'),
#               24790: tensor(0.9962, device='cuda:1'),
#               15889: tensor(0.9896, device='cuda:1'),
#               9677: tensor(0.9866, device='cuda:1'),
#               5505: tensor(0.9986, device='cuda:1'),
#               19018: tensor(0.9986, device='cuda:1'),
#               9118: tensor(0.9986, device='cuda:1'),
#               1865: tensor(0.9920, device='cuda:1')},
#              '13358': {25417: tensor(0.9979, device='cuda:1'),
#               16223: tensor(0.9973, device='cuda:1'),
#               9133: tensor(0.9983, device='cuda:1'),
#               26306: tensor(0.9977, device='cuda:1')},
#              '1103': {15474: tensor(0.9827, device='cuda:1'),
#               16223: tensor(0.9975, device='cuda:1'),
#               8126: tensor(0.9599, device='cuda:1'),
#               22998: tensor(0.9964, device='cuda:1')},
#              '14794': {16223: tensor(0.9933, device='cuda:1'),
#               19174: tensor(0.9980, device='cuda:1')},
#              '12779': {8828: tensor(0.9981, device='cuda:1'),
#               12533: tensor(0.9910, device='cuda:1')},
#              '10447': {27820: tensor(0.9923, device='cuda:1'),
#               21325: tensor(0.9954, device='cuda:1')},
#              '1754': {26306: tensor(0.9392, device='cuda:1'),
#               13756: tensor(0.9981, device='cuda:1'),
#               8589: tensor(0.9981, device='cuda:1'),
#               12710: tensor(0.9981, device='cuda:1'),
#               20183: tensor(0.9981, device='cuda:1'),
#               29425: tensor(0.9985, device='cuda:1'),
#               13573: tensor(0.9985, device='cuda:1')},
#              '18102': {12533: tensor(0.9904, device='cuda:1'),
#               16223: tensor(0.9904, device='cuda:1'),
#               10856: tensor(0.9979, device='cuda:1'),
#               25858: tensor(0.9959, device='cuda:1')},
#              '9368': {3682: tensor(0.9917, device='cuda:1'),
#               20602: tensor(0.9967, device='cuda:1'),
#               7822: tensor(0.9973, device='cuda:1'),
#               8579: tensor(0.9973, device='cuda:1'),
#               29279: tensor(0.9973, device='cuda:1'),
#               26306: tensor(0.9983, device='cuda:1')},
#              '3757': {12533: tensor(0.9945, device='cuda:1'),
#               16506: tensor(0.9784, device='cuda:1')},
#              '9301': {21083: tensor(0.9958, device='cuda:1'),
#               3828: tensor(0.9823, device='cuda:1')},
#              '6252': {27698: tensor(0.9961, device='cuda:1'),
#               11834: tensor(0.9252, device='cuda:1'),
#               26306: tensor(0.9977, device='cuda:1'),
#               1615: tensor(0.9982, device='cuda:1')},
#              '11003': {17897: tensor(0.9970, device='cuda:1'),
#               7952: tensor(0.9989, device='cuda:1')},
#              '674': {1925: tensor(0.9088, device='cuda:1'),
#               26306: tensor(0.8830, device='cuda:1')},
#              '18677': {17897: tensor(0.9961, device='cuda:1'),
#               22254: tensor(0.9961, device='cuda:1'),
#               16730: tensor(0.9861, device='cuda:1'),
#               3828: tensor(0.9861, device='cuda:1'),
#               26402: tensor(0.9925, device='cuda:1'),
#               7822: tensor(0.9925, device='cuda:1'),
#               24790: tensor(0.9925, device='cuda:1')},
#              '10430': {16223: tensor(0.9986, device='cuda:1')},
#              '6701': {22992: tensor(0.0772, device='cuda:1'),
#               15474: tensor(0.0772, device='cuda:1'),
#               5251: tensor(0.0772, device='cuda:1'),
#               19174: tensor(0.7993, device='cuda:1'),
#               21700: tensor(0.3978, device='cuda:1'),
#               6869: tensor(0.3978, device='cuda:1')},
#              '18477': {28149: tensor(0.9989, device='cuda:1'),
#               25417: tensor(0.9934, device='cuda:1'),
#               21083: tensor(0.9934, device='cuda:1'),
#               19174: tensor(0.8246, device='cuda:1'),
#               16785: tensor(0.9955, device='cuda:1'),
#               26306: tensor(0.9649, device='cuda:1'),
#               12497: tensor(0.9986, device='cuda:1')},
#              '1944': {27708: tensor(0.9988, device='cuda:1'),
#               16620: tensor(0.9904, device='cuda:1'),
#               2558: tensor(0.9904, device='cuda:1'),
#               3369: tensor(0.9981, device='cuda:1')},
#              '18654': {12533: tensor(0.9955, device='cuda:1')},
#              '538': {25417: tensor(0.7476, device='cuda:1'),
#               19174: tensor(0.8798, device='cuda:1'),
#               6862: tensor(0.8798, device='cuda:1'),
#               28551: tensor(0.8798, device='cuda:1'),
#               26306: tensor(0.9947, device='cuda:1')},
#              '18591': {3828: tensor(0.9982, device='cuda:1'),
#               12533: tensor(0.8996, device='cuda:1'),
#               7491: tensor(0.8996, device='cuda:1'),
#               15070: tensor(0.8996, device='cuda:1'),
#               980: tensor(0.9956, device='cuda:1'),
#               13332: tensor(0.9982, device='cuda:1')},
#              '6760': {15171: tensor(0.9978, device='cuda:1'),
#               25858: tensor(0.9983, device='cuda:1'),
#               26306: tensor(0.9985, device='cuda:1'),
#               19018: tensor(0.9980, device='cuda:1')},
#              '8990': {25726: tensor(0.9959, device='cuda:1'),
#               13332: tensor(0.9932, device='cuda:1'),
#               29407: tensor(0.9932, device='cuda:1')},
#              '560': {25858: tensor(0.9984, device='cuda:1'),
#               16223: tensor(0.8919, device='cuda:1'),
#               29961: tensor(0.9981, device='cuda:1')},
#              '2340': {2115: tensor(0.9981, device='cuda:1'),
#               16223: tensor(0.9991, device='cuda:1'),
#               21083: tensor(0.9985, device='cuda:1'),
#               7348: tensor(0.9985, device='cuda:1'),
#               6589: tensor(0.9985, device='cuda:1'),
#               19247: tensor(0.9969, device='cuda:1'),
#               6311: tensor(0.9974, device='cuda:1')},
#              '9859': {1925: tensor(0.9948, device='cuda:1'),
#               25257: tensor(0.9958, device='cuda:1'),
#               12533: tensor(0.9721, device='cuda:1')},
#              '14726': {13835: tensor(0.9335, device='cuda:1')},
#              '3950': {26306: tensor(0.9848, device='cuda:1'),
#               30823: tensor(0.9833, device='cuda:1'),
#               2115: tensor(0.9976, device='cuda:1'),
#               5251: tensor(0.9976, device='cuda:1')},
#              '4938': {25858: tensor(0.9982, device='cuda:1'),
#               28621: tensor(0.9982, device='cuda:1'),
#               22998: tensor(0.9982, device='cuda:1'),
#               26306: tensor(0.9972, device='cuda:1'),
#               16223: tensor(0.9972, device='cuda:1')},
#              '14028': {12570: tensor(0.9862, device='cuda:1'),
#               19454: tensor(0.9862, device='cuda:1'),
#               16223: tensor(0.8867, device='cuda:1'),
#               15264: tensor(0.9893, device='cuda:1')},
#              '12134': {16223: tensor(0.9956, device='cuda:1'),
#               23903: tensor(0.9950, device='cuda:1')},
#              '15973': {13332: tensor(0.9940, device='cuda:1'),
#               12533: tensor(0.9983, device='cuda:1'),
#               20028: tensor(0.9983, device='cuda:1'),
#               5894: tensor(0.9983, device='cuda:1'),
#               19174: tensor(0.9982, device='cuda:1')},
#              '927': {25417: tensor(0.9950, device='cuda:1'),
#               12533: tensor(0.8886, device='cuda:1'),
#               19018: tensor(0.9948, device='cuda:1'),
#               25107: tensor(0.8886, device='cuda:1'),
#               25731: tensor(0.8886, device='cuda:1'),
#               16223: tensor(0.9941, device='cuda:1'),
#               23183: tensor(0.9941, device='cuda:1'),
#               20816: tensor(0.9941, device='cuda:1')},
#              '2785': {25417: tensor(0.9941, device='cuda:1'),
#               19174: tensor(0.9963, device='cuda:1')},
#              '14730': {25858: tensor(0.9966, device='cuda:1'),
#               13835: tensor(0.5545, device='cuda:1'),
#               16223: tensor(0.9148, device='cuda:1')},
#              '17896': {20066: tensor(0.9974, device='cuda:1'),
#               22575: tensor(0.9981, device='cuda:1'),
#               27011: tensor(0.9981, device='cuda:1')},
#              '13482': {20848: tensor(0.9936, device='cuda:1'),
#               12626: tensor(0.9837, device='cuda:1'),
#               25731: tensor(0.9837, device='cuda:1'),
#               1925: tensor(0.9941, device='cuda:1')},
#              '12431': {16507: tensor(0.9971, device='cuda:1')},
#              '11505': {21083: tensor(0.9981, device='cuda:1'),
#               3828: tensor(0.9993, device='cuda:1')},
#              '963': {27698: tensor(0.9915, device='cuda:1'),
#               26306: tensor(0.9986, device='cuda:1'),
#               20066: tensor(0.9915, device='cuda:1'),
#               13093: tensor(0.9984, device='cuda:1'),
#               24748: tensor(0.9986, device='cuda:1'),
#               2613: tensor(0.9986, device='cuda:1'),
#               11866: tensor(0.9986, device='cuda:1'),
#               7580: tensor(0.9986, device='cuda:1'),
#               19487: tensor(0.9986, device='cuda:1'),
#               8878: tensor(0.9985, device='cuda:1'),
#               19174: tensor(0.9984, device='cuda:1')},
#              '14635': {29787: tensor(0.9950, device='cuda:1'),
#               20028: tensor(0.9984, device='cuda:1'),
#               25417: tensor(0.7513, device='cuda:1')},
#              '3961': {10856: tensor(0.9929, device='cuda:1'),
#               19174: tensor(0.9980, device='cuda:1')},
#              '7469': {7959: tensor(0.9986, device='cuda:1'),
#               3682: tensor(0.9961, device='cuda:1'),
#               18308: tensor(0.9979, device='cuda:1')},
#              '8137': {6856: tensor(0.9821, device='cuda:1'),
#               25417: tensor(0.9821, device='cuda:1')},
#              '6931': {26306: tensor(0.9984, device='cuda:1'),
#               25107: tensor(0.9915, device='cuda:1'),
#               12205: tensor(0.9961, device='cuda:1')},
#              '7420': {19018: tensor(0.9972, device='cuda:1'),
#               16394: tensor(0.9972, device='cuda:1'),
#               3682: tensor(0.8443, device='cuda:1'),
#               15812: tensor(0.9963, device='cuda:1'),
#               16223: tensor(0.8443, device='cuda:1')},
#              '11873': {2115: tensor(0.9976, device='cuda:1'),
#               21083: tensor(0.9973, device='cuda:1')},
#              '3124': {5251: tensor(0.9986, device='cuda:1'),
#               11229: tensor(0.9582, device='cuda:1'),
#               19174: tensor(0.9582, device='cuda:1'),
#               8828: tensor(0.7820, device='cuda:1'),
#               26306: tensor(0.9866, device='cuda:1'),
#               10276: tensor(0.4550, device='cuda:1')},
#              '16962': {1685: tensor(0.9490, device='cuda:1'),
#               12246: tensor(0.9739, device='cuda:1'),
#               19174: tensor(0.9451, device='cuda:1'),
#               12533: tensor(0.9786, device='cuda:1')},
#              '791': {3682: tensor(0.9657, device='cuda:1'),
#               19174: tensor(0.9961, device='cuda:1'),
#               29101: tensor(0.9907, device='cuda:1'),
#               5251: tensor(0.8367, device='cuda:1'),
#               1925: tensor(0.8367, device='cuda:1')},
#              '16523': {11240: tensor(0.9911, device='cuda:1'),
#               19174: tensor(0.9945, device='cuda:1'),
#               4986: tensor(0.9942, device='cuda:1'),
#               8263: tensor(0.0381, device='cuda:1')},
#              '8702': {26306: tensor(0.9985, device='cuda:1'),
#               3828: tensor(0.9985, device='cuda:1'),
#               24180: tensor(0.9982, device='cuda:1'),
#               12533: tensor(0.9980, device='cuda:1'),
#               28149: tensor(0.9980, device='cuda:1')},
#              '6534': {16223: tensor(0.8838, device='cuda:1')},
#              '6833': {16223: tensor(0.6846, device='cuda:1')},
#              '3737': {29787: tensor(0.9972, device='cuda:1'),
#               20028: tensor(0.9972, device='cuda:1'),
#               9083: tensor(0.9218, device='cuda:1'),
#               24151: tensor(0.9975, device='cuda:1'),
#               25126: tensor(0.9828, device='cuda:1'),
#               19174: tensor(0.9828, device='cuda:1'),
#               25726: tensor(0.9828, device='cuda:1')},
#              '16129': {12533: tensor(0.9877, device='cuda:1'),
#               21083: tensor(0.9955, device='cuda:1')},
#              '18563': {2653: tensor(0.9976, device='cuda:1'),
#               25107: tensor(0.9972, device='cuda:1'),
#               25721: tensor(0.9959, device='cuda:1')},
#              '12337': {12533: tensor(0.9964, device='cuda:1'),
#               27001: tensor(0.9988, device='cuda:1'),
#               24790: tensor(0.9988, device='cuda:1'),
#               16223: tensor(0.9951, device='cuda:1'),
#               21083: tensor(0.9974, device='cuda:1')},
#              '3164': {3812: tensor(0.9221, device='cuda:1'),
#               21083: tensor(0.6459, device='cuda:1'),
#               20183: tensor(0.6459, device='cuda:1'),
#               18488: tensor(0.9221, device='cuda:1'),
#               12533: tensor(0.9221, device='cuda:1')},
#              '12889': {25858: tensor(0.9987, device='cuda:1'),
#               19174: tensor(0.9967, device='cuda:1'),
#               15070: tensor(0.9967, device='cuda:1')},
#              '13315': {15474: tensor(0.6295, device='cuda:1'),
#               25417: tensor(0.7544, device='cuda:1')},
#              '16573': {15171: tensor(0.9870, device='cuda:1'),
#               12533: tensor(0.9986, device='cuda:1')},
#              '3031': {19174: tensor(0.9974, device='cuda:1'),
#               3682: tensor(0.9963, device='cuda:1')},
#              '10259': {25107: tensor(0.9898, device='cuda:1'),
#               25417: tensor(0.9901, device='cuda:1'),
#               3812: tensor(0.9901, device='cuda:1'),
#               28551: tensor(0.9901, device='cuda:1')},
#              '6461': {16223: tensor(0.9987, device='cuda:1'),
#               19174: tensor(0.9764, device='cuda:1')},
#              '9540': {25726: tensor(0.9988, device='cuda:1'),
#               3682: tensor(0.9988, device='cuda:1')},
#              '11011': {21083: tensor(0.9569, device='cuda:1'),
#               16223: tensor(0.9957, device='cuda:1'),
#               27619: tensor(0.9934, device='cuda:1'),
#               19174: tensor(0.9660, device='cuda:1')},
#              '5710': {19174: tensor(0.9975, device='cuda:1'),
#               12533: tensor(0.9968, device='cuda:1')},
#              '16945': {5332: tensor(0.9976, device='cuda:1'),
#               12533: tensor(0.9958, device='cuda:1'),
#               10953: tensor(0.9958, device='cuda:1'),
#               2558: tensor(0.9958, device='cuda:1'),
#               5894: tensor(0.9958, device='cuda:1')},
#              '2820': {20028: tensor(0.9777, device='cuda:1'),
#               26306: tensor(0.9987, device='cuda:1'),
#               5251: tensor(0.9987, device='cuda:1'),
#               19174: tensor(0.9868, device='cuda:1')},
#              '3545': {7952: tensor(0.9986, device='cuda:1'),
#               20066: tensor(0.9989, device='cuda:1')},
#              '4250': {10856: tensor(0.9796, device='cuda:1'),
#               26306: tensor(0.9989, device='cuda:1')},
#              '8250': {26306: tensor(0.9918, device='cuda:1'),
#               12533: tensor(0.9436, device='cuda:1'),
#               16223: tensor(0.9436, device='cuda:1'),
#               21516: tensor(0.2948, device='cuda:1')},
#              '15519': {8509: tensor(0.9986, device='cuda:1'),
#               7822: tensor(0.9986, device='cuda:1'),
#               8828: tensor(0.9988, device='cuda:1'),
#               12533: tensor(0.9988, device='cuda:1')},
#              '14162': {10856: tensor(0.9799, device='cuda:1'),
#               25858: tensor(0.9954, device='cuda:1'),
#               21083: tensor(0.5720, device='cuda:1')},
#              '17686': {19354: tensor(0.6336, device='cuda:1'),
#               21083: tensor(0.6336, device='cuda:1')},
#              '17151': {17897: tensor(0.9945, device='cuda:1'),
#               26306: tensor(0.9931, device='cuda:1'),
#               19018: tensor(0.9931, device='cuda:1'),
#               19174: tensor(0.9937, device='cuda:1'),
#               17579: tensor(0.9986, device='cuda:1'),
#               19724: tensor(0.9986, device='cuda:1')},
#              '12355': {17897: tensor(0.9416, device='cuda:1')},
#              '12727': {28149: tensor(0.8146, device='cuda:1'),
#               16223: tensor(0.9592, device='cuda:1'),
#               19174: tensor(0.8518, device='cuda:1')},
#              '18324': {26306: tensor(0.9986, device='cuda:1'),
#               28026: tensor(0.9986, device='cuda:1'),
#               12205: tensor(0.9798, device='cuda:1')},
#              '16612': {29787: tensor(0.9636, device='cuda:1'),
#               12533: tensor(0.9985, device='cuda:1'),
#               17579: tensor(0.9849, device='cuda:1'),
#               17340: tensor(0.9849, device='cuda:1'),
#               26829: tensor(0.9849, device='cuda:1')},
#              '19826': {18719: tensor(0.9988, device='cuda:1'),
#               1775: tensor(0.9969, device='cuda:1')},
#              '10903': {26306: tensor(0.9976, device='cuda:1'),
#               12533: tensor(0.9977, device='cuda:1')},
#              '16608': {17897: tensor(0.9989, device='cuda:1'),
#               26306: tensor(0.9989, device='cuda:1')},
#              '7419': {16223: tensor(0.9988, device='cuda:1'),
#               15812: tensor(0.9936, device='cuda:1'),
#               3682: tensor(0.9981, device='cuda:1'),
#               12533: tensor(0.9981, device='cuda:1'),
#               1925: tensor(0.9981, device='cuda:1')},
#              '12289': {19336: tensor(0.9979, device='cuda:1'),
#               3633: tensor(0.9979, device='cuda:1'),
#               8386: tensor(0.9954, device='cuda:1'),
#               19174: tensor(0.9944, device='cuda:1'),
#               10856: tensor(0.9928, device='cuda:1'),
#               4105: tensor(0.9928, device='cuda:1'),
#               28339: tensor(0.9982, device='cuda:1'),
#               6249: tensor(0.9970, device='cuda:1')},
#              '12611': {17144: tensor(0.9957, device='cuda:1'),
#               1925: tensor(0.9920, device='cuda:1'),
#               24386: tensor(0.9822, device='cuda:1'),
#               11434: tensor(0.9895, device='cuda:1'),
#               2115: tensor(0.6121, device='cuda:1'),
#               26306: tensor(0.9980, device='cuda:1'),
#               21253: tensor(0.9980, device='cuda:1'),
#               21030: tensor(0.9980, device='cuda:1'),
#               15070: tensor(0.9945, device='cuda:1'),
#               5251: tensor(0.9911, device='cuda:1'),
#               29787: tensor(0.9907, device='cuda:1')},
#              '5821': {7350: tensor(0.9977, device='cuda:1'),
#               21083: tensor(0.9959, device='cuda:1'),
#               17897: tensor(0.9958, device='cuda:1'),
#               16223: tensor(0.9958, device='cuda:1'),
#               22254: tensor(0.9977, device='cuda:1')},
#              '1303': {26306: tensor(0.9983, device='cuda:1'),
#               27714: tensor(0.9983, device='cuda:1'),
#               15083: tensor(0.9983, device='cuda:1'),
#               12533: tensor(0.7740, device='cuda:1'),
#               29407: tensor(0.9977, device='cuda:1')},
#              '9743': {3067: tensor(0.9941, device='cuda:1'),
#               12533: tensor(0.9806, device='cuda:1'),
#               16392: tensor(0.9958, device='cuda:1')},
#              '6062': {19174: tensor(0.9814, device='cuda:1'),
#               17489: tensor(0.9884, device='cuda:1'),
#               12533: tensor(0.9788, device='cuda:1')},
#              '897': {3682: tensor(0.9596, device='cuda:1'),
#               3812: tensor(0.9972, device='cuda:1'),
#               29425: tensor(0.9950, device='cuda:1'),
#               1925: tensor(0.9950, device='cuda:1')},
#              '7205': {20066: tensor(0.9952, device='cuda:1'),
#               19174: tensor(0.9960, device='cuda:1')},
#              '7456': {19174: tensor(0.9984, device='cuda:1'),
#               25417: tensor(0.9929, device='cuda:1')},
#              '18538': {10856: tensor(0.9990, device='cuda:1')},
#              '3639': {25417: tensor(0.9986, device='cuda:1'),
#               25107: tensor(0.9986, device='cuda:1'),
#               1439: tensor(0.9976, device='cuda:1')},
#              '19117': {12533: tensor(0.9984, device='cuda:1')},
#              '2764': {1925: tensor(0.9818, device='cuda:1'),
#               15264: tensor(0.9899, device='cuda:1'),
#               14190: tensor(0.9899, device='cuda:1'),
#               2431: tensor(0.9899, device='cuda:1'),
#               1865: tensor(0.9866, device='cuda:1'),
#               21142: tensor(0.9973, device='cuda:1'),
#               20066: tensor(0.9914, device='cuda:1'),
#               19174: tensor(0.9979, device='cuda:1'),
#               29279: tensor(0.9979, device='cuda:1'),
#               8828: tensor(0.9973, device='cuda:1'),
#               4613: tensor(0.9832, device='cuda:1'),
#               12631: tensor(0.9832, device='cuda:1'),
#               26893: tensor(0.9889, device='cuda:1')},
#              '9318': {19247: tensor(0.9899, device='cuda:1'),
#               16223: tensor(0.9988, device='cuda:1'),
#               6138: tensor(0.9979, device='cuda:1'),
#               3491: tensor(0.9979, device='cuda:1'),
#               17579: tensor(0.9979, device='cuda:1'),
#               26402: tensor(0.9947, device='cuda:1')},
#              '2862': {3682: tensor(0.8574, device='cuda:1'),
#               8828: tensor(0.7745, device='cuda:1'),
#               7432: tensor(0.9951, device='cuda:1')},
#              '11084': {10856: tensor(0.9951, device='cuda:1'),
#               8828: tensor(0.9925, device='cuda:1'),
#               26338: tensor(0.9951, device='cuda:1')},
#              '12476': {26244: tensor(0.9968, device='cuda:1'),
#               1925: tensor(0.9920, device='cuda:1'),
#               17897: tensor(0.9975, device='cuda:1')},
#              '16178': {8828: tensor(0.9988, device='cuda:1'),
#               24528: tensor(0.9960, device='cuda:1')},
#              '19576': {21722: tensor(0.9057, device='cuda:1'),
#               21325: tensor(0.9944, device='cuda:1'),
#               4613: tensor(0.9944, device='cuda:1'),
#               20183: tensor(0.9944, device='cuda:1'),
#               26341: tensor(0.9957, device='cuda:1')},
#              '9200': {9293: tensor(0.9983, device='cuda:1'),
#               19174: tensor(0.9682, device='cuda:1')},
#              '14982': {25858: tensor(0.9988, device='cuda:1'),
#               16507: tensor(0.9988, device='cuda:1'),
#               13088: tensor(0.9987, device='cuda:1'),
#               26306: tensor(0.9987, device='cuda:1'),
#               6099: tensor(0.9986, device='cuda:1'),
#               19174: tensor(0.9986, device='cuda:1'),
#               2115: tensor(0.9987, device='cuda:1'),
#               16223: tensor(0.9939, device='cuda:1')},
#              '11428': {19174: tensor(0.9886, device='cuda:1'),
#               16223: tensor(0.9983, device='cuda:1')},
#              '1472': {25858: tensor(0.9983, device='cuda:1'),
#               16223: tensor(0.9911, device='cuda:1')},
#              '3206': {28026: tensor(0.9985, device='cuda:1'),
#               25417: tensor(0.9984, device='cuda:1')},
#              '4787': {15264: tensor(0.9932, device='cuda:1'),
#               29407: tensor(0.9932, device='cuda:1'),
#               19205: tensor(0.9895, device='cuda:1'),
#               29703: tensor(0.9932, device='cuda:1'),
#               27619: tensor(0.9955, device='cuda:1'),
#               3682: tensor(0.9955, device='cuda:1'),
#               5332: tensor(0.9895, device='cuda:1'),
#               21142: tensor(0.9895, device='cuda:1'),
#               2460: tensor(0.9955, device='cuda:1')},
#              '3926': {25731: tensor(0.9973, device='cuda:1'),
#               25417: tensor(0.9961, device='cuda:1')},
#              '2756': {26306: tensor(0.9904, device='cuda:1'),
#               16223: tensor(0.9783, device='cuda:1'),
#               12533: tensor(0.9711, device='cuda:1'),
#               12631: tensor(0.9711, device='cuda:1')},
#              '4843': {5251: tensor(0.9975, device='cuda:1'),
#               3828: tensor(0.9987, device='cuda:1')},
#              '16072': {8828: tensor(0.9278, device='cuda:1'),
#               3682: tensor(0.9278, device='cuda:1'),
#               3724: tensor(0.8458, device='cuda:1'),
#               3828: tensor(0.7856, device='cuda:1'),
#               2115: tensor(0.9920, device='cuda:1'),
#               21700: tensor(0.9278, device='cuda:1'),
#               1925: tensor(0.9919, device='cuda:1')},
#              '7530': {16223: tensor(0.9250, device='cuda:1'),
#               15264: tensor(0.9800, device='cuda:1'),
#               24790: tensor(0.9800, device='cuda:1')},
#              '6414': {12533: tensor(0.9981, device='cuda:1')},
#              '15787': {1925: tensor(0.9962, device='cuda:1'),
#               16223: tensor(0.9927, device='cuda:1'),
#               3491: tensor(0.9981, device='cuda:1')},
#              '12570': {19174: tensor(0.9928, device='cuda:1'),
#               25417: tensor(0.9467, device='cuda:1'),
#               12533: tensor(0.9782, device='cuda:1')},
#              '6049': {26306: tensor(0.9957, device='cuda:1'),
#               12533: tensor(0.9967, device='cuda:1'),
#               20028: tensor(0.9957, device='cuda:1'),
#               19174: tensor(0.9957, device='cuda:1'),
#               29787: tensor(0.9943, device='cuda:1'),
#               2537: tensor(0.9550, device='cuda:1')},
#              '10968': {16223: tensor(0.9949, device='cuda:1')},
#              '8082': {16223: tensor(0.9988, device='cuda:1'),
#               11864: tensor(0.9881, device='cuda:1')},
#              '9782': {26306: tensor(0.9976, device='cuda:1'),
#               4762: tensor(0.9976, device='cuda:1'),
#               28687: tensor(0.9980, device='cuda:1'),
#               16223: tensor(0.9978, device='cuda:1')},
#              '5219': {8565: tensor(0.9966, device='cuda:1'),
#               26306: tensor(0.9861, device='cuda:1'),
#               25417: tensor(0.9974, device='cuda:1'),
#               20183: tensor(0.9967, device='cuda:1'),
#               16507: tensor(0.9965, device='cuda:1')},
#              '13721': {14081: tensor(0.9956, device='cuda:1'),
#               29787: tensor(0.9931, device='cuda:1'),
#               20028: tensor(0.9931, device='cuda:1'),
#               18874: tensor(0.9977, device='cuda:1'),
#               3682: tensor(0.9977, device='cuda:1')},
#              '7488': {19174: tensor(0.9984, device='cuda:1'),
#               10856: tensor(0.9753, device='cuda:1'),
#               6099: tensor(0.9984, device='cuda:1'),
#               27698: tensor(0.9984, device='cuda:1')},
#              '6784': {16223: tensor(0.9985, device='cuda:1'),
#               27649: tensor(0.9977, device='cuda:1'),
#               21430: tensor(0.9977, device='cuda:1'),
#               10856: tensor(0.9951, device='cuda:1'),
#               25417: tensor(0.9930, device='cuda:1')},
#              '1158': {26306: tensor(0.9980, device='cuda:1'),
#               11864: tensor(0.9984, device='cuda:1'),
#               29425: tensor(0.9984, device='cuda:1'),
#               3682: tensor(0.9984, device='cuda:1'),
#               7875: tensor(0.9984, device='cuda:1'),
#               19430: tensor(0.9980, device='cuda:1')},
#              '16142': {16506: tensor(0.9987, device='cuda:1')},
#              '2910': {12533: tensor(0.9985, device='cuda:1'),
#               3067: tensor(0.9965, device='cuda:1'),
#               19174: tensor(0.9977, device='cuda:1')},
#              '16398': {19174: tensor(0.9864, device='cuda:1'),
#               3682: tensor(0.9944, device='cuda:1')},
#              '15504': {19174: tensor(0.9958, device='cuda:1'),
#               25858: tensor(0.9979, device='cuda:1'),
#               16223: tensor(0.9913, device='cuda:1')},
#              '8911': {10535: tensor(0.9936, device='cuda:1'),
#               3369: tensor(0.9901, device='cuda:1'),
#               13332: tensor(0.9870, device='cuda:1'),
#               25726: tensor(0.9870, device='cuda:1')},
#              '19275': {20183: tensor(0.9966, device='cuda:1'),
#               12533: tensor(0.9979, device='cuda:1'),
#               19174: tensor(0.9836, device='cuda:1'),
#               19018: tensor(0.9979, device='cuda:1'),
#               17192: tensor(0.9959, device='cuda:1'),
#               1034: tensor(0.9959, device='cuda:1')},
#              '4738': {29787: tensor(0.9522, device='cuda:1'),
#               14135: tensor(0.9522, device='cuda:1'),
#               16223: tensor(0.9522, device='cuda:1'),
#               25858: tensor(0.9696, device='cuda:1')},
#              '1791': {15264: tensor(0.9979, device='cuda:1')},
#              '9287': {25417: tensor(0.9924, device='cuda:1'),
#               13617: tensor(0.9983, device='cuda:1'),
#               3682: tensor(0.7842, device='cuda:1'),
#               29425: tensor(0.9983, device='cuda:1'),
#               26306: tensor(0.9983, device='cuda:1')},
#              '16586': {3812: tensor(0.9983, device='cuda:1'),
#               26306: tensor(0.9970, device='cuda:1'),
#               25107: tensor(0.9970, device='cuda:1'),
#               19174: tensor(0.9970, device='cuda:1'),
#               7491: tensor(0.9705, device='cuda:1'),
#               15083: tensor(0.9960, device='cuda:1'),
#               3828: tensor(0.9960, device='cuda:1'),
#               12533: tensor(0.9960, device='cuda:1')},
#              '10552': {26306: tensor(0.9985, device='cuda:1'),
#               12533: tensor(0.9943, device='cuda:1')},
#              '17310': {12533: tensor(0.5662, device='cuda:1'),
#               15264: tensor(0.9796, device='cuda:1'),
#               3682: tensor(0.9802, device='cuda:1')},
#              '14376': {16223: tensor(0.9796, device='cuda:1'),
#               26306: tensor(0.9979, device='cuda:1'),
#               5251: tensor(0.9979, device='cuda:1'),
#               2115: tensor(0.9979, device='cuda:1'),
#               3828: tensor(0.9979, device='cuda:1'),
#               4028: tensor(0.9979, device='cuda:1'),
#               1925: tensor(0.9808, device='cuda:1')},
#              '18196': {5251: tensor(0.9950, device='cuda:1'),
#               4508: tensor(0.9972, device='cuda:1'),
#               3682: tensor(0.9975, device='cuda:1'),
#               12533: tensor(0.9958, device='cuda:1'),
#               8726: tensor(0.9601, device='cuda:1'),
#               19174: tensor(0.9975, device='cuda:1')},
#              '11974': {10196: tensor(0.9990, device='cuda:1'),
#               29336: tensor(0.9989, device='cuda:1'),
#               29787: tensor(0.9989, device='cuda:1'),
#               7952: tensor(0.9984, device='cuda:1'),
#               16223: tensor(0.9984, device='cuda:1'),
#               26059: tensor(0.9991, device='cuda:1'),
#               16507: tensor(0.9991, device='cuda:1')},
#              '10189': {14135: tensor(0.9964, device='cuda:1'),
#               29407: tensor(0.9971, device='cuda:1')},
#              '6778': {5251: tensor(0.9886, device='cuda:1'),
#               26306: tensor(0.9867, device='cuda:1'),
#               17897: tensor(0.9979, device='cuda:1')},
#              '10384': {6138: tensor(0.9967, device='cuda:1'),
#               607: tensor(0.9955, device='cuda:1'),
#               5505: tensor(0.9982, device='cuda:1'),
#               12533: tensor(0.9982, device='cuda:1'),
#               28551: tensor(0.9982, device='cuda:1'),
#               1865: tensor(0.9939, device='cuda:1')},
#              '3949': {3682: tensor(0.9896, device='cuda:1'),
#               16223: tensor(0.9896, device='cuda:1'),
#               26306: tensor(0.9960, device='cuda:1'),
#               19174: tensor(0.9955, device='cuda:1')},
#              '12249': {12533: tensor(0.9873, device='cuda:1')},
#              '11970': {7952: tensor(0.9990, device='cuda:1'),
#               26306: tensor(0.9990, device='cuda:1'),
#               16507: tensor(0.9988, device='cuda:1'),
#               19174: tensor(0.9989, device='cuda:1'),
#               16223: tensor(0.9977, device='cuda:1')},
#              '14370': {2115: tensor(0.9957, device='cuda:1'),
#               12533: tensor(0.9971, device='cuda:1'),
#               25417: tensor(0.9957, device='cuda:1'),
#               21700: tensor(0.9957, device='cuda:1')},
#              '19129': {20066: tensor(0.9800, device='cuda:1'),
#               20816: tensor(0.9932, device='cuda:1'),
#               20183: tensor(0.9932, device='cuda:1'),
#               26244: tensor(0.9800, device='cuda:1'),
#               27698: tensor(0.9981, device='cuda:1'),
#               25417: tensor(0.9118, device='cuda:1'),
#               26306: tensor(0.9697, device='cuda:1')},
#              '18765': {20028: tensor(0.9950, device='cuda:1'),
#               16223: tensor(0.9966, device='cuda:1')},
#              '9439': {26306: tensor(0.9651, device='cuda:1')},
#              '2632': {12533: tensor(0.9858, device='cuda:1'),
#               17296: tensor(0.9915, device='cuda:1')},
#              '2805': {5396: tensor(0.9971, device='cuda:1'),
#               26306: tensor(0.9876, device='cuda:1'),
#               5251: tensor(0.9876, device='cuda:1'),
#               27335: tensor(0.9964, device='cuda:1'),
#               8828: tensor(0.9938, device='cuda:1'),
#               29787: tensor(0.9876, device='cuda:1')},
#              '2716': {3682: tensor(0.9974, device='cuda:1'),
#               12533: tensor(0.9987, device='cuda:1'),
#               19174: tensor(0.9987, device='cuda:1'),
#               18112: tensor(0.9984, device='cuda:1'),
#               28551: tensor(0.9984, device='cuda:1'),
#               24528: tensor(0.9984, device='cuda:1'),
#               3828: tensor(0.9984, device='cuda:1'),
#               2558: tensor(0.9984, device='cuda:1')},
#              '5197': {12533: tensor(0.9981, device='cuda:1'),
#               16223: tensor(0.9977, device='cuda:1')},
#              '6058': {3682: tensor(0.9970, device='cuda:1'),
#               7432: tensor(0.9943, device='cuda:1'),
#               29040: tensor(0.9943, device='cuda:1')},
#              '19628': {29787: tensor(0.9531, device='cuda:1'),
#               21083: tensor(0.9531, device='cuda:1'),
#               20028: tensor(0.9531, device='cuda:1'),
#               15083: tensor(0.9397, device='cuda:1'),
#               3496: tensor(0.9969, device='cuda:1'),
#               19018: tensor(0.9745, device='cuda:1'),
#               12533: tensor(0.9745, device='cuda:1'),
#               19174: tensor(0.9745, device='cuda:1')},
#              '14774': {16223: tensor(0.9969, device='cuda:1')},
#              '15898': {16223: tensor(0.9984, device='cuda:1'),
#               17897: tensor(0.9989, device='cuda:1'),
#               2115: tensor(0.9990, device='cuda:1'),
#               19174: tensor(0.9976, device='cuda:1'),
#               10856: tensor(0.9974, device='cuda:1')},
#              '9827': {12533: tensor(0.9944, device='cuda:1'),
#               21083: tensor(0.9911, device='cuda:1'),
#               17340: tensor(0.9911, device='cuda:1')},
#              '19135': {12533: tensor(0.9913, device='cuda:1'),
#               26306: tensor(0.9978, device='cuda:1'),
#               20028: tensor(0.9962, device='cuda:1'),
#               1925: tensor(0.9930, device='cuda:1')},
#              '15963': {21435: tensor(0.9973, device='cuda:1'),
#               19174: tensor(0.9951, device='cuda:1'),
#               1865: tensor(0.9949, device='cuda:1'),
#               20028: tensor(0.9949, device='cuda:1'),
#               26306: tensor(0.9962, device='cuda:1'),
#               3682: tensor(0.9929, device='cuda:1'),
#               20183: tensor(0.9951, device='cuda:1'),
#               2115: tensor(0.9968, device='cuda:1'),
#               1925: tensor(0.9962, device='cuda:1'),
#               15839: tensor(0.9962, device='cuda:1'),
#               24942: tensor(0.9981, device='cuda:1')},
#              '7525': {19174: tensor(0.9901, device='cuda:1'),
#               25417: tensor(0.9926, device='cuda:1'),
#               1925: tensor(0.9926, device='cuda:1'),
#               17340: tensor(0.9903, device='cuda:1'),
#               607: tensor(0.9903, device='cuda:1'),
#               12533: tensor(0.9901, device='cuda:1')},
#              '16424': {29425: tensor(0.9985, device='cuda:1'),
#               6696: tensor(0.9977, device='cuda:1'),
#               2558: tensor(0.9990, device='cuda:1'),
#               26306: tensor(0.9990, device='cuda:1')},
#              '2828': {16223: tensor(0.9957, device='cuda:1')},
#              '9157': {29407: tensor(0.9965, device='cuda:1'),
#               16506: tensor(0.9982, device='cuda:1')},
#              '11299': {11240: tensor(0.9979, device='cuda:1'),
#               3369: tensor(0.9976, device='cuda:1'),
#               18488: tensor(0.9972, device='cuda:1')},
#              '18552': {16223: tensor(0.9904, device='cuda:1'),
#               19174: tensor(0.9967, device='cuda:1')},
#              '16539': {18320: tensor(0.9976, device='cuda:1'),
#               13573: tensor(0.9984, device='cuda:1'),
#               24151: tensor(0.9984, device='cuda:1'),
#               14662: tensor(0.9985, device='cuda:1'),
#               22353: tensor(0.9984, device='cuda:1'),
#               25319: tensor(0.9981, device='cuda:1')},
#              '5327': {17489: tensor(0.9973, device='cuda:1'),
#               8750: tensor(0.9860, device='cuda:1')},
#              '13821': {2115: tensor(0.9967, device='cuda:1'),
#               3682: tensor(0.9963, device='cuda:1'),
#               5251: tensor(0.9963, device='cuda:1'),
#               19174: tensor(0.9963, device='cuda:1'),
#               17067: tensor(0.9963, device='cuda:1'),
#               15839: tensor(0.9963, device='cuda:1'),
#               21083: tensor(0.9944, device='cuda:1')},
#              '8609': {3828: tensor(0.8880, device='cuda:1'),
#               21083: tensor(0.9912, device='cuda:1')},
#              '8316': {16223: tensor(0.9600, device='cuda:1'),
#               19724: tensor(0.9988, device='cuda:1')},
#              '5570': {3828: tensor(0.9934, device='cuda:1'),
#               26306: tensor(0.9982, device='cuda:1'),
#               3682: tensor(0.9982, device='cuda:1'),
#               16223: tensor(0.9982, device='cuda:1')},
#              '9053': {21083: tensor(0.9896, device='cuda:1'),
#               26306: tensor(0.9971, device='cuda:1')},
#              '16200': {29310: tensor(0.9970, device='cuda:1'),
#               29425: tensor(0.9953, device='cuda:1')},
#              '7395': {1455: tensor(0.7585, device='cuda:1'),
#               15474: tensor(0.9957, device='cuda:1'),
#               19174: tensor(0.9957, device='cuda:1')},
#              '16913': {25858: tensor(0.9982, device='cuda:1'),
#               25726: tensor(0.9978, device='cuda:1'),
#               26306: tensor(0.9987, device='cuda:1'),
#               3682: tensor(0.9987, device='cuda:1'),
#               21435: tensor(0.9987, device='cuda:1')},
#              '9573': {25417: tensor(0.7476, device='cuda:1'),
#               21030: tensor(0.9971, device='cuda:1')},
#              '17140': {1717: tensor(0.9974, device='cuda:1'),
#               12631: tensor(0.9953, device='cuda:1'),
#               30178: tensor(0.9967, device='cuda:1'),
#               16506: tensor(0.9956, device='cuda:1'),
#               26306: tensor(0.9982, device='cuda:1'),
#               29407: tensor(0.9982, device='cuda:1'),
#               12533: tensor(0.9974, device='cuda:1'),
#               25895: tensor(0.9982, device='cuda:1'),
#               25731: tensor(0.9955, device='cuda:1'),
#               23189: tensor(0.9949, device='cuda:1'),
#               20028: tensor(0.9938, device='cuda:1')},
#              '13685': {21083: tensor(0.9922, device='cuda:1'),
#               26306: tensor(0.9224, device='cuda:1'),
#               3491: tensor(0.9935, device='cuda:1'),
#               16223: tensor(0.9848, device='cuda:1'),
#               15264: tensor(0.9848, device='cuda:1'),
#               12570: tensor(0.9848, device='cuda:1')},
#              '11855': {16223: tensor(0.1551, device='cuda:1'),
#               10856: tensor(0.9521, device='cuda:1')},
#              '518': {16223: tensor(0.9829, device='cuda:1'),
#               1925: tensor(0.9827, device='cuda:1'),
#               19018: tensor(0.9984, device='cuda:1'),
#               25107: tensor(0.9984, device='cuda:1')},
#              '18214': {19174: tensor(0.9957, device='cuda:1'),
#               16223: tensor(0.9986, device='cuda:1'),
#               20028: tensor(0.9989, device='cuda:1'),
#               15091: tensor(0.9870, device='cuda:1'),
#               27619: tensor(0.9943, device='cuda:1'),
# ...
#               16506: tensor(0.6685, device='cuda:1'),
#               1925: tensor(0.6685, device='cuda:1')},
#              '12121': {19174: tensor(0.9984, device='cuda:1'),
#               16223: tensor(0.9984, device='cuda:1'),
#               3616: tensor(0.9989, device='cuda:1'),
#               16507: tensor(0.9984, device='cuda:1'),
#               26306: tensor(0.9984, device='cuda:1'),
#               7952: tensor(0.9987, device='cuda:1')},
#              '7863': {19174: tensor(0.9279, device='cuda:1'),
#               26306: tensor(0.9356, device='cuda:1'),
#               26229: tensor(0.9950, device='cuda:1'),
#               21083: tensor(0.1637, device='cuda:1'),
#               15912: tensor(0.9681, device='cuda:1'),
#               3812: tensor(0.8327, device='cuda:1'),
#               25417: tensor(0.9519, device='cuda:1'),
#               19299: tensor(0.9356, device='cuda:1'),
#               7693: tensor(0.9970, device='cuda:1'),
#               28890: tensor(0.9356, device='cuda:1'),
#               20028: tensor(0.9356, device='cuda:1'),
#               1925: tensor(0.9970, device='cuda:1')},
#              '2915': {3067: tensor(0.9986, device='cuda:1'),
#               27335: tensor(0.9986, device='cuda:1'),
#               18344: tensor(0.9987, device='cuda:1'),
#               20028: tensor(0.9989, device='cuda:1'),
#               12533: tensor(0.9392, device='cuda:1')},
#              '15540': {26306: tensor(0.9988, device='cuda:1'),
#               8509: tensor(0.9988, device='cuda:1'),
#               20028: tensor(0.9984, device='cuda:1')},
#              '4867': {25155: tensor(0.9894, device='cuda:1'),
#               11617: tensor(0.9891, device='cuda:1'),
#               16223: tensor(0.9891, device='cuda:1'),
#               24790: tensor(0.9923, device='cuda:1'),
#               26306: tensor(0.9991, device='cuda:1'),
#               19018: tensor(0.9925, device='cuda:1')},
#              '2771': {19174: tensor(0.9989, device='cuda:1'),
#               8828: tensor(0.9708, device='cuda:1')},
#              '17176': {3369: tensor(0.9983, device='cuda:1'),
#               24790: tensor(0.9986, device='cuda:1'),
#               16223: tensor(0.9974, device='cuda:1')},
#              '16818': {20066: tensor(0.9973, device='cuda:1')},
#              '15931': {12533: tensor(0.9955, device='cuda:1'),
#               1439: tensor(0.9984, device='cuda:1')},
#              '19901': {19174: tensor(0.9821, device='cuda:1'),
#               3491: tensor(0.9960, device='cuda:1'),
#               21083: tensor(0.9656, device='cuda:1')},
#              '10179': {2115: tensor(0.9989, device='cuda:1'),
#               12533: tensor(0.9984, device='cuda:1')},
#              '15878': {20183: tensor(0.9974, device='cuda:1'),
#               16223: tensor(0.9418, device='cuda:1'),
#               19174: tensor(0.9987, device='cuda:1')},
#              '9117': {16223: tensor(0.9749, device='cuda:1'),
#               25731: tensor(0.9943, device='cuda:1'),
#               20028: tensor(0.9749, device='cuda:1')},
#              '11804': {12533: tensor(0.9969, device='cuda:1'),
#               3369: tensor(0.9980, device='cuda:1'),
#               29425: tensor(0.9982, device='cuda:1'),
#               6441: tensor(0.9982, device='cuda:1'),
#               20028: tensor(0.9984, device='cuda:1')},
#              '7560': {15264: tensor(0.9314, device='cuda:1'),
#               25858: tensor(0.9314, device='cuda:1'),
#               11012: tensor(0.9314, device='cuda:1'),
#               19174: tensor(0.9314, device='cuda:1'),
#               7433: tensor(0.9314, device='cuda:1'),
#               3342: tensor(0.9314, device='cuda:1'),
#               15259: tensor(0.9314, device='cuda:1'),
#               22900: tensor(0.9781, device='cuda:1')},
#              '4857': {8126: tensor(0.9970, device='cuda:1'),
#               15694: tensor(0.9970, device='cuda:1'),
#               16223: tensor(0.9928, device='cuda:1'),
#               8828: tensor(0.9922, device='cuda:1'),
#               10856: tensor(0.9928, device='cuda:1')},
#              '10029': {19174: tensor(0.9770, device='cuda:1'),
#               16730: tensor(0.9836, device='cuda:1'),
#               17340: tensor(0.9836, device='cuda:1'),
#               16223: tensor(0.9914, device='cuda:1'),
#               21083: tensor(0.9666, device='cuda:1'),
#               12570: tensor(0.9755, device='cuda:1'),
#               19596: tensor(0.9755, device='cuda:1'),
#               10238: tensor(0.9755, device='cuda:1'),
#               25417: tensor(0.6766, device='cuda:1')},
#              '7826': {19174: tensor(0.9472, device='cuda:1'),
#               6642: tensor(0.9884, device='cuda:1'),
#               10055: tensor(0.9850, device='cuda:1')},
#              '7575': {8589: tensor(0.9697, device='cuda:1'),
#               21083: tensor(0.9836, device='cuda:1'),
#               10856: tensor(0.9865, device='cuda:1'),
#               26338: tensor(0.9478, device='cuda:1')},
#              '6019': {10856: tensor(0.6362, device='cuda:1')},
#              '8797': {26306: tensor(0.9808, device='cuda:1'),
#               13966: tensor(0.9808, device='cuda:1'),
#               12533: tensor(0.9624, device='cuda:1'),
#               19174: tensor(0.9936, device='cuda:1')},
#              '1958': {26306: tensor(0.9895, device='cuda:1'),
#               12631: tensor(0.9465, device='cuda:1'),
#               1925: tensor(0.4516, device='cuda:1')},
#              '17106': {26306: tensor(0.9988, device='cuda:1'),
#               16223: tensor(0.9988, device='cuda:1'),
#               2115: tensor(0.9980, device='cuda:1'),
#               17579: tensor(0.9976, device='cuda:1')},
#              '12805': {2115: tensor(0.9297, device='cuda:1'),
#               7491: tensor(0.9986, device='cuda:1')},
#              '10252': {26306: tensor(0.9951, device='cuda:1'),
#               25858: tensor(0.9951, device='cuda:1'),
#               24790: tensor(0.9951, device='cuda:1'),
#               16223: tensor(0.9989, device='cuda:1')},
#              '957': {16223: tensor(0.9964, device='cuda:1'),
#               26306: tensor(0.9965, device='cuda:1'),
#               27001: tensor(0.9944, device='cuda:1'),
#               15264: tensor(0.9964, device='cuda:1'),
#               3881: tensor(0.9964, device='cuda:1'),
#               23209: tensor(0.9940, device='cuda:1'),
#               28621: tensor(0.9940, device='cuda:1')},
#              '6240': {20183: tensor(0.9909, device='cuda:1'),
#               26306: tensor(0.9977, device='cuda:1')},
#              '18315': {19174: tensor(0.8577, device='cuda:1'),
#               980: tensor(0.7290, device='cuda:1'),
#               1925: tensor(0.7290, device='cuda:1'),
#               25417: tensor(0.9426, device='cuda:1'),
#               25107: tensor(0.9426, device='cuda:1'),
#               20028: tensor(0.9956, device='cuda:1')},
#              '1554': {19174: tensor(0.9974, device='cuda:1'),
#               16223: tensor(0.9878, device='cuda:1')},
#              '1895': {3682: tensor(0.9953, device='cuda:1'),
#               8589: tensor(0.9986, device='cuda:1'),
#               8726: tensor(0.9986, device='cuda:1')},
#              '5160': {26306: tensor(0.9965, device='cuda:1'),
#               2115: tensor(0.9272, device='cuda:1'),
#               12631: tensor(0.9272, device='cuda:1')},
#              '9873': {7952: tensor(0.9547, device='cuda:1'),
#               1925: tensor(0.9547, device='cuda:1'),
#               22254: tensor(0.9547, device='cuda:1')},
#              '19536': {25417: tensor(0.7578, device='cuda:1'),
#               20183: tensor(0.9986, device='cuda:1'),
#               16785: tensor(0.9874, device='cuda:1')},
#              '4533': {12246: tensor(0.9990, device='cuda:1'),
#               8828: tensor(0.9101, device='cuda:1'),
#               16223: tensor(0.9101, device='cuda:1'),
#               10856: tensor(0.9983, device='cuda:1')},
#              '18363': {20028: tensor(0.9982, device='cuda:1'),
#               26306: tensor(0.9974, device='cuda:1'),
#               19018: tensor(0.9982, device='cuda:1'),
#               25107: tensor(0.9982, device='cuda:1'),
#               12533: tensor(0.9982, device='cuda:1'),
#               19174: tensor(0.9975, device='cuda:1')},
#              '5229': {19174: tensor(0.9980, device='cuda:1'),
#               5894: tensor(0.9980, device='cuda:1'),
#               24645: tensor(0.9971, device='cuda:1'),
#               12533: tensor(0.9971, device='cuda:1'),
#               1286: tensor(0.9971, device='cuda:1')},
#              '2666': {11866: tensor(0.9670, device='cuda:1'),
#               15839: tensor(0.9877, device='cuda:1')},
#              '11961': {16223: tensor(0.9988, device='cuda:1'),
#               19174: tensor(0.9955, device='cuda:1'),
#               25155: tensor(0.9987, device='cuda:1')},
#              '6195': {12533: tensor(0.9827, device='cuda:1'),
#               29787: tensor(0.9970, device='cuda:1')},
#              '3018': {7432: tensor(0.9970, device='cuda:1'),
#               26306: tensor(0.9974, device='cuda:1'),
#               19174: tensor(0.9974, device='cuda:1')},
#              '736': {21083: tensor(0.9963, device='cuda:1'),
#               3369: tensor(0.9943, device='cuda:1'),
#               26971: tensor(0.9807, device='cuda:1'),
#               16223: tensor(0.9941, device='cuda:1')},
#              '16957': {4665: tensor(0.9979, device='cuda:1'),
#               5024: tensor(0.8022, device='cuda:1'),
#               5332: tensor(0.8022, device='cuda:1'),
#               24924: tensor(0.8301, device='cuda:1'),
#               1772: tensor(0.9974, device='cuda:1'),
#               6539: tensor(0.9984, device='cuda:1'),
#               25054: tensor(0.9984, device='cuda:1')},
#              '5674': {16223: tensor(0.9979, device='cuda:1'),
#               16394: tensor(0.9980, device='cuda:1'),
#               28687: tensor(0.9987, device='cuda:1')},
#              '10369': {3828: tensor(0.7780, device='cuda:1')},
#              '6652': {25417: tensor(0.9853, device='cuda:1'),
#               23189: tensor(0.9984, device='cuda:1'),
#               16223: tensor(0.9915, device='cuda:1')},
#              '16511': {19174: tensor(0.9800, device='cuda:1'),
#               3682: tensor(0.9903, device='cuda:1'),
#               12246: tensor(0.5888, device='cuda:1'),
#               16223: tensor(0.9903, device='cuda:1'),
#               12533: tensor(0.9801, device='cuda:1'),
#               8509: tensor(0.9801, device='cuda:1')},
#              '18143': {11866: tensor(0.8489, device='cuda:1'),
#               26893: tensor(0.9973, device='cuda:1'),
#               16223: tensor(0.8202, device='cuda:1'),
#               26306: tensor(0.9973, device='cuda:1')},
#              '9160': {24472: tensor(0.9917, device='cuda:1'),
#               25858: tensor(0.9917, device='cuda:1'),
#               8828: tensor(0.9839, device='cuda:1')},
#              '15801': {25417: tensor(0.9794, device='cuda:1'),
#               15474: tensor(0.9794, device='cuda:1'),
#               25107: tensor(0.9863, device='cuda:1'),
#               1925: tensor(0.9945, device='cuda:1'),
#               20183: tensor(0.9945, device='cuda:1')},
#              '19439': {8426: tensor(0.9900, device='cuda:1'),
#               26306: tensor(0.9900, device='cuda:1'),
#               21083: tensor(0.9900, device='cuda:1'),
#               13617: tensor(0.9983, device='cuda:1')},
#              '8620': {6192: tensor(0.9978, device='cuda:1'),
#               12570: tensor(0.9967, device='cuda:1'),
#               16223: tensor(0.9977, device='cuda:1'),
#               29612: tensor(0.9977, device='cuda:1')},
#              '10181': {20028: tensor(0.9981, device='cuda:1'),
#               15083: tensor(0.9986, device='cuda:1')},
#              '6812': {12533: tensor(0.9882, device='cuda:1'),
#               26306: tensor(0.9985, device='cuda:1')},
#              '12643': {19174: tensor(0.9983, device='cuda:1'),
#               26306: tensor(0.9985, device='cuda:1'),
#               16223: tensor(0.9985, device='cuda:1')},
#              '19277': {16223: tensor(0.9971, device='cuda:1'),
#               8649: tensor(0.9971, device='cuda:1'),
#               11235: tensor(0.9885, device='cuda:1'),
#               20578: tensor(0.9707, device='cuda:1'),
#               19174: tensor(0.9707, device='cuda:1'),
#               17698: tensor(0.9659, device='cuda:1')},
#              '2431': {12533: tensor(0.9938, device='cuda:1'),
#               16223: tensor(0.9959, device='cuda:1')},
#              '4529': {16223: tensor(0.9940, device='cuda:1'),
#               16507: tensor(0.9438, device='cuda:1'),
#               25858: tensor(0.9986, device='cuda:1'),
#               3491: tensor(0.9777, device='cuda:1')},
#              '10408': {19174: tensor(0.9894, device='cuda:1'),
#               12205: tensor(0.3646, device='cuda:1'),
#               5251: tensor(0.9918, device='cuda:1'),
#               12533: tensor(0.9918, device='cuda:1'),
#               28551: tensor(0.9918, device='cuda:1')},
#              '582': {21700: tensor(0.9888, device='cuda:1'),
#               4215: tensor(0.9888, device='cuda:1'),
#               22353: tensor(0.7973, device='cuda:1'),
#               25858: tensor(0.9954, device='cuda:1'),
#               14190: tensor(0.9954, device='cuda:1')},
#              '16402': {16223: tensor(0.9982, device='cuda:1'),
#               12533: tensor(0.9525, device='cuda:1'),
#               8509: tensor(0.9677, device='cuda:1'),
#               19174: tensor(0.9626, device='cuda:1'),
#               7822: tensor(0.9860, device='cuda:1'),
#               25107: tensor(0.9677, device='cuda:1')},
#              '13972': {12533: tensor(0.9475, device='cuda:1'),
#               2115: tensor(0.9969, device='cuda:1')},
#              '7614': {25417: tensor(0.9885, device='cuda:1'),
#               19174: tensor(0.9974, device='cuda:1')},
#              '9565': {12533: tensor(0.9694, device='cuda:1'),
#               13332: tensor(0.9694, device='cuda:1'),
#               27714: tensor(0.9981, device='cuda:1'),
#               1717: tensor(0.9981, device='cuda:1')},
#              '14224': {13819: tensor(0.9986, device='cuda:1'),
#               7432: tensor(0.9942, device='cuda:1'),
#               29787: tensor(0.9987, device='cuda:1'),
#               21700: tensor(0.9987, device='cuda:1'),
#               26306: tensor(0.9979, device='cuda:1')},
#              '10648': {19174: tensor(0.9792, device='cuda:1'),
#               17985: tensor(0.9854, device='cuda:1'),
#               16482: tensor(0.9854, device='cuda:1'),
#               19238: tensor(0.9854, device='cuda:1'),
#               27335: tensor(0.9854, device='cuda:1'),
#               29192: tensor(0.9854, device='cuda:1'),
#               13991: tensor(0.9854, device='cuda:1'),
#               8073: tensor(0.9854, device='cuda:1'),
#               21862: tensor(0.9854, device='cuda:1'),
#               8076: tensor(0.9854, device='cuda:1'),
#               8396: tensor(0.9854, device='cuda:1'),
#               16620: tensor(0.9854, device='cuda:1'),
#               18608: tensor(0.9854, device='cuda:1'),
#               25107: tensor(0.9854, device='cuda:1'),
#               26740: tensor(0.9854, device='cuda:1'),
#               30423: tensor(0.9854, device='cuda:1'),
#               13496: tensor(0.9854, device='cuda:1'),
#               9497: tensor(0.9854, device='cuda:1'),
#               19018: tensor(0.9976, device='cuda:1'),
#               12533: tensor(0.9909, device='cuda:1')},
#              '10257': {26306: tensor(0.9981, device='cuda:1'),
#               19174: tensor(0.9979, device='cuda:1'),
#               20066: tensor(0.9985, device='cuda:1'),
#               29425: tensor(0.9987, device='cuda:1'),
#               26039: tensor(0.9982, device='cuda:1')},
#              '5233': {16620: tensor(0.9987, device='cuda:1'),
#               3369: tensor(0.9684, device='cuda:1'),
#               25155: tensor(0.9750, device='cuda:1'),
#               18670: tensor(0.9969, device='cuda:1')},
#              '411': {12533: tensor(0.9822, device='cuda:1'),
#               26306: tensor(0.9735, device='cuda:1')},
#              '8207': {16223: tensor(0.9175, device='cuda:1'),
#               27619: tensor(0.9938, device='cuda:1'),
#               19174: tensor(0.9889, device='cuda:1')},
#              ...})

# %%
# from transformers import pipeline
# sentiment_analysis = pipeline("sentiment-analysis",model=args.text_encoder)
# print(sentiment_analysis("I love this!"))
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.bias', 'roberta.pooler.dense.bias', 'roberta.pooler.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.bias', 'classifier.out_proj.weight', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [{'label': 'LABEL_0', 'score': 0.5122907161712646}]

# %%
# model = AutoModel.from_pretrained("roberta-base").to(args.device)
# senti_tokenizer = AutoTokenizer.from_pretrained("roberta-base")

# text = "I hate this!"

# encoded_input = senti_tokenizer(text, return_tensors='pt')
# for k, v in encoded_input.items():
#     encoded_input[k] = torch.as_tensor(v, device=args.device)
    
# output = model(**encoded_input)
# scores = output[0][0]

# li = nn.Linear(768, 2).to(args.device)
# scores = li(scores)

# sigmoid = nn.Sigmoid()
# scores = sigmoid(scores)
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.decoder.weight', 'lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer
import torch

task='sentiment'
MODEL = f"cardiffnlp/twitter-roberta-base-{task}"

# Assuming 'args.device' is set to 'cuda' if a GPU is available, else 'cpu'
device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")

# Load the pre-trained RoBERTa model for sequence classification
model = AutoModelForSequenceClassification.from_pretrained(MODEL)
model = model.to(device)

# Load the tokenizer
senti_tokenizer = AutoTokenizer.from_pretrained(MODEL)

# Sample text
text = "I like to watch scary movies"

# Tokenize the text
inputs = senti_tokenizer(text, return_tensors="pt", padding=True, truncation=True)
inputs = {k: v.to(device) for k, v in inputs.items()}

# Get the logits from the model
with torch.no_grad():
    outputs = model(**inputs)
    logits = outputs.logits

# Apply softmax to get probabilities
probabilities = torch.nn.functional.softmax(logits, dim=1).cpu().numpy()

# Note: twitter-roberta-senti model => [negative, neutral, positive]
negative, neutral, positive = probabilities[0]
sentiment_score = positive / (positive + negative)

print(sentiment_score)
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# 0.995256

# %%
from transformers import RobertaTokenizer, RobertaModel
tokenizer = RobertaTokenizer.from_pretrained('roberta-base')
model = RobertaModel.from_pretrained('roberta-base')
text = "Replace me by any text you'd like."
encoded_input = tokenizer(text, return_tensors='pt')
output = model(**encoded_input)
output[0][0]
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.bias', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tensor([[-0.1146,  0.1103, -0.0149,  ..., -0.0809, -0.0018, -0.0271],
#         [-0.0225,  0.1612,  0.0556,  ...,  0.5366,  0.1196,  0.1576],
#         [ 0.0532, -0.0020,  0.0370,  ..., -0.4887,  0.1641,  0.2736],
#         ...,
#         [-0.1586,  0.0837,  0.1302,  ...,  0.3970,  0.1715, -0.0848],
#         [-0.1065,  0.1044, -0.0383,  ..., -0.1068, -0.0015, -0.0517],
#         [ 0.0059,  0.0758,  0.1228,  ...,  0.1037,  0.0075,  0.0976]],
#        grad_fn=<SelectBackward0>)

# %% [markdown]
# ## KG 모델링

# %%
kg = DBpedia(dataset=args.dataset).get_entity_kg_info()

# %%
class SelfAttentionBatch(nn.Module):
    def __init__(self, dim, da, alpha=0.2, dropout=0.5):
        super(SelfAttentionBatch, self).__init__()
        self.dim = dim
        self.da = da
        self.alpha = alpha
        self.dropout = dropout
        self.a = nn.Parameter(torch.zeros(size=(self.dim, self.da)), requires_grad=True)
        self.b = nn.Parameter(torch.zeros(size=(self.da, 1)), requires_grad=True)
        nn.init.xavier_uniform_(self.a.data, gain=1.414)
        nn.init.xavier_uniform_(self.b.data, gain=1.414)

    def forward(self, h):
        # h: (N, dim)
        e = torch.matmul(torch.tanh(torch.matmul(h, self.a)), self.b).squeeze(dim=1)
        attention = F.softmax(e, dim=0)  # (N)
        return torch.matmul(attention, h)  # (dim)

# %%
import torch
from torch import nn
from torch.nn import functional as F
from torch_geometric.nn import RGCNConv


class RecModel(nn.Module):
    def __init__(self, kg_emb_dim, n_entity, num_relations,
                 num_bases, edge_index, edge_type, device
    ):
        super(RecModel, self).__init__()
        
        self.device = device
        self.kg_emb_dim = kg_emb_dim
        self.kg_encoder = RGCNConv(kg_emb_dim, kg_emb_dim, num_relations=num_relations,
                                   num_bases=num_bases)
        
        self.edge_index = nn.Parameter(edge_index, requires_grad=False) # edge_index가 entity 정보 및 연결이 담긴 인덱스들 => grad=False로 변하지 말아라 (관계성이니)
        self.edge_type = nn.Parameter(edge_type, requires_grad=False)
    
        self.kg_attn = SelfAttentionBatch(self.kg_emb_dim, self.kg_emb_dim)
        
        self.rec_bias = nn.Linear(self.kg_emb_dim, n_entity)
        # self.rec_loss = nn.CrossEntropyLoss()
    
    def get_user_rep(self, batch):
        user_rep, item_rep = self.get_kg_user_rep(batch)

        return user_rep, item_rep

    def get_kg_user_rep(self, batch):
        user_rep, kg_embedding = self.get_kg_rep(batch) # (bs, user_dim), (n_entities, user_dim)

        return user_rep, kg_embedding # (bs, user_dim), (n_entities, user_dim)
    
    def get_kg_rep(self, batch):
        context_entities = batch['entity']

        kg_user_rep, kg_embedding = self._get_kg_user_rep(context_entities)  # (bs, dim), (n_entity, dim)

        return kg_user_rep, kg_embedding
    
    def _get_kg_user_rep(self, context_entities):
        # ipdb.set_trace()
        kg_embedding = self.kg_encoder(None, self.edge_index, self.edge_type)
        # print(self.config.edge_idx.shape)
        # ipdb.set_trace()
        user_rep = self._encode_user(context_entities, kg_embedding)  # (bs, dim)

        return user_rep, kg_embedding
    
    def _encode_user(self, entity_lists, kg_embedding):
        user_repr_list = []
        for entity_list in entity_lists:
            if not entity_list:
                user_repr_list.append(torch.zeros(self.kg_emb_dim, device=self.device))
                continue
            user_repr = kg_embedding[entity_list]
            user_repr = self.kg_attn(user_repr)
            user_repr_list.append(user_repr)
        return torch.stack(user_repr_list, dim=0)  # (bs, dim)
    
    def forward(self, batch):        
        user_rep, item_rep = self.get_user_rep(batch) # (bs, user_dim), (n_entities, user_dim)
        rec_scores = F.linear(user_rep, item_rep, self.rec_bias.bias)  # (bs, n_entity)

        return rec_scores

# %%
rec_loss = nn.CrossEntropyLoss()
rec_loss = self.rec_loss(rec_scores, y)
